# %% [markdown]
# <a href="https://colab.research.google.com/github/SaraBCoutinho/Pesquisa_Analysis/blob/main/LIAR_atual_Caso3_cv_tfidf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## PARTE I

# %% [markdown]
# Caso 3 adota pre process 1 para CV e TF IDF e adota Pre process 2 para Glove, W2V, Fast. Dai Para o Caso 3 sao 3 situaçoes: 1-Multiclass, 2-Binarizer, 3-Sentimental Liar.
# Logo em cada uma delas vai ter X_...3_a/b/c. Além disso, vai ter X_train_3_a_proc1 e X_train_3_a_proc2.

# %% [markdown]
# ### Imports

# %%
# %%capture
from numpy import load
#--Data
# !pip install datasets
from datasets import load_dataset
import pandas as pd
#--Data analysis 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import STOPWORDS, WordCloud
# !pip install ftfy
# import libraries
import ftfy
import nltk
import json
import re
# %matplotlib inline
import pandas as pd
import csv
import numpy as np
import nltk
import seaborn as sb
import warnings

from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.preprocessing import Binarizer

from collections import Counter
from os import listdir, makedirs
from os.path import isfile, join, splitext, split

from nltk.stem import SnowballStemmer
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from collections import defaultdict
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

from nltk import pos_tag
#nltk.download('stopwords')

from wordcloud import STOPWORDS, WordCloud

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.naive_bayes import GaussianNB

from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn import model_selection, naive_bayes, svm
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier # need to import xboost calssifer

warnings.filterwarnings('ignore')
np.random.seed(0)

import nltk
nltk.download('stopwords')

# stop words list set to english
stopwords_list = stopwords.words('english') # stop word list

""" Regular expression for cleaning the statements"""
import re

hashtag_re = re.compile(r"#\w+")
mention_re = re.compile(r"@\w+")
url_re = re.compile(r"(?:https?://)?(?:[-\w]+\.)+[a-zA-Z]{2,9}[-\w/#~:;.?+=&%@~]*")
extras_re = re.compile("[.;:!\'?,\"()\[\]]")
#apos_re = "\'[a-z]*"
#leftover_re = "\S+"

from unicodedata import normalize

# !pip install zeugma
# !pip install preprocessing
# !pip install function

from zeugma.embeddings import EmbeddingTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from preprocessing import *
from function import *

#!pip install itertools
import itertools
# !pip install bert_embedding
from bert_embedding import BertEmbedding

#classifiers
from sklearn.svm import SVC 
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import ExtraTreesClassifier
import tensorflow as tf#--cnn
from tensorflow.keras import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from gensim.models import Word2Vec

from sklearn.neighbors import KNeighborsClassifier

# %%
# !pip install transformers
import transformers
from transformers import pipeline, AutoTokenizer
# Out:
# Collecting transformers
#   Downloading transformers-4.17.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 5.3 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.2)
# Collecting numpy>=1.17
#   Downloading numpy-1.21.5-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 50.0 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.63.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 66.5 MB/s
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting tokenizers!=0.11.3,>=0.11.1
#   Downloading tokenizers-0.11.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 35.7 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 51.4 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, numpy, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.14.6
#     Uninstalling numpy-1.14.6:
#       Successfully uninstalled numpy-1.14.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mxnet 1.4.0 requires numpy<1.15.0,>=1.8.2, but you have numpy 1.21.5 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# bert-embedding 1.0.1 requires numpy==1.14.6, but you have numpy 1.21.5 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed numpy-1.21.5 pyyaml-6.0 sacremoses-0.0.47 tokenizers-0.11.6 transformers-4.17.0

# %% [markdown]
# ### Data

# %%
#dataset
dataset = load_dataset('liar')

#data
train=pd.DataFrame(dataset['train'])
test=pd.DataFrame(dataset['test'])
val=pd.DataFrame(dataset['validation'])
# Out:
# Downloading:   0%|          | 0.00/2.33k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.68k [00:00<?, ?B/s]
# Using custom data configuration default
# Downloading and preparing dataset liar/default (download: 989.82 KiB, generated: 3.26 MiB, post-processed: Unknown size, total: 4.22 MiB) to /root/.cache/huggingface/datasets/liar/default/1.0.0/479463e757b7991eed50ffa7504d7788d6218631a484442e2098dabbf3b44514...
# Downloading:   0%|          | 0.00/1.01M [00:00<?, ?B/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset liar downloaded and prepared to /root/.cache/huggingface/datasets/liar/default/1.0.0/479463e757b7991eed50ffa7504d7788d6218631a484442e2098dabbf3b44514. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# Dos pre processamentos, o multiclass tem desbalanceio na classe 5 , o sentimental liar é mais desbalanceado que o pré processamento 2.

# %%
#verificaçao de valores nulos - #without blank values
#example of sample (statement)
print(train['statement'][0])
print(pd.isnull(train['statement']).sum(),pd.isnull(test['statement']).sum(),pd.isnull(val['statement']).sum())
print(pd.isnull(train['label']).sum(),pd.isnull(test['label']).sum(),pd.isnull(val['label']).sum())
# Out:
# Says the Annies List political group supports third-trimester abortions on demand.
# 0 0 0
# 0 0 0

# %% [markdown]
# ### Case 1 (a) : Pre process + MultiClasse
# (X_train_a,y_train_a)

# %% [markdown]
# #### Pre process 1 + CV/TFIDF

# %% [markdown]
# This pre processing will be applied to all tecniques (CV, TFIDF)

# %%
# %%time
""" Regular expression for cleaning the statements"""
hashtag_re = re.compile(r"#\w+") # hashtag
mention_re = re.compile(r"@\w+") # arroba
url_re = re.compile(r"(?:https?://)?(?:[-\w]+\.)+[a-zA-Z]{2,9}[-\w/#~:;.?+=&%@~]*") #url e ponntuaçoes
extras_re = re.compile("[.;:!\'?,\"()\[\]]") # extras 
#apos_re = "\'[a-z]*"
#leftover_re = "\S+"

""" Preprocessing the text in the statements"""
def preprocess(text):
    p_text = hashtag_re.sub("[hashtag]",text)
    p_text = mention_re.sub("[mention]",p_text)
    p_text = extras_re.sub("",p_text)
    p_text = url_re.sub("[url]",p_text) #remove pontuaçoes, numeros
    p_text = ftfy.fix_text(p_text) #encoding 
    return p_text.lower() #change lower

# regular expression for custom tokenisation"
tokenise_re = re.compile(r"(\[[^\]]+\]|[-'\w]+|[^\s\w\[']+)") #([]|words|other non-space)

#--tokenizer
def tokenizer(str_input):
    words = re.sub(r"[^A-Za-z0-9\-]", " ", str_input).lower().split()
    porter_stemmer=nltk.PorterStemmer()
    words = [porter_stemmer.stem(word) for word in words]
    return words

# stop words list set to english
stopwords_list = stopwords.words('english') # stop word list

""" function for decontracting the statements"""
def decontracted(phrase):
    phrase = re.sub(r"won\'t", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase
# Out:
# CPU times: user 497 µs, sys: 13 µs, total: 510 µs
# Wall time: 521 µs

# %%
# %%time 
#pre process 1 
train['statement']=train['statement'].map(decontracted)
test['statement']=test['statement'].map(decontracted)
val['statement']=val['statement'].map(decontracted)

train['statement']=train['statement'].map(preprocess)
val['statement']=val['statement'].map(preprocess)
test['statement']=test['statement'].map(preprocess)

# specifying features and labels
X_train_a= train['statement']
X_val_a=val['statement']
X_test_a=test['statement']
y_train_a=train['label']
y_val_a=val['label']
y_test_a=test['label']
# Out:
# CPU times: user 925 ms, sys: 2.37 ms, total: 927 ms
# Wall time: 929 ms

# %% [markdown]
# ### Case 1 (b) : Pre process 1 + BinariClass
# (X_train_b,y_train_b)

# %%
# %%time 

del train
del test
del val
#data
train=pd.DataFrame(dataset['train'])
test=pd.DataFrame(dataset['test'])
val=pd.DataFrame(dataset['validation'])
#0 fake 1 true 
Original_labels={5:1, 4:1, 3:1, 1:0,2:0,0:0}
# Out:
# CPU times: user 2.28 s, sys: 71.7 ms, total: 2.35 s
# Wall time: 2.26 s

# %%
# %%time 
train['statement']=train['statement'].map(decontracted)
test['statement']=test['statement'].map(decontracted)
val['statement']=val['statement'].map(decontracted)

train['statement']=train['statement'].map(preprocess)
val['statement']=val['statement'].map(preprocess)
test['statement']=test['statement'].map(preprocess)

train['label'] = train['label'].map(Original_labels)
test['label'] = test['label'].map(Original_labels)
val['label'] = val['label'].map(Original_labels)

# specifying features and labels
X_train_b= train['statement']
X_val_b=val['statement']
X_test_b=test['statement']
y_train_b=train['label']
y_val_b=val['label']
y_test_b=test['label']
# Out:
# CPU times: user 842 ms, sys: 854 µs, total: 843 ms
# Wall time: 846 ms

# %%
y_train_b.value_counts(1)
# Out:
# 0    0.592755
# 1    0.407245
# Name: label, dtype: float64

# %% [markdown]
# ### Case 1 (c) : Pre process 1 + Sentimental Liar
# (X_train_c,y_train_c)

# %% [markdown]
# false (0), half-true(1), mostly-true(2), true (3), ,barely-true(4), pants-fire(5)
#
# 0-1-4-5:0, 2-3:1
#
# https://huggingface.co/datasets/liar
#
# https://arxiv.org/pdf/2009.01047v2.pdf

# %%
del train
del test
del val
#data
train=pd.DataFrame(dataset['train'])
test=pd.DataFrame(dataset['test'])
val=pd.DataFrame(dataset['validation'])

# %%
# %%time 
#0 fake 1 true 
Original_labels={5:0, 4:0, 3:1, 1:0,2:1,0:0}
# Out:
# CPU times: user 6 µs, sys: 1 µs, total: 7 µs
# Wall time: 11.4 µs

# %%
# %%time 
train['statement']=train['statement'].map(decontracted)
test['statement']=test['statement'].map(decontracted)
val['statement']=val['statement'].map(decontracted)

train['statement']=train['statement'].map(preprocess)
val['statement']=val['statement'].map(preprocess)
test['statement']=test['statement'].map(preprocess)

train['label'] = train['label'].map(Original_labels)
test['label'] = test['label'].map(Original_labels)
val['label'] = val['label'].map(Original_labels)

# specifying features and labels
X_train_c= train['statement']
X_val_c=val['statement']
X_test_c=test['statement']
y_train_c=train['label']
y_val_c=val['label']
y_test_c=test['label']
# Out:
# CPU times: user 847 ms, sys: 1.3 ms, total: 849 ms
# Wall time: 850 ms

# %%
y_train_c.count()
# Out:
# 10269

# %%
y_train_c.value_counts()
# Out:
# 0    6620
# 1    3649
# Name: label, dtype: int64

# %%
y_train_c.value_counts(1)
# Out:
# 0    0.644659
# 1    0.355341
# Name: label, dtype: float64

# %% [markdown]
# ### Embeddings

# %%
#Features
cv = CountVectorizer(analyzer='word', tokenizer= tokenizer, lowercase=True, stop_words=stopwords_list)
tfidf =  TfidfVectorizer(analyzer='word',  tokenizer= tokenizer, lowercase=True, use_idf=True, stop_words=stopwords_list)

# %% [markdown]
# ## PARTE II

# %% [markdown]
# ### Classificadores

# %%
#--Classifiers
#--SVM
def get_svm(cv, tfidf):
    return{
        'CV': {'CLF': SVC(random_state=42, kernel='linear', gamma=0.1, probability=True),'EXT': cv,},
        'TFIDF': {'CLF': SVC(random_state=42, kernel='linear', gamma=0.1, probability=True),'EXT': tfidf,},
    }

def get_svm(cv, tfidf):
    return{
        'CV': {'CLF': SVC(random_state=42, kernel='linear', gamma=0.1, probability=True),'EXT': cv,},
        'TFIDF': {'CLF': SVC(random_state=42, kernel='linear', gamma=0.1, probability=True),'EXT': tfidf,},
    }
    
#--LR
def get_lr(cv,tfidf):
    return {
        'CV': {'CLF': LogisticRegression(random_state=42,multi_class='auto', solver='liblinear', penalty='l1'),'EXT': cv,},
        'TFIDF': {'CLF': LogisticRegression(random_state=42, multi_class='auto', solver='liblinear', penalty='l1'),'EXT': tfidf,},
        }
#--RF
def get_rf(cv, tfidf):
    return {'CV': {'CLF': RandomForestClassifier(random_state=42, verbose=100, n_estimators=20, n_jobs=-1),'EXT': cv,},
        'TFIDF': {'CLF': RandomForestClassifier(random_state=42, verbose=100, n_estimators=50, n_jobs=-1),'EXT': tfidf,},
            }
#--NB
def get_nb(cv, tfidf):
    return {
        'CV': {'CLF': MultinomialNB(alpha=1, fit_prior=False),'EXT': cv,},
        'TFIDF': {'CLF': MultinomialNB(alpha=0.5, fit_prior=False),'EXT': tfidf,},
    }
#--MLP
def get_mlp(cv, tfidf):
    return {'CV': {'CLF': MLPClassifier(random_state=42, batch_size=20, max_iter=40,activation='relu', solver='lbfgs'),'EXT': cv,},
        'TFIDF': {'CLF': MLPClassifier(random_state=42, batch_size=20, max_iter=40,activation='logistic', solver='adam'),'EXT': tfidf,},
    }
#--EXTRA
def get_extra(cv, tfidf):
    return {
        'CV': {'CLF': ExtraTreesClassifier(random_state=42, n_estimators=50, n_jobs=-1),'EXT': cv,},
        'TFIDF': {'CLF': ExtraTreesClassifier(random_state=42, n_estimators=50, n_jobs=-1),'EXT': tfidf,},
    }
#--KNN
def get_knn(cv, tfidf):
    return {
        'CV': {'CLF': KNeighborsClassifier(n_neighbors=3, n_jobs=-1),'EXT': cv,},
        'TFIDF': {'CLF': KNeighborsClassifier(n_neighbors=5, n_jobs=-1),'EXT': tfidf,},
    }

# %%
def get_CNN_6(ext, tokenizer, MAX_NB_WORDS, EMBEDDING_DIM=300, MAX_SEQUENCE_LENGTH=300, activation='sigmoid', word_embedding=False, dense=6):
    if word_embedding == False:
        X_ext = ext.get_feature_names()
        model = Word2Vec([X_ext], min_count=1, workers=1, size=300)
    else:
        model = ext.model

    word_index = tokenizer.word_index

    nb_words = min(MAX_NB_WORDS, len(word_index)) + 1

    embedding_matrix = np.zeros((nb_words, EMBEDDING_DIM))
    for word, i in word_index.items():
        if word in model.wv.vocab:
            embedding_matrix[i] = model.wv.word_vec(word)

    embedding_layer = Embedding(nb_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False
                                )
    cnn = Sequential()
    cnn.add(embedding_layer)
    cnn.add(Dropout(0.2))
    cnn.add(Conv1D(64, 6, padding='valid', activation='relu', strides=1))
    cnn.add(GlobalMaxPooling1D())
    cnn.add(Dense(256))
    cnn.add(Dropout(0.2))
    cnn.add(Activation('relu'))
    cnn.add(Dense(6))
    cnn.add(Activation(activation))
    cnn.summary()
    cnn.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

    return cnn

def get_CNN_2(ext, tokenizer, MAX_NB_WORDS, EMBEDDING_DIM=300, MAX_SEQUENCE_LENGTH=300, activation='sigmoid', word_embedding=False, dense=2):
    if word_embedding == False:
        X_ext = ext.get_feature_names()
        model = Word2Vec([X_ext], min_count=1, workers=1, size=300)
    else:
        model = ext.model

    word_index = tokenizer.word_index

    nb_words = min(MAX_NB_WORDS, len(word_index)) + 1

    embedding_matrix = np.zeros((nb_words, EMBEDDING_DIM))
    for word, i in word_index.items():
        if word in model.wv.vocab:
            embedding_matrix[i] = model.wv.word_vec(word)

    embedding_layer = Embedding(nb_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False
                                )
    cnn = Sequential()
    cnn.add(embedding_layer)
    cnn.add(Dropout(0.2))
    cnn.add(Conv1D(64, 2, padding='valid', activation='relu', strides=1))
    cnn.add(GlobalMaxPooling1D())
    cnn.add(Dense(256))
    cnn.add(Dropout(0.2))
    cnn.add(Activation('relu'))
    cnn.add(Dense(2))
    cnn.add(Activation(activation))
    cnn.summary()
    cnn.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

    return cnn

# %%
def get_classifier(clf, X, y, ext):
    pipe_clf = Pipeline([('extractor', ext),('clf', clf)])
    pipe_clf.fit(X, y)
    return pipe_clf

# %%
def update_pred_proba_6(clfs, label, train, val, test):
    pred_val = pd.DataFrame()
    pred_test = pd.DataFrame()
    prob_val = pd.DataFrame()
    prob_test = pd.DataFrame()

    for ext, clf in clfs.items():
        # Predict
        df_pred_val_ = pd.DataFrame(clf.predict(val), columns=["{}-{}".format(label, ext)])
        df_pred_test_ = pd.DataFrame(clf.predict(test), columns=["{}-{}".format(label, ext)])
        
        # # Probabilidades
        cols = [
            "{}-{}-{}".format(label, ext, clf.classes_[0]), 
            "{}-{}-{}".format(label, ext, clf.classes_[1]),
            "{}-{}-{}".format(label, ext, clf.classes_[2]),
            "{}-{}-{}".format(label, ext, clf.classes_[3]),
            "{}-{}-{}".format(label, ext, clf.classes_[4]),
            "{}-{}-{}".format(label, ext, clf.classes_[5])
        ]
        df_prob_val_ = pd.DataFrame(clf.predict_proba(val), columns=cols)
        df_prob_test_ = pd.DataFrame(clf.predict_proba(test), columns=cols)

        pred_val = pd.concat([pred_val, df_pred_val_], axis=1, sort=False)
        pred_test = pd.concat([pred_test, df_pred_test_], axis=1, sort=False)

        prob_val = pd.concat([prob_val, df_prob_val_], axis=1, sort=False)
        prob_test = pd.concat([prob_test, df_prob_test_], axis=1, sort=False)

    return pred_val, pred_test, prob_val, prob_test

def update_pred_proba_2(clfs, label, train, val, test):
    pred_val = pd.DataFrame()
    pred_test = pd.DataFrame()

    prob_val = pd.DataFrame()
    prob_test = pd.DataFrame()

    for ext, clf in clfs.items():
        # Predict
        df_pred_val_ = pd.DataFrame(clf.predict(val), columns=["{}-{}".format(label, ext)])
        df_pred_test_ = pd.DataFrame(clf.predict(test), columns=["{}-{}".format(label, ext)])
        
        # # Probabilidades
        cols = [
            "{}-{}-{}".format(label, ext, clf.classes_[0]), 
            "{}-{}-{}".format(label, ext, clf.classes_[1])
        ]
        df_prob_val_ = pd.DataFrame(clf.predict_proba(val), columns=cols)
        df_prob_test_ = pd.DataFrame(clf.predict_proba(test), columns=cols)

        pred_val = pd.concat([pred_val, df_pred_val_], axis=1, sort=False)
        pred_test = pd.concat([pred_test, df_pred_test_], axis=1, sort=False)

        prob_val = pd.concat([prob_val, df_prob_val_], axis=1, sort=False)
        prob_test = pd.concat([prob_test, df_prob_test_], axis=1, sort=False)

    return pred_val, pred_test, prob_val, prob_test

# %% [markdown]
# #### Caso 1 (a) - 6

# %%
# !mkdir Data
# !mkdir Data/liar

# %%
del train
del test
del val
#data
train=pd.DataFrame(dataset['train'])
test=pd.DataFrame(dataset['test'])
val=pd.DataFrame(dataset['validation'])

# %%
# load data
train.to_csv('/content/Data/liar/train_1_a.csv')
test.to_csv('/content/Data/liar/test_1_a.csv')
val.to_csv('/content/Data/liar/val_1_a.csv')
y_train=train['label']
y_train.to_csv('/content/Data/liar/train_labels_1_a.csv')
y_test=test['label']
y_test.to_csv('/content/Data/liar/test_labels_1_a.csv')
y_val=val['label']
y_val.to_csv('/content/Data/liar/val_labels_1_a.csv')

# %%
train_1_a=train
test_1_a=test 
val_1_a=val

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
# %%time
def main():
  for db in ["liar"]:
    if db == 'liar':
      classe = 'label'
      df_pred_val = pd.DataFrame()
      df_pred_test = pd.DataFrame()
      df_prob_val = pd.DataFrame()# inicializando proba
      df_prob_test = pd.DataFrame()
      
      df_pred_val = pd.concat([df_pred_val, val_1_a['label']], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, test_1_a['label']], axis=1, sort=False)
      df_prob_val = pd.concat([df_prob_val, val_1_a['label']], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, test_1_a['label']], axis=1, sort=False)
      print('dados ok')

      # SVM
      classifier = get_svm(cv, tfidf)
      clfs = { }
      for ext, clf in classifier.items():
        clfs[ext] = get_classifier(clf['CLF'], X_train_a, y_train_a, clf['EXT'])
      pred_val, pred_test, prob_val, prob_test = update_pred_proba_6(clfs, "SVM", X_train_a, X_val_a, X_test_a)

      print('svm parte 1 ok')
      
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('svm parte 2 ok')

      # LR
      classifier = get_lr(cv,tfidf)
      clfs = { }
      for ext, clf in classifier.items():
        clfs[ext] = get_classifier(clf['CLF'],X_train_a, y_train_a, clf['EXT'])

      pred_val, pred_test, prob_val, prob_test = update_pred_proba_6(clfs, "LR", X_train_a, X_val_a, X_test_a)
      
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('lr ok')

      # RF
      classifier = get_rf(cv, tfidf)
      # clfs = { }
      for ext, clf in classifier.items():
          clfs.update({ext: get_classifier(clf['CLF'], X_train_a, y_train_a, clf['EXT'])})
      pred_val, pred_test, prob_val, prob_test = update_pred_proba_6(clfs, "RF", X_train_a, X_val_a, X_test_a)
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('rf ok')

      # NB
      classifier = get_nb(cv, tfidf)
      # clfs = { }
      for ext, clf in classifier.items():
          clfs.update({ext: get_classifier(clf['CLF'], X_train_a, y_train_a, clf['EXT'])})
      pred_val, pred_test, prob_val, prob_test = update_pred_proba_6(clfs, "NB", X_train_a, X_val_a, X_test_a)
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('nb ok')

      # MLP
      classifier = get_mlp(cv, tfidf)
      # clfs = { }
      for ext, clf in classifier.items():
          clfs.update({ext: get_classifier(clf['CLF'],X_train_a, y_train_a, clf['EXT'])})
          
      pred_val, pred_test, prob_train, prob_test = update_pred_proba_6(clfs, "MLP", X_train_a, X_val_a, X_test_a)
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('mlp ok')

      # Extra
      classifier = get_extra(cv, tfidf)
      # clfs = { }
      for ext, clf in classifier.items():
          clfs.update({ext: get_classifier(clf['CLF'],X_train_a, y_train_a, clf['EXT'])})
          
      pred_val, pred_test, prob_val, prob_test = update_pred_proba_6(clfs, "EXTRA", X_train_a, X_val_a, X_test_a)
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('extra ok')

      # KNN
      classifier = get_knn(cv, tfidf)
      # clfs = { }
      for ext, clf in classifier.items():
          clfs.update({ext: get_classifier(clf['CLF'],X_train_a, y_train_a, clf['EXT'])})
          
      pred_val, pred_test, prob_val, prob_test = update_pred_proba_6(clfs, "KNN", X_train_a, X_val_a, X_test_a)
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('knn ok')

      #CNN
      MAX_NB_WORDS = 20000
      MAX_SEQUENCE_LENGTH=300
      tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
      tokenizer.fit_on_texts(X_train_a) #rever por que 
      seq_train = tokenizer.texts_to_sequences(X_train_a)
      seq_val = tokenizer.texts_to_sequences(X_val_a)
      seq_test = tokenizer.texts_to_sequences(X_test_a)

      data_train = pad_sequences(seq_train,padding='pre', truncating='pre',maxlen=MAX_SEQUENCE_LENGTH)
      data_val = pad_sequences(seq_val,padding='pre', truncating='pre',maxlen=MAX_SEQUENCE_LENGTH)
      data_test = pad_sequences(seq_test, padding='pre', truncating='pre',maxlen=MAX_SEQUENCE_LENGTH)
                            
      # NET
      cnn_cv = get_CNN_6(cv, tokenizer, MAX_NB_WORDS, EMBEDDING_DIM=300, activation='sigmoid', dense=3)
      cnn_tfidf = get_CNN_6(tfidf, tokenizer, MAX_NB_WORDS, EMBEDDING_DIM=300, activation='sigmoid', dense=3)
      
      y_validation=to_categorical(y_val_a)
      y_training=to_categorical(y_train_a)
      y_testing=to_categorical(y_test_a)
      
      # TRAIN
      cnn_cv.fit(data_train, y_training, validation_data=(data_val,y_validation), epochs=20, batch_size=20)
      cnn_tfidf.fit(data_train, y_training, validation_data=(data_val,y_validation), epochs=20, batch_size=20)
     
      #predictions and proba
      cols = ["CNN-CV-0", "CNN-CV-1","CNN-CV-2", "CNN-CV-3","CNN-CV-4", "CNN-CV-5"]
      df_val_ = pd.DataFrame(np.argmax(cnn_cv.predict(data_val), axis=1), columns=["CNN-CV"])
      df_test_ = pd.DataFrame(np.argmax(cnn_cv.predict(data_test), axis=1), columns=["CNN-CV"])
      df_pred_val = pd.concat([df_pred_val, df_val_], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, df_test_], axis=1, sort=False)
      # Probabilidades
      df_val_ = pd.DataFrame(cnn_cv.predict(data_val), columns=cols)
      df_test_ = pd.DataFrame(cnn_cv.predict(data_test), columns=cols)
      df_prob_val = pd.concat([df_prob_val, df_val_], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, df_test_], axis=1, sort=False)
      
      cols = ["CNN-TF-0", "CNN-TF-1","CNN-TF-2", "CNN-TF-3","CNN-TF-4", "CNN-TF-5"]
      df_val_ = pd.DataFrame(np.argmax(cnn_tfidf.predict(data_val), axis=1), columns=["CNN-TFIDF"])
      df_test_ = pd.DataFrame(np.argmax(cnn_tfidf.predict(data_test), axis=1), columns=["CNN-TFIDF"])
      df_pred_val = pd.concat([df_pred_val, df_val_], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, df_test_], axis=1, sort=False)
      # Probabilidades
      df_val_ = pd.DataFrame(cnn_tfidf.predict(data_val), columns=cols)
      df_test_ = pd.DataFrame(cnn_tfidf.predict(data_test), columns=cols)
      df_prob_val = pd.concat([df_prob_val, df_val_], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, df_test_], axis=1, sort=False)

      print('cnn ok')     

      # Probabilidade
      path = "./Data/{}".format(db)
      df_pred_val.to_csv("{}/pred_val_3_a.csv".format(path))
      df_pred_test.to_csv("{}/pred_test_3_a.csv".format(path))
      df_prob_val.to_csv("{}/prob_val_3_a.csv".format(path))
      df_prob_test.to_csv("{}/prob_test_3_a.csv".format(path))
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 9.06 µs

# %%
# %%time
if __name__ == "__main__":
    main()
# Out:
# dados ok
# svm parte 1 ok
# svm parte 2 ok
# lr ok
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 20
# building tree 2 of 20
# building tree 3 of 20[Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.2s
#
# building tree 4 of 20[Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.2s
#
# building tree 5 of 20[Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.5s
#
# building tree 6 of 20[Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.5s
#
# building tree 7 of 20[Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.7s
#
# building tree 8 of 20
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    0.7s
# building tree 9 of 20[Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    0.9s
#
# building tree 10 of 20[Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    1.0s
#
# building tree 11 of 20[Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    1.2s
#
# building tree 12 of 20[Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.2s
#
# building tree 13 of 20[Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    1.4s
#
# building tree 14 of 20[Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    1.5s
#
# building tree 15 of 20[Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    1.6s
#
# building tree 16 of 20[Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    1.7s
#
# building tree 17 of 20[Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    1.9s
#
# building tree 18 of 20[Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    1.9s
#
# building tree 19 of 20[Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    2.1s
#
# building tree 20 of 20[Parallel(n_jobs=-1)]: Done  18 out of  20 | elapsed:    2.2s remaining:    0.2s
#
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    2.4s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 50
# building tree 2 of 50
# building tree 3 of 50[Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.2s
#
# building tree 4 of 50[Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.2s
#
# building tree 5 of 50[Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.5s
#
# building tree 6 of 50[Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.5s
#
# building tree 7 of 50[Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.7s
#
# building tree 8 of 50[Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    0.7s
#
# building tree 9 of 50[Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    0.9s
#
# building tree 10 of 50[Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    1.0s
#
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    1.1s
# building tree 11 of 50
# building tree 12 of 50[Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.2s
#
# building tree 13 of 50[Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    1.4s
#
# building tree 14 of 50[Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    1.4s
#
# building tree 15 of 50[Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    1.6s
#
# building tree 16 of 50[Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    1.7s
#
# building tree 17 of 50[Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    1.8s
#
# building tree 18 of 50[Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    1.9s
#
# building tree 19 of 50[Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    2.1s
#
# building tree 20 of 50[Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    2.1s
#
# building tree 21 of 50[Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:    2.3s
#
# building tree 22 of 50[Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:    2.3s
#
# building tree 23 of 50[Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    2.5s
#
# building tree 24 of 50[Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:    2.6s
#
# building tree 25 of 50[Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:    2.8s
#
# building tree 26 of 50[Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    2.8s
#
# building tree 27 of 50[Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    3.0s
#
# building tree 28 of 50[Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    3.0s
#
# building tree 29 of 50[Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    3.3s
#
# building tree 30 of 50[Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    3.3s
#
# building tree 31 of 50[Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:    3.5s
#
# building tree 32 of 50
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    3.5s
# building tree 33 of 50[Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:    3.7s
#
# building tree 34 of 50[Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    3.7s
#
# building tree 35 of 50[Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    3.9s
#
# building tree 36 of 50[Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    3.9s
#
# building tree 37 of 50[Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:    4.2s
#
# building tree 38 of 50[Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:    4.2s
#
# building tree 39 of 50[Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    4.4s
#
# building tree 40 of 50[Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:    4.4s
#
# building tree 41 of 50[Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:    4.6s
#
# building tree 42 of 50[Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    4.6s
#
# building tree 43 of 50[Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:    4.9s
#
# building tree 44 of 50[Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    4.9s
#
# building tree 45 of 50[Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:    5.1s
#
# building tree 46 of 50[Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:    5.1s
#
# building tree 47 of 50[Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:    5.3s
#
# building tree 48 of 50
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:    5.3s
# building tree 49 of 50[Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:    5.6s
#
# building tree 50 of 50[Parallel(n_jobs=-1)]: Done  48 out of  50 | elapsed:    5.6s remaining:    0.2s
#
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    5.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    5.8s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  19 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  22 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  23 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  27 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  29 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  31 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  32 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  33 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  38 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  39 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  40 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  41 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  43 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  45 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  47 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  48 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  19 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  22 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  23 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  27 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  29 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  31 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  32 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  33 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  38 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  39 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  40 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  41 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  43 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  45 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  47 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  48 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  19 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  22 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  23 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  27 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  29 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  31 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  32 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  33 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  38 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  39 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  40 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  41 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  43 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  45 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  47 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  48 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  19 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  22 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  23 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  27 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  29 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  31 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  32 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  33 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  38 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  39 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  40 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  41 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  43 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  45 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  47 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  48 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s finished
# rf ok
# nb ok
# mlp ok
# extra ok
# knn ok
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 300, 300)          3750000
#
#  dropout (Dropout)           (None, 300, 300)          0
#
#  conv1d (Conv1D)             (None, 295, 64)           115264
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 256)               16640
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  activation (Activation)     (None, 256)               0
#
#  dense_1 (Dense)             (None, 6)                 1542
#
#  activation_1 (Activation)   (None, 6)                 0
#
# =================================================================
# Total params: 3,883,446
# Trainable params: 133,446
# Non-trainable params: 3,750,000
# _________________________________________________________________
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 300, 300)          3750000
#
#  dropout_2 (Dropout)         (None, 300, 300)          0
#
#  conv1d_1 (Conv1D)           (None, 295, 64)           115264
#
#  global_max_pooling1d_1 (Glo  (None, 64)               0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (None, 256)               16640
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dense_3 (Dense)             (None, 6)                 1542
#
#  activation_3 (Activation)   (None, 6)                 0
#
# =================================================================
# Total params: 3,883,446
# Trainable params: 133,446
# Non-trainable params: 3,750,000
# _________________________________________________________________
# Epoch 1/20
# 514/514 [==============================] - 54s 104ms/step - loss: 1.7600 - accuracy: 0.2007 - val_loss: 1.7647 - val_accuracy: 0.1955
# Epoch 2/20
# 514/514 [==============================] - 53s 104ms/step - loss: 1.7564 - accuracy: 0.2046 - val_loss: 1.7600 - val_accuracy: 0.1994
# Epoch 3/20
# 514/514 [==============================] - 52s 101ms/step - loss: 1.7511 - accuracy: 0.2083 - val_loss: 1.7525 - val_accuracy: 0.2321
# Epoch 4/20
# 514/514 [==============================] - 52s 101ms/step - loss: 1.7428 - accuracy: 0.2285 - val_loss: 1.7652 - val_accuracy: 0.1986
# Epoch 5/20
# 514/514 [==============================] - 51s 100ms/step - loss: 1.7337 - accuracy: 0.2327 - val_loss: 1.7364 - val_accuracy: 0.2492
# Epoch 6/20
# 514/514 [==============================] - 52s 100ms/step - loss: 1.7226 - accuracy: 0.2431 - val_loss: 1.7324 - val_accuracy: 0.2500
# Epoch 7/20
# 514/514 [==============================] - 52s 100ms/step - loss: 1.7088 - accuracy: 0.2512 - val_loss: 1.7296 - val_accuracy: 0.2570
# Epoch 8/20
# 514/514 [==============================] - 51s 100ms/step - loss: 1.6967 - accuracy: 0.2560 - val_loss: 1.7343 - val_accuracy: 0.2220
# Epoch 9/20
# 514/514 [==============================] - 52s 100ms/step - loss: 1.6816 - accuracy: 0.2683 - val_loss: 1.7559 - val_accuracy: 0.2407
# Epoch 10/20
# 514/514 [==============================] - 52s 101ms/step - loss: 1.6658 - accuracy: 0.2780 - val_loss: 1.7567 - val_accuracy: 0.2523
# Epoch 11/20
# 514/514 [==============================] - 52s 101ms/step - loss: 1.6480 - accuracy: 0.2822 - val_loss: 1.7382 - val_accuracy: 0.2547
# Epoch 12/20
# 514/514 [==============================] - 51s 100ms/step - loss: 1.6251 - accuracy: 0.2977 - val_loss: 1.7563 - val_accuracy: 0.2399
# Epoch 13/20
# 514/514 [==============================] - 51s 99ms/step - loss: 1.6019 - accuracy: 0.3126 - val_loss: 1.7516 - val_accuracy: 0.2235
# Epoch 14/20
# 514/514 [==============================] - 51s 99ms/step - loss: 1.5761 - accuracy: 0.3309 - val_loss: 1.7690 - val_accuracy: 0.2368
# Epoch 15/20
# 514/514 [==============================] - 51s 99ms/step - loss: 1.5420 - accuracy: 0.3472 - val_loss: 1.9056 - val_accuracy: 0.2126
# Epoch 16/20
# 514/514 [==============================] - 51s 99ms/step - loss: 1.5086 - accuracy: 0.3722 - val_loss: 1.8192 - val_accuracy: 0.2064
# Epoch 17/20
# 514/514 [==============================] - 51s 99ms/step - loss: 1.4821 - accuracy: 0.3879 - val_loss: 1.8328 - val_accuracy: 0.2142
# Epoch 18/20
# 514/514 [==============================] - 51s 99ms/step - loss: 1.4443 - accuracy: 0.4092 - val_loss: 1.9059 - val_accuracy: 0.2251
# Epoch 19/20
# 514/514 [==============================] - 51s 99ms/step - loss: 1.4059 - accuracy: 0.4303 - val_loss: 1.8910 - val_accuracy: 0.2313
# Epoch 20/20
# 514/514 [==============================] - 51s 99ms/step - loss: 1.3728 - accuracy: 0.4479 - val_loss: 1.8589 - val_accuracy: 0.2126
# Epoch 1/20
# 514/514 [==============================] - 58s 111ms/step - loss: 1.7609 - accuracy: 0.2071 - val_loss: 1.7665 - val_accuracy: 0.1931
# Epoch 2/20
# 514/514 [==============================] - 57s 111ms/step - loss: 1.7567 - accuracy: 0.2040 - val_loss: 1.7612 - val_accuracy: 0.2048
# Epoch 3/20
# 514/514 [==============================] - 57s 111ms/step - loss: 1.7534 - accuracy: 0.2058 - val_loss: 1.7528 - val_accuracy: 0.2274
# Epoch 4/20
# 514/514 [==============================] - 57s 111ms/step - loss: 1.7468 - accuracy: 0.2211 - val_loss: 1.7508 - val_accuracy: 0.2298
# Epoch 5/20
# 514/514 [==============================] - 57s 110ms/step - loss: 1.7392 - accuracy: 0.2307 - val_loss: 1.7448 - val_accuracy: 0.2368
# Epoch 6/20
# 514/514 [==============================] - 57s 110ms/step - loss: 1.7286 - accuracy: 0.2389 - val_loss: 1.7393 - val_accuracy: 0.2375
# Epoch 7/20
# 514/514 [==============================] - 57s 110ms/step - loss: 1.7157 - accuracy: 0.2526 - val_loss: 1.7384 - val_accuracy: 0.2383
# Epoch 8/20
# 514/514 [==============================] - 56s 109ms/step - loss: 1.7006 - accuracy: 0.2644 - val_loss: 1.7443 - val_accuracy: 0.2484
# Epoch 9/20
# 514/514 [==============================] - 56s 110ms/step - loss: 1.6857 - accuracy: 0.2695 - val_loss: 1.7468 - val_accuracy: 0.2360
# Epoch 10/20
# 514/514 [==============================] - 56s 110ms/step - loss: 1.6699 - accuracy: 0.2788 - val_loss: 1.7301 - val_accuracy: 0.2445
# Epoch 11/20
# 514/514 [==============================] - 56s 110ms/step - loss: 1.6498 - accuracy: 0.2936 - val_loss: 1.7431 - val_accuracy: 0.2453
# Epoch 12/20
# 514/514 [==============================] - 56s 110ms/step - loss: 1.6273 - accuracy: 0.3103 - val_loss: 1.7428 - val_accuracy: 0.2321
# Epoch 13/20
# 514/514 [==============================] - 56s 110ms/step - loss: 1.6046 - accuracy: 0.3269 - val_loss: 1.7624 - val_accuracy: 0.2251
# Epoch 14/20
# 514/514 [==============================] - 56s 109ms/step - loss: 1.5811 - accuracy: 0.3439 - val_loss: 1.7626 - val_accuracy: 0.2243
# Epoch 15/20
# 514/514 [==============================] - 56s 110ms/step - loss: 1.5512 - accuracy: 0.3560 - val_loss: 1.7600 - val_accuracy: 0.2274
# Epoch 16/20
# 514/514 [==============================] - 56s 110ms/step - loss: 1.5226 - accuracy: 0.3663 - val_loss: 1.8064 - val_accuracy: 0.2305
# Epoch 17/20
# 514/514 [==============================] - 56s 110ms/step - loss: 1.4942 - accuracy: 0.3842 - val_loss: 1.9446 - val_accuracy: 0.2274
# Epoch 18/20
# 514/514 [==============================] - 56s 109ms/step - loss: 1.4580 - accuracy: 0.4011 - val_loss: 1.8338 - val_accuracy: 0.2087
# Epoch 19/20
# 514/514 [==============================] - 56s 110ms/step - loss: 1.4231 - accuracy: 0.4252 - val_loss: 1.9303 - val_accuracy: 0.2087
# Epoch 20/20
# 514/514 [==============================] - 56s 110ms/step - loss: 1.3924 - accuracy: 0.4359 - val_loss: 1.8497 - val_accuracy: 0.2220
# cnn ok
# CPU times: user 1h 17min 48s, sys: 10min 57s, total: 1h 28min 45s
# Wall time: 52min 32s

# %% [markdown]
# #### Caso 1 (b) - 2

# %%
del train
del test
del val
#data
train=pd.DataFrame(dataset['train'])
test=pd.DataFrame(dataset['test'])
val=pd.DataFrame(dataset['validation'])

Original_labels={5:1, 4:1, 3:1, 1:0,2:0,0:0}

train['label'] = train['label'].map(Original_labels)
test['label'] = test['label'].map(Original_labels)
val['label'] = val['label'].map(Original_labels)

# load data
train.to_csv('/content/Data/liar/train_3_b.csv')
test.to_csv('/content/Data/liar/test_3_b.csv')
val.to_csv('/content/Data/liar/val_3_b.csv')
y_train.to_csv('/content/Data/liar/train_labels_3_b.csv')
y_test.to_csv('/content/Data/liar/test_labels_3_b.csv')
y_val.to_csv('/content/Data/liar/val_labels_3_b.csv')

train_3_b=train
test_3_b=test 
val_3_b=val

# %%
# %%time
def main():
  for db in ["liar"]:
    if db == 'liar':
      classe = 'label'
      df_pred_val = pd.DataFrame()
      df_pred_test = pd.DataFrame()
      df_prob_val = pd.DataFrame()# inicializando proba
      df_prob_test = pd.DataFrame()
      
      df_pred_val = pd.concat([df_pred_val, val_3_b['label']], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, test_3_b['label']], axis=1, sort=False)
      df_prob_val = pd.concat([df_prob_val, val_3_b['label']], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, test_3_b['label']], axis=1, sort=False)
      print('dados ok')

      # SVM
      classifier = get_svm(cv, tfidf)
      clfs = { }
      for ext, clf in classifier.items():
        clfs[ext] = get_classifier(clf['CLF'], X_train_b, y_train_b, clf['EXT'])
      pred_val, pred_test, prob_val, prob_test = update_pred_proba_2(clfs, "SVM", X_train_b, X_val_b, X_test_b)

      print('svm parte 1 ok')
      
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('svm parte 2 ok')

      # LR
      classifier = get_lr(cv,tfidf)
      clfs = { }
      for ext, clf in classifier.items():
        clfs[ext] = get_classifier(clf['CLF'],X_train_b, y_train_b, clf['EXT'])

      pred_val, pred_test, prob_val, prob_test = update_pred_proba_2(clfs, "LR", X_train_b, X_val_b, X_test_b)
      
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('lr ok')

      # RF
      classifier = get_rf(cv, tfidf)
      # clfs = { }
      for ext, clf in classifier.items():
          clfs.update({ext: get_classifier(clf['CLF'], X_train_b, y_train_b, clf['EXT'])})
      pred_val, pred_test, prob_val, prob_test = update_pred_proba_2(clfs, "RF", X_train_b, X_val_b, X_test_b)
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('rf ok')

      # NB
      classifier = get_nb(cv, tfidf)
      # clfs = { }
      for ext, clf in classifier.items():
          clfs.update({ext: get_classifier(clf['CLF'], X_train_b, y_train_b, clf['EXT'])})
      pred_val, pred_test, prob_val, prob_test = update_pred_proba_2(clfs, "NB", X_train_b, X_val_b, X_test_b)
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('nb ok')

      # MLP
      classifier = get_mlp(cv, tfidf)
      # clfs = { }
      for ext, clf in classifier.items():
          clfs.update({ext: get_classifier(clf['CLF'],X_train_b, y_train_b, clf['EXT'])})
          
      pred_val, pred_test, prob_train, prob_test = update_pred_proba_2(clfs, "MLP", X_train_b, X_val_b, X_test_b)
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('mlp ok')

      # Extra
      classifier = get_extra(cv, tfidf)
      # clfs = { }
      for ext, clf in classifier.items():
          clfs.update({ext: get_classifier(clf['CLF'],X_train_b, y_train_b, clf['EXT'])})
          
      pred_val, pred_test, prob_val, prob_test = update_pred_proba_2(clfs, "EXTRA", X_train_b, X_val_b, X_test_b)
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('extra ok')

      # KNN
      classifier = get_knn(cv, tfidf)
      # clfs = { }
      for ext, clf in classifier.items():
          clfs.update({ext: get_classifier(clf['CLF'],X_train_b, y_train_b, clf['EXT'])})
          
      pred_val, pred_test, prob_val, prob_test = update_pred_proba_2(clfs, "KNN", X_train_b, X_val_b, X_test_b)
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('knn ok')

      #CNN
      MAX_NB_WORDS = 20000
      MAX_SEQUENCE_LENGTH=300
      tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
      tokenizer.fit_on_texts(X_train_b) #rever por que 
      seq_train = tokenizer.texts_to_sequences(X_train_b)
      seq_val = tokenizer.texts_to_sequences(X_val_b)
      seq_test = tokenizer.texts_to_sequences(X_test_b)

      data_train = pad_sequences(seq_train,padding='pre', truncating='pre',maxlen=MAX_SEQUENCE_LENGTH)
      data_val = pad_sequences(seq_val,padding='pre', truncating='pre',maxlen=MAX_SEQUENCE_LENGTH)
      data_test = pad_sequences(seq_test, padding='pre', truncating='pre',maxlen=MAX_SEQUENCE_LENGTH)
                            
      # NET
      cnn_cv = get_CNN_2(cv, tokenizer, MAX_NB_WORDS, EMBEDDING_DIM=300, activation='sigmoid', dense=2)
      cnn_tfidf = get_CNN_2(tfidf, tokenizer, MAX_NB_WORDS, EMBEDDING_DIM=300, activation='sigmoid', dense=2)
      
      y_validation=to_categorical(y_val_b)
      y_training=to_categorical(y_train_b)
      y_testing=to_categorical(y_test_b)
      
      # TRAIN
      cnn_cv.fit(data_train, y_training, validation_data=(data_val,y_validation), epochs=20, batch_size=20)
      cnn_tfidf.fit(data_train, y_training, validation_data=(data_val,y_validation), epochs=20, batch_size=20)
     
      #predictions and proba
      cols = ["CNN-CV-0", "CNN-CV-1"]
      df_val_ = pd.DataFrame(np.argmax(cnn_cv.predict(data_val), axis=1), columns=["CNN-CV"])
      df_test_ = pd.DataFrame(np.argmax(cnn_cv.predict(data_test), axis=1), columns=["CNN-CV"])
      df_pred_val = pd.concat([df_pred_val, df_val_], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, df_test_], axis=1, sort=False)
      # Probabilidades
      df_val_ = pd.DataFrame(cnn_cv.predict(data_val), columns=cols)
      df_test_ = pd.DataFrame(cnn_cv.predict(data_test), columns=cols)
      df_prob_val = pd.concat([df_prob_val, df_val_], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, df_test_], axis=1, sort=False)
      
      cols = ["CNN-TF-0", "CNN-TF-1"]
      df_val_ = pd.DataFrame(np.argmax(cnn_tfidf.predict(data_val), axis=1), columns=["CNN-TFIDF"])
      df_test_ = pd.DataFrame(np.argmax(cnn_tfidf.predict(data_test), axis=1), columns=["CNN-TFIDF"])
      df_pred_val = pd.concat([df_pred_val, df_val_], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, df_test_], axis=1, sort=False)
      # Probabilidades
      df_val_ = pd.DataFrame(cnn_tfidf.predict(data_val), columns=cols)
      df_test_ = pd.DataFrame(cnn_tfidf.predict(data_test), columns=cols)
      df_prob_val = pd.concat([df_prob_val, df_val_], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, df_test_], axis=1, sort=False)

      print('cnn ok')     

      # Probabilidade
      path = "./Data/{}".format(db)
      df_pred_val.to_csv("{}/pred_val_3_b.csv".format(path))
      df_pred_test.to_csv("{}/pred_test_3_b.csv".format(path))
      df_prob_val.to_csv("{}/prob_val_3_b.csv".format(path))
      df_prob_test.to_csv("{}/prob_test_3_b.csv".format(path))
# Out:
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 9.78 µs

# %%
# %%time
if __name__ == "__main__":
    main()
# Out:
# dados ok
# svm parte 1 ok
# svm parte 2 ok
# lr ok
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 20building tree 2 of 20
#
# building tree 3 of 20[Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.2s
#
# building tree 4 of 20[Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.2s
#
# building tree 5 of 20[Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.4s
#
# building tree 6 of 20[Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.4s
#
# building tree 7 of 20[Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.5s
#
# building tree 8 of 20[Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    0.5s
#
# building tree 9 of 20[Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    0.7s
#
# building tree 10 of 20[Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.7s
#
# building tree 11 of 20[Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    0.9s
#
# building tree 12 of 20[Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    0.9s
#
# building tree 13 of 20[Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    1.1s
#
# building tree 14 of 20[Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    1.1s
#
# building tree 15 of 20[Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    1.2s
#
# building tree 16 of 20[Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    1.3s
#
# building tree 17 of 20[Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    1.4s
#
# building tree 18 of 20[Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    1.5s
#
# building tree 19 of 20[Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    1.6s
#
# building tree 20 of 20[Parallel(n_jobs=-1)]: Done  18 out of  20 | elapsed:    1.6s remaining:    0.2s
#
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    1.8s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 50
# building tree 2 of 50
# building tree 3 of 50[Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.1s
#
# building tree 4 of 50[Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.2s
#
# building tree 5 of 50[Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.3s
#
# building tree 6 of 50[Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.3s
#
# building tree 7 of 50[Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.5s
#
# building tree 8 of 50[Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    0.5s
#
# building tree 9 of 50[Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    0.7s
#
# building tree 10 of 50[Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.7s
#
# building tree 11 of 50[Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    0.8s
#
# building tree 12 of 50[Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    0.8s
#
# building tree 13 of 50[Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    1.0s
#
# building tree 14 of 50[Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    1.0s
#
# building tree 15 of 50[Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    1.2s
#
# building tree 16 of 50[Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    1.2s
#
# building tree 17 of 50[Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    1.3s
#
# building tree 18 of 50[Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    1.3s
#
# building tree 19 of 50[Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    1.5s
#
# building tree 20 of 50[Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    1.5s
#
# building tree 21 of 50[Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:    1.6s
#
# building tree 22 of 50[Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:    1.7s
#
# building tree 23 of 50[Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    1.8s
#
# building tree 24 of 50[Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:    1.8s
#
# building tree 25 of 50[Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:    2.0s
#
# building tree 26 of 50[Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    2.0s
#
# building tree 27 of 50[Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    2.2s
#
# building tree 28 of 50[Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    2.2s
#
# building tree 29 of 50[Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    2.4s
#
# building tree 30 of 50[Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    2.4s
#
# building tree 31 of 50[Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:    2.5s
#
# building tree 32 of 50[Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    2.5s
#
# building tree 33 of 50[Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:    2.7s
#
# building tree 34 of 50[Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    2.7s
#
# building tree 35 of 50[Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    2.8s
#
# building tree 36 of 50[Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.9s
#
# building tree 37 of 50[Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:    3.0s
#
# building tree 38 of 50[Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:    3.0s
#
# building tree 39 of 50[Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    3.2s
#
# building tree 40 of 50[Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:    3.2s
#
# building tree 41 of 50[Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:    3.4s
#
# building tree 42 of 50[Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    3.4s
#
# building tree 43 of 50[Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:    3.5s
#
# building tree 44 of 50[Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    3.5s
#
# building tree 45 of 50[Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:    3.7s
#
# building tree 46 of 50[Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:    3.7s
#
# building tree 47 of 50[Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:    3.9s
#
# building tree 48 of 50[Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:    3.9s
#
# building tree 49 of 50[Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:    4.1s
#
# building tree 50 of 50[Parallel(n_jobs=-1)]: Done  48 out of  50 | elapsed:    4.1s remaining:    0.2s
#
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    4.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    4.2s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  19 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  22 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  23 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  27 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  29 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  31 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  32 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  33 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  38 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  39 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  40 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  41 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  43 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  45 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  47 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  48 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  19 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  22 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  23 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  27 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  29 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  30 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  31 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  32 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  33 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  35 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  36 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  38 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  39 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  40 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  41 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  43 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  45 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  47 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  48 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  19 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  22 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  23 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  27 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  29 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  31 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  32 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  33 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  36 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  38 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  39 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  40 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  41 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  43 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  45 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  47 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  48 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  19 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  22 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  23 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  27 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  29 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  31 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  32 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  33 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  38 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  39 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  40 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  41 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  43 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  45 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  47 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  48 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s finished
# rf ok
# nb ok
# mlp ok
# extra ok
# knn ok
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 300, 300)          3750000
#
#  dropout_8 (Dropout)         (None, 300, 300)          0
#
#  conv1d_4 (Conv1D)           (None, 299, 64)           38464
#
#  global_max_pooling1d_4 (Glo  (None, 64)               0
#  balMaxPooling1D)
#
#  dense_8 (Dense)             (None, 256)               16640
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  activation_8 (Activation)   (None, 256)               0
#
#  dense_9 (Dense)             (None, 2)                 514
#
#  activation_9 (Activation)   (None, 2)                 0
#
# =================================================================
# Total params: 3,805,618
# Trainable params: 55,618
# Non-trainable params: 3,750,000
# _________________________________________________________________
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 300, 300)          3750000
#
#  dropout_10 (Dropout)        (None, 300, 300)          0
#
#  conv1d_5 (Conv1D)           (None, 299, 64)           38464
#
#  global_max_pooling1d_5 (Glo  (None, 64)               0
#  balMaxPooling1D)
#
#  dense_10 (Dense)            (None, 256)               16640
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  activation_10 (Activation)  (None, 256)               0
#
#  dense_11 (Dense)            (None, 2)                 514
#
#  activation_11 (Activation)  (None, 2)                 0
#
# =================================================================
# Total params: 3,805,618
# Trainable params: 55,618
# Non-trainable params: 3,750,000
# _________________________________________________________________
# Epoch 1/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6770 - accuracy: 0.5921 - val_loss: 0.6756 - val_accuracy: 0.5935
# Epoch 2/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6764 - accuracy: 0.5928 - val_loss: 0.6758 - val_accuracy: 0.5935
# Epoch 3/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6760 - accuracy: 0.5928 - val_loss: 0.6752 - val_accuracy: 0.5935
# Epoch 4/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6751 - accuracy: 0.5928 - val_loss: 0.6759 - val_accuracy: 0.5935
# Epoch 5/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6738 - accuracy: 0.5928 - val_loss: 0.6769 - val_accuracy: 0.5935
# Epoch 6/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6718 - accuracy: 0.5928 - val_loss: 0.6790 - val_accuracy: 0.5935
# Epoch 7/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6699 - accuracy: 0.5925 - val_loss: 0.6777 - val_accuracy: 0.5935
# Epoch 8/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6685 - accuracy: 0.5924 - val_loss: 0.6788 - val_accuracy: 0.5935
# Epoch 9/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6653 - accuracy: 0.5922 - val_loss: 0.6791 - val_accuracy: 0.5927
# Epoch 10/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6641 - accuracy: 0.5915 - val_loss: 0.6825 - val_accuracy: 0.5794
# Epoch 11/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6619 - accuracy: 0.5945 - val_loss: 0.6790 - val_accuracy: 0.5864
# Epoch 12/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6618 - accuracy: 0.5930 - val_loss: 0.6808 - val_accuracy: 0.5693
# Epoch 13/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6586 - accuracy: 0.5993 - val_loss: 0.6896 - val_accuracy: 0.5171
# Epoch 14/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6582 - accuracy: 0.6008 - val_loss: 0.6936 - val_accuracy: 0.5903
# Epoch 15/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6589 - accuracy: 0.5979 - val_loss: 0.6829 - val_accuracy: 0.5755
# Epoch 16/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6549 - accuracy: 0.6015 - val_loss: 0.6900 - val_accuracy: 0.5888
# Epoch 17/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6542 - accuracy: 0.6023 - val_loss: 0.6861 - val_accuracy: 0.5483
# Epoch 18/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6521 - accuracy: 0.6049 - val_loss: 0.7004 - val_accuracy: 0.5849
# Epoch 19/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6518 - accuracy: 0.6003 - val_loss: 0.6924 - val_accuracy: 0.5833
# Epoch 20/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6493 - accuracy: 0.6092 - val_loss: 0.6948 - val_accuracy: 0.5771
# Epoch 1/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6771 - accuracy: 0.5924 - val_loss: 0.6755 - val_accuracy: 0.5935
# Epoch 2/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6763 - accuracy: 0.5928 - val_loss: 0.6777 - val_accuracy: 0.5935
# Epoch 3/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6760 - accuracy: 0.5928 - val_loss: 0.6753 - val_accuracy: 0.5935
# Epoch 4/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6752 - accuracy: 0.5928 - val_loss: 0.6749 - val_accuracy: 0.5935
# Epoch 5/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6732 - accuracy: 0.5928 - val_loss: 0.6824 - val_accuracy: 0.5935
# Epoch 6/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6723 - accuracy: 0.5928 - val_loss: 0.6765 - val_accuracy: 0.5935
# Epoch 7/20
# 514/514 [==============================] - 27s 52ms/step - loss: 0.6698 - accuracy: 0.5928 - val_loss: 0.6755 - val_accuracy: 0.5935
# Epoch 8/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6682 - accuracy: 0.5941 - val_loss: 0.6762 - val_accuracy: 0.5935
# Epoch 9/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6661 - accuracy: 0.5932 - val_loss: 0.6816 - val_accuracy: 0.5935
# Epoch 10/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6650 - accuracy: 0.5944 - val_loss: 0.6800 - val_accuracy: 0.5935
# Epoch 11/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6633 - accuracy: 0.5950 - val_loss: 0.6810 - val_accuracy: 0.5732
# Epoch 12/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6608 - accuracy: 0.5942 - val_loss: 0.6865 - val_accuracy: 0.5966
# Epoch 13/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6611 - accuracy: 0.5920 - val_loss: 0.6838 - val_accuracy: 0.5592
# Epoch 14/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6597 - accuracy: 0.5969 - val_loss: 0.6906 - val_accuracy: 0.5156
# Epoch 15/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6575 - accuracy: 0.5981 - val_loss: 0.6881 - val_accuracy: 0.5779
# Epoch 16/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6555 - accuracy: 0.6012 - val_loss: 0.6913 - val_accuracy: 0.5646
# Epoch 17/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6537 - accuracy: 0.6004 - val_loss: 0.6954 - val_accuracy: 0.4829
# Epoch 18/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6523 - accuracy: 0.6046 - val_loss: 0.6975 - val_accuracy: 0.4751
# Epoch 19/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6527 - accuracy: 0.5999 - val_loss: 0.6970 - val_accuracy: 0.5849
# Epoch 20/20
# 514/514 [==============================] - 27s 53ms/step - loss: 0.6497 - accuracy: 0.6033 - val_loss: 0.6927 - val_accuracy: 0.5249
# cnn ok
# CPU times: user 46min 22s, sys: 14min 30s, total: 1h 53s
# Wall time: 36min 19s

# %% [markdown]
# #### Caso 1 (c) - 2 - Sentimental

# %%
# %%time 

del train
del test
del val
#data
train=pd.DataFrame(dataset['train'])
test=pd.DataFrame(dataset['test'])
val=pd.DataFrame(dataset['validation'])

Original_labels={5:0, 4:0, 3:1, 1:0,2:1,0:0}

train['label'] = train['label'].map(Original_labels)
test['label'] = test['label'].map(Original_labels)
val['label'] = val['label'].map(Original_labels)

# load data
train.to_csv('/content/Data/liar/train_3_c.csv')
test.to_csv('/content/Data/liar/test_3_c.csv')
val.to_csv('/content/Data/liar/val_1_c.csv')
y_train.to_csv('/content/Data/liar/train_labels_3_c.csv')
y_test.to_csv('/content/Data/liar/test_labels_3_c.csv')
y_val.to_csv('/content/Data/liar/val_labels_3_c.csv')

train_3_c=train
test_3_c=test 
val_3_c=val
# Out:
# CPU times: user 3.97 s, sys: 34 ms, total: 4 s
# Wall time: 4.68 s

# %%
# %%time
def main():
  for db in ["liar"]:
    if db == 'liar':
      classe = 'label'
      df_pred_val = pd.DataFrame()
      df_pred_test = pd.DataFrame()
      df_prob_val = pd.DataFrame()# inicializando proba
      df_prob_test = pd.DataFrame()
      
      df_pred_val = pd.concat([df_pred_val, val_3_c['label']], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, test_3_c['label']], axis=1, sort=False)
      df_prob_val = pd.concat([df_prob_val, val_3_c['label']], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, test_3_c['label']], axis=1, sort=False)
      print('dados ok')

      # SVM
      classifier = get_svm(cv, tfidf)
      clfs = { }
      for ext, clf in classifier.items():
        clfs[ext] = get_classifier(clf['CLF'], X_train_c, y_train_c, clf['EXT'])
      pred_val, pred_test, prob_val, prob_test = update_pred_proba_2(clfs, "SVM", X_train_c, X_val_c, X_test_c)

      print('svm parte 1 ok')
      
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('svm parte 2 ok')

      # LR
      classifier = get_lr(cv,tfidf)
      clfs = { }
      for ext, clf in classifier.items():
        clfs[ext] = get_classifier(clf['CLF'],X_train_c, y_train_c, clf['EXT'])

      pred_val, pred_test, prob_val, prob_test = update_pred_proba_2(clfs, "LR", X_train_c, X_val_c, X_test_c)
      
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('lr ok')

      # RF
      classifier = get_rf(cv, tfidf)
      # clfs = { }
      for ext, clf in classifier.items():
          clfs.update({ext: get_classifier(clf['CLF'], X_train_c, y_train_c, clf['EXT'])})
      pred_val, pred_test, prob_val, prob_test = update_pred_proba_2(clfs, "RF", X_train_c, X_val_c, X_test_c)
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('rf ok')

      # NB
      classifier = get_nb(cv, tfidf)
      # clfs = { }
      for ext, clf in classifier.items():
          clfs.update({ext: get_classifier(clf['CLF'], X_train_c, y_train_c, clf['EXT'])})
      pred_val, pred_test, prob_val, prob_test = update_pred_proba_2(clfs, "NB", X_train_c, X_val_c, X_test_c)
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('nb ok')

      # MLP
      classifier = get_mlp(cv, tfidf)
      # clfs = { }
      for ext, clf in classifier.items():
          clfs.update({ext: get_classifier(clf['CLF'],X_train_c, y_train_c, clf['EXT'])})
          
      pred_val, pred_test, prob_train, prob_test = update_pred_proba_2(clfs, "MLP", X_train_c, X_val_c, X_test_c)
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('mlp ok')

      # Extra
      classifier = get_extra(cv, tfidf)
      # clfs = { }
      for ext, clf in classifier.items():
          clfs.update({ext: get_classifier(clf['CLF'],X_train_c, y_train_c, clf['EXT'])})
          
      pred_val, pred_test, prob_val, prob_test = update_pred_proba_2(clfs, "EXTRA", X_train_c, X_val_c, X_test_c)
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('extra ok')

      # KNN
      classifier = get_knn(cv, tfidf)
      # clfs = { }
      for ext, clf in classifier.items():
          clfs.update({ext: get_classifier(clf['CLF'],X_train_c, y_train_c, clf['EXT'])})
          
      pred_val, pred_test, prob_val, prob_test = update_pred_proba_2(clfs, "KNN", X_train_c, X_val_c, X_test_c)
      # Concatenando pred
      df_pred_val = pd.concat([df_pred_val, pred_val], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, pred_test], axis=1, sort=False)
      # Concatenando prob
      df_prob_val = pd.concat([df_prob_val, prob_val], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, prob_test], axis=1, sort=False)
      print('knn ok')

      #CNN
      MAX_NB_WORDS = 20000
      MAX_SEQUENCE_LENGTH=300
      tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
      tokenizer.fit_on_texts(X_train_c) #rever por que 
      seq_train = tokenizer.texts_to_sequences(X_train_c)
      seq_val = tokenizer.texts_to_sequences(X_val_c)
      seq_test = tokenizer.texts_to_sequences(X_test_c)

      data_train = pad_sequences(seq_train,padding='pre', truncating='pre',maxlen=MAX_SEQUENCE_LENGTH)
      data_val = pad_sequences(seq_val,padding='pre', truncating='pre',maxlen=MAX_SEQUENCE_LENGTH)
      data_test = pad_sequences(seq_test, padding='pre', truncating='pre',maxlen=MAX_SEQUENCE_LENGTH)
                            
      # NET
      cnn_cv = get_CNN_2(cv, tokenizer, MAX_NB_WORDS, EMBEDDING_DIM=300, activation='sigmoid', dense=2)
      cnn_tfidf = get_CNN_2(tfidf, tokenizer, MAX_NB_WORDS, EMBEDDING_DIM=300, activation='sigmoid', dense=2)
      
      y_validation=to_categorical(y_val_c)
      y_training=to_categorical(y_train_c)
      y_testing=to_categorical(y_test_c)
      
      # TRAIN
      cnn_cv.fit(data_train, y_training, validation_data=(data_val,y_validation), epochs=20, batch_size=20)
      cnn_tfidf.fit(data_train, y_training, validation_data=(data_val,y_validation), epochs=20, batch_size=20)
     
      #predictions and proba
      cols = ["CNN-CV-0", "CNN-CV-1"]
      df_val_ = pd.DataFrame(np.argmax(cnn_cv.predict(data_val), axis=1), columns=["CNN-CV"])
      df_test_ = pd.DataFrame(np.argmax(cnn_cv.predict(data_test), axis=1), columns=["CNN-CV"])
      df_pred_val = pd.concat([df_pred_val, df_val_], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, df_test_], axis=1, sort=False)
      # Probabilidades
      df_val_ = pd.DataFrame(cnn_cv.predict(data_val), columns=cols)
      df_test_ = pd.DataFrame(cnn_cv.predict(data_test), columns=cols)
      df_prob_val = pd.concat([df_prob_val, df_val_], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, df_test_], axis=1, sort=False)
      
      cols = ["CNN-TF-0", "CNN-TF-1"]
      df_val_ = pd.DataFrame(np.argmax(cnn_tfidf.predict(data_val), axis=1), columns=["CNN-TFIDF"])
      df_test_ = pd.DataFrame(np.argmax(cnn_tfidf.predict(data_test), axis=1), columns=["CNN-TFIDF"])
      df_pred_val = pd.concat([df_pred_val, df_val_], axis=1, sort=False)
      df_pred_test = pd.concat([df_pred_test, df_test_], axis=1, sort=False)
      # Probabilidades
      df_val_ = pd.DataFrame(cnn_tfidf.predict(data_val), columns=cols)
      df_test_ = pd.DataFrame(cnn_tfidf.predict(data_test), columns=cols)
      df_prob_val = pd.concat([df_prob_val, df_val_], axis=1, sort=False)
      df_prob_test = pd.concat([df_prob_test, df_test_], axis=1, sort=False)

      print('cnn ok')     

      # Probabilidade
      path = "./Data/{}".format(db)
      df_pred_val.to_csv("{}/pred_val_3_c.csv".format(path))
      df_pred_test.to_csv("{}/pred_test_3_c.csv".format(path))
      df_prob_val.to_csv("{}/prob_val_3_c.csv".format(path))
      df_prob_test.to_csv("{}/prob_test_3_c.csv".format(path))
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 10.5 µs

# %%
# %%time 
if __name__ == "__main__":
    main()
# Out:
# dados ok
# svm parte 1 ok
# svm parte 2 ok
# lr ok
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 20building tree 2 of 20
#
# building tree 3 of 20[Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.2s
#
# building tree 4 of 20[Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.2s
#
# building tree 5 of 20[Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.3s
#
# building tree 6 of 20
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.3s
# building tree 7 of 20[Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.5s
#
# building tree 8 of 20[Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    0.5s
#
# building tree 9 of 20[Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    0.7s
#
# building tree 10 of 20[Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.7s
#
# building tree 11 of 20[Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    0.8s
#
# building tree 12 of 20[Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    0.8s
#
# building tree 13 of 20[Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    1.0s
#
# building tree 14 of 20[Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    1.0s
#
# building tree 15 of 20[Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    1.2s
# building tree 16 of 20
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    1.2s
#
# building tree 17 of 20[Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    1.3s
# building tree 18 of 20
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    1.3s
#
# building tree 19 of 20[Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    1.5s
#
# building tree 20 of 20[Parallel(n_jobs=-1)]: Done  18 out of  20 | elapsed:    1.5s remaining:    0.2s
#
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    1.7s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 50
# building tree 2 of 50
# building tree 3 of 50[Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.2s
#
# building tree 4 of 50[Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.2s
#
# building tree 5 of 50[Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.3s
#
# building tree 6 of 50
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.3s
# building tree 7 of 50[Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.5s
#
# building tree 8 of 50[Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    0.5s
#
# building tree 9 of 50[Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    0.6s
#
# building tree 10 of 50[Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.6s
#
# building tree 11 of 50[Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    0.8s
#
# building tree 12 of 50[Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    0.8s
#
# building tree 13 of 50[Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    0.9s
#
# building tree 14 of 50[Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    0.9s
#
# building tree 15 of 50[Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    1.1s
#
# building tree 16 of 50[Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    1.1s
#
# building tree 17 of 50[Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    1.2s
#
# building tree 18 of 50[Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    1.2s
#
# building tree 19 of 50[Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    1.4s
#
# building tree 20 of 50[Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    1.4s
#
# building tree 21 of 50[Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:    1.5s
#
# building tree 22 of 50[Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:    1.5s
#
# building tree 23 of 50[Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    1.7s
#
# building tree 24 of 50[Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:    1.7s
#
# building tree 25 of 50[Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:    1.8s
#
# building tree 26 of 50[Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    1.8s
#
# building tree 27 of 50[Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    2.0s
#
# building tree 28 of 50[Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    2.0s
#
# building tree 29 of 50[Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    2.1s
#
# building tree 30 of 50[Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    2.1s
#
# building tree 31 of 50[Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:    2.3s
#
# building tree 32 of 50[Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    2.3s
#
# building tree 33 of 50[Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:    2.4s
#
# building tree 34 of 50[Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    2.4s
#
# building tree 35 of 50[Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    2.6s
# building tree 36 of 50
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.6s
#
# building tree 37 of 50[Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:    2.7s
#
# building tree 38 of 50[Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:    2.8s
#
# building tree 39 of 50[Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    2.9s
#
# building tree 40 of 50[Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:    2.9s
#
# building tree 41 of 50[Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:    3.0s
#
# building tree 42 of 50[Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    3.1s
#
# building tree 43 of 50[Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:    3.2s
#
# building tree 44 of 50[Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    3.2s
#
# building tree 45 of 50[Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:    3.3s
#
# building tree 46 of 50[Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:    3.4s
#
# building tree 47 of 50[Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:    3.5s
#
# building tree 48 of 50[Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:    3.5s
#
# building tree 49 of 50[Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:    3.7s
#
# building tree 50 of 50[Parallel(n_jobs=-1)]: Done  48 out of  50 | elapsed:    3.7s remaining:    0.2s
#
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    3.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    3.8s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  19 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  22 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  23 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  27 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  29 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  31 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  32 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  33 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  38 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  39 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  40 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  41 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  43 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  45 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  47 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  48 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  19 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  22 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  23 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  27 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  29 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  31 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  32 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  33 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  35 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  36 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  38 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  39 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  40 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  41 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  43 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  45 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  47 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  48 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  19 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  22 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  23 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  27 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  29 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  31 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  32 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  33 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  38 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  39 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  40 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  41 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  43 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  45 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  47 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  48 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  19 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  22 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  23 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  27 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  29 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  31 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  32 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  33 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  38 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done  39 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  40 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  41 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  43 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  45 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  47 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done  48 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.1s finished
# rf ok
# nb ok
# mlp ok
# extra ok
# knn ok
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 300, 300)          3750000
#
#  dropout_12 (Dropout)        (None, 300, 300)          0
#
#  conv1d_6 (Conv1D)           (None, 299, 64)           38464
#
#  global_max_pooling1d_6 (Glo  (None, 64)               0
#  balMaxPooling1D)
#
#  dense_12 (Dense)            (None, 256)               16640
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  activation_12 (Activation)  (None, 256)               0
#
#  dense_13 (Dense)            (None, 2)                 514
#
#  activation_13 (Activation)  (None, 2)                 0
#
# =================================================================
# Total params: 3,805,618
# Trainable params: 55,618
# Non-trainable params: 3,750,000
# _________________________________________________________________
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 300, 300)          3750000
#
#  dropout_14 (Dropout)        (None, 300, 300)          0
#
#  conv1d_7 (Conv1D)           (None, 299, 64)           38464
#
#  global_max_pooling1d_7 (Glo  (None, 64)               0
#  balMaxPooling1D)
#
#  dense_14 (Dense)            (None, 256)               16640
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  activation_14 (Activation)  (None, 256)               0
#
#  dense_15 (Dense)            (None, 2)                 514
#
#  activation_15 (Activation)  (None, 2)                 0
#
# =================================================================
# Total params: 3,805,618
# Trainable params: 55,618
# Non-trainable params: 3,750,000
# _________________________________________________________________
# Epoch 1/20
# 514/514 [==============================] - 29s 54ms/step - loss: 0.6514 - accuracy: 0.6448 - val_loss: 0.6373 - val_accuracy: 0.6729
# Epoch 2/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6491 - accuracy: 0.6447 - val_loss: 0.6254 - val_accuracy: 0.6729
# Epoch 3/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6462 - accuracy: 0.6447 - val_loss: 0.6220 - val_accuracy: 0.6729
# Epoch 4/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6422 - accuracy: 0.6446 - val_loss: 0.6151 - val_accuracy: 0.6729
# Epoch 5/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6383 - accuracy: 0.6448 - val_loss: 0.6306 - val_accuracy: 0.6752
# Epoch 6/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6347 - accuracy: 0.6473 - val_loss: 0.6133 - val_accuracy: 0.6737
# Epoch 7/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6332 - accuracy: 0.6482 - val_loss: 0.6226 - val_accuracy: 0.6729
# Epoch 8/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6288 - accuracy: 0.6490 - val_loss: 0.6131 - val_accuracy: 0.6799
# Epoch 9/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6241 - accuracy: 0.6549 - val_loss: 0.6221 - val_accuracy: 0.6745
# Epoch 10/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6218 - accuracy: 0.6551 - val_loss: 0.6110 - val_accuracy: 0.6729
# Epoch 11/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6177 - accuracy: 0.6583 - val_loss: 0.6165 - val_accuracy: 0.6713
# Epoch 12/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6127 - accuracy: 0.6650 - val_loss: 0.6243 - val_accuracy: 0.6643
# Epoch 13/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6102 - accuracy: 0.6685 - val_loss: 0.6496 - val_accuracy: 0.6028
# Epoch 14/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6072 - accuracy: 0.6672 - val_loss: 0.6484 - val_accuracy: 0.6776
# Epoch 15/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.6047 - accuracy: 0.6731 - val_loss: 0.6158 - val_accuracy: 0.6776
# Epoch 16/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.5987 - accuracy: 0.6770 - val_loss: 0.6392 - val_accuracy: 0.6308
# Epoch 17/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.5979 - accuracy: 0.6807 - val_loss: 0.6156 - val_accuracy: 0.6752
# Epoch 18/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.5955 - accuracy: 0.6769 - val_loss: 0.6138 - val_accuracy: 0.6791
# Epoch 19/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.5939 - accuracy: 0.6812 - val_loss: 0.6388 - val_accuracy: 0.6355
# Epoch 20/20
# 514/514 [==============================] - 28s 54ms/step - loss: 0.5910 - accuracy: 0.6879 - val_loss: 0.6156 - val_accuracy: 0.6799
# Epoch 1/20
# 514/514 [==============================] - 28s 52ms/step - loss: 0.6521 - accuracy: 0.6435 - val_loss: 0.6310 - val_accuracy: 0.6729
# Epoch 2/20
# 514/514 [==============================] - 27s 52ms/step - loss: 0.6496 - accuracy: 0.6447 - val_loss: 0.6281 - val_accuracy: 0.6729
# Epoch 3/20
# 514/514 [==============================] - 26s 52ms/step - loss: 0.6468 - accuracy: 0.6447 - val_loss: 0.6229 - val_accuracy: 0.6729
# Epoch 4/20
# 514/514 [==============================] - 26s 51ms/step - loss: 0.6428 - accuracy: 0.6447 - val_loss: 0.6228 - val_accuracy: 0.6729
# Epoch 5/20
# 514/514 [==============================] - 26s 51ms/step - loss: 0.6387 - accuracy: 0.6450 - val_loss: 0.6125 - val_accuracy: 0.6729
# Epoch 6/20
# 514/514 [==============================] - 27s 52ms/step - loss: 0.6352 - accuracy: 0.6466 - val_loss: 0.6172 - val_accuracy: 0.6737
# Epoch 7/20
# 514/514 [==============================] - 27s 52ms/step - loss: 0.6313 - accuracy: 0.6493 - val_loss: 0.6105 - val_accuracy: 0.6729
# Epoch 8/20
# 514/514 [==============================] - 26s 51ms/step - loss: 0.6266 - accuracy: 0.6505 - val_loss: 0.6078 - val_accuracy: 0.6752
# Epoch 9/20
# 514/514 [==============================] - 27s 52ms/step - loss: 0.6234 - accuracy: 0.6525 - val_loss: 0.6357 - val_accuracy: 0.6441
# Epoch 10/20
# 514/514 [==============================] - 26s 51ms/step - loss: 0.6177 - accuracy: 0.6593 - val_loss: 0.6123 - val_accuracy: 0.6807
# Epoch 11/20
# 514/514 [==============================] - 26s 51ms/step - loss: 0.6137 - accuracy: 0.6632 - val_loss: 0.6400 - val_accuracy: 0.6316
# Epoch 12/20
# 514/514 [==============================] - 27s 52ms/step - loss: 0.6095 - accuracy: 0.6644 - val_loss: 0.6289 - val_accuracy: 0.6433
# Epoch 13/20
# 514/514 [==============================] - 26s 51ms/step - loss: 0.6056 - accuracy: 0.6713 - val_loss: 0.6103 - val_accuracy: 0.6698
# Epoch 14/20
# 514/514 [==============================] - 26s 52ms/step - loss: 0.6003 - accuracy: 0.6762 - val_loss: 0.6574 - val_accuracy: 0.6768
# Epoch 15/20
# 514/514 [==============================] - 27s 52ms/step - loss: 0.5985 - accuracy: 0.6774 - val_loss: 0.6624 - val_accuracy: 0.5849
# Epoch 16/20
# 514/514 [==============================] - 26s 52ms/step - loss: 0.5922 - accuracy: 0.6770 - val_loss: 0.6914 - val_accuracy: 0.5296
# Epoch 17/20
# 514/514 [==============================] - 26s 51ms/step - loss: 0.5900 - accuracy: 0.6838 - val_loss: 0.6431 - val_accuracy: 0.6153
# Epoch 18/20
# 514/514 [==============================] - 26s 51ms/step - loss: 0.5859 - accuracy: 0.6908 - val_loss: 0.6267 - val_accuracy: 0.6737
# Epoch 19/20
# 514/514 [==============================] - 27s 52ms/step - loss: 0.5851 - accuracy: 0.6878 - val_loss: 0.6203 - val_accuracy: 0.6768
# Epoch 20/20
# 514/514 [==============================] - 26s 51ms/step - loss: 0.5807 - accuracy: 0.6907 - val_loss: 0.6246 - val_accuracy: 0.6799
# cnn ok
# CPU times: user 44min 47s, sys: 7min 33s, total: 52min 20s
# Wall time: 31min 48s
