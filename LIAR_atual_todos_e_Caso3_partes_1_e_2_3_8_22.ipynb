# %% [markdown]
# <a href="https://colab.research.google.com/github/SaraBCoutinho/Pesquisa_Analysis/blob/main/LIAR_atual_todos_e_Caso3_partes_1_e_2_3_8_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Arquivos

# %%
# %%capture
# !mkdir Data
# !mkdir Data/liar
# !mkdir Data/liar/Caso1
# !mkdir Data/liar/Caso2
# !mkdir Data/liar/Caso3
# !mkdir Data/liar/Caso3/union

# %%
# !mkdir Data/liar/Caso3/cv_tfidf
# !mkdir Data/liar/Caso3/word_embeddings

# %%
# Upload directly files Casos 1, 2 , 3 (création du dossier cv_tfidf et word_embeddings and upload respectively files to each one)

# %%
import pandas as pd
#LIAR CASO 3 - 1
pred_test_3_a_1=pd.read_csv('/content/Data/liar/Caso3/cv_tfidf/pred_test_3_a.csv')
pred_val_3_a_1=pd.read_csv('/content/Data/liar/Caso3/cv_tfidf/pred_val_3_a.csv')
prob_test_3_a_1=pd.read_csv('/content/Data/liar/Caso3/cv_tfidf/prob_test_3_a.csv')
prob_val_3_a_1=pd.read_csv('/content/Data/liar/Caso3/cv_tfidf/prob_val_3_a.csv')

pred_test_3_b_1=pd.read_csv('/content/Data/liar/Caso3/cv_tfidf/pred_test_3_b.csv')
pred_val_3_b_1=pd.read_csv('/content/Data/liar/Caso3/cv_tfidf/pred_val_3_b.csv')
prob_test_3_b_1=pd.read_csv('/content/Data/liar/Caso3/cv_tfidf/prob_test_3_b.csv')
prob_val_3_b_1=pd.read_csv('/content/Data/liar/Caso3/cv_tfidf/prob_val_3_b.csv')

pred_test_3_c_1=pd.read_csv('/content/Data/liar/Caso3/cv_tfidf/pred_test_3_c.csv')
pred_val_3_c_1=pd.read_csv('/content/Data/liar/Caso3/cv_tfidf/pred_val_3_c.csv')
prob_test_3_c_1=pd.read_csv('/content/Data/liar/Caso3/cv_tfidf/prob_test_3_c.csv')
prob_val_3_c_1=pd.read_csv('/content/Data/liar/Caso3/cv_tfidf/prob_val_3_c.csv')

#LIAR CASO 3 - 2

pred_test_3_a_2=pd.read_csv('/content/Data/liar/Caso3/word_embeddings/pred_test_3_a.csv')
pred_test_3_a_2=pred_test_3_a_2.drop(columns=['Unnamed: 0','label'])
pred_val_3_a_2=pd.read_csv('/content/Data/liar/Caso3/word_embeddings/pred_val_3_a.csv')
pred_val_3_a_2=pred_val_3_a_2.drop(columns=['Unnamed: 0','label'])
prob_test_3_a_2=pd.read_csv('/content/Data/liar/Caso3/word_embeddings/prob_test_3_a.csv')
prob_test_3_a_2=prob_test_3_a_2.drop(columns=['Unnamed: 0','label'])
prob_val_3_a_2=pd.read_csv('/content/Data/liar/Caso3/word_embeddings/prob_val_3_a.csv')
prob_val_3_a_2=prob_val_3_a_2.drop(columns=['Unnamed: 0','label'])

pred_test_3_b_2=pd.read_csv('/content/Data/liar/Caso3/word_embeddings/pred_test_3_b.csv')
pred_test_3_b_2=pred_test_3_b_2.drop(columns=['Unnamed: 0','label'])
pred_val_3_b_2=pd.read_csv('/content/Data/liar/Caso3/word_embeddings/pred_val_3_b.csv')
pred_val_3_b_2=pred_val_3_b_2.drop(columns=['Unnamed: 0','label'])
prob_test_3_b_2=pd.read_csv('/content/Data/liar/Caso3/word_embeddings/prob_test_3_b.csv')
prob_test_3_b_2=prob_test_3_b_2.drop(columns=['Unnamed: 0','label'])
prob_val_3_b_2=pd.read_csv('/content/Data/liar/Caso3/word_embeddings/prob_val_3_b.csv')
prob_val_3_b_2=prob_val_3_b_2.drop(columns=['Unnamed: 0','label'])

pred_test_3_c_2=pd.read_csv('/content/Data/liar/Caso3/word_embeddings/pred_test_3_c.csv')
pred_test_3_c_2=pred_test_3_c_2.drop(columns=['Unnamed: 0','label'])
pred_val_3_c_2=pd.read_csv('/content/Data/liar/Caso3/word_embeddings/pred_val_3_c.csv')
pred_val_3_c_2=pred_val_3_c_2.drop(columns=['Unnamed: 0','label'])
prob_test_3_c_2=pd.read_csv('/content/Data/liar/Caso3/word_embeddings/prob_test_3_c.csv')
prob_test_3_c_2=prob_test_3_c_2.drop(columns=['Unnamed: 0','label'])
prob_val_3_c_2=pd.read_csv('/content/Data/liar/Caso3/word_embeddings/prob_val_3_c.csv')
prob_val_3_c_2=prob_val_3_c_2.drop(columns=['Unnamed: 0','label'])

# %%
#print(pd.read_csv('/content/Data/liar/Caso2/pred_val_2_a.csv').columns)
#print(pred_val_3_a.columns)

# %%
column_names=['Unnamed: 0', 'label', 'SVM-CV', 'SVM-TFIDF', 'SVM-W2V', 'SVM-GLOVE',
       'SVM-FAST', 'LR-CV', 'LR-TFIDF', 'LR-GLOVE', 'LR-W2V', 'LR-FAST',
       'RF-CV', 'RF-TFIDF', 'RF-GLOVE', 'RF-W2V', 'RF-FAST', 'NB-CV',
       'NB-TFIDF', 'NB-GLOVE', 'NB-W2V', 'NB-FAST', 'MLP-CV', 'MLP-TFIDF',
       'MLP-GLOVE', 'MLP-W2V', 'MLP-FAST', 'EXTRA-CV', 'EXTRA-TFIDF',
       'EXTRA-GLOVE', 'EXTRA-W2V', 'EXTRA-FAST', 'KNN-CV', 'KNN-TFIDF',
       'KNN-GLOVE', 'KNN-W2V', 'KNN-FAST', 'CNN-CV', 'CNN-TFIDF', 'CNN-W2V',
       'CNN-GLOVE', 'CNN-FAST']

# %%
column_names_prob=pd.DataFrame(pd.read_csv('/content/Data/liar/Caso2/prob_test_2_a.csv')).columns

# %%
pred_test_3_a=pd.concat([pred_test_3_a_1,pred_test_3_a_2],axis=1)
pred_test_3_a = pred_test_3_a.reindex(columns=column_names)
pred_val_3_a=pd.concat([pred_val_3_a_1,pred_val_3_a_2],axis=1)
pred_val_3_a = pred_val_3_a.reindex(columns=column_names)
prob_test_3_a=pd.concat([prob_test_3_a_1,prob_test_3_a_2],axis=1)
prob_test_3_a = prob_test_3_a.reindex(columns=column_names_prob)
prob_val_3_a=pd.concat([prob_val_3_a_1,prob_val_3_a_2],axis=1)
prob_val_3_a = prob_val_3_a.reindex(columns=column_names_prob)

pred_test_3_b=pd.concat([pred_test_3_b_1,pred_test_3_b_2],axis=1)
pred_test_3_b = pred_test_3_b.reindex(columns=column_names)
pred_val_3_b=pd.concat([pred_val_3_b_1,pred_val_3_b_2],axis=1)
pred_val_3_b = pred_val_3_b.reindex(columns=column_names)
prob_test_3_b=pd.concat([prob_test_3_b_1,prob_test_3_b_2],axis=1)
prob_test_3_b = prob_test_3_b.reindex(columns=column_names_prob)
prob_val_3_b=pd.concat([prob_val_3_b_1,prob_val_3_b_2],axis=1)
prob_val_3_b = prob_val_3_b.reindex(columns=column_names_prob)

pred_test_3_c=pd.concat([pred_test_3_c_1,pred_test_3_c_2],axis=1)
pred_test_3_c = pred_test_3_c.reindex(columns=column_names)
pred_val_3_c=pd.concat([pred_val_3_c_1,pred_val_3_c_2],axis=1)
pred_val_3_c = pred_val_3_c.reindex(columns=column_names)
prob_test_3_c=pd.concat([prob_test_3_c_1,prob_test_3_c_2],axis=1)
prob_test_3_c = prob_test_3_c.reindex(columns=column_names_prob)
prob_val_3_c=pd.concat([prob_val_3_c_1,prob_val_3_c_2],axis=1)
prob_val_3_c = prob_val_3_c.reindex(columns=column_names_prob)

# %%
#!rm /content/Data/liar/Caso3/union/pred_test_3_b

# %%
pd.DataFrame(prob_test_3_a).to_csv('/content/Data/liar/Caso3/union/prob_test_3_a.csv')

# %%
pd.DataFrame(pred_test_3_a).to_csv('/content/Data/liar/Caso3/union/pred_test_3_a.csv')
pd.DataFrame(pred_val_3_a).to_csv('/content/Data/liar/Caso3/union/pred_val_3_a.csv')
pd.DataFrame(prob_test_3_a).to_csv('/content/Data/liar/Caso3/union/prob_test_3_a.csv')
pd.DataFrame(prob_val_3_a).to_csv('/content/Data/liar/Caso3/union/prob_val_3_a.csv')

pd.DataFrame(pred_test_3_b).to_csv('/content/Data/liar/Caso3/union/pred_test_3_b.csv')
pd.DataFrame(pred_val_3_b).to_csv('/content/Data/liar/Caso3/union/pred_val_3_b.csv')
pd.DataFrame(prob_test_3_b).to_csv('/content/Data/liar/Caso3/union/prob_test_3_b.csv')
pd.DataFrame(prob_val_3_b).to_csv('/content/Data/liar/Caso3/union/prob_val_3_b.csv')

pd.DataFrame(pred_test_3_c).to_csv('/content/Data/liar/Caso3/union/pred_test_3_c.csv')
pd.DataFrame(pred_val_3_c).to_csv('/content/Data/liar/Caso3/union/pred_val_3_c.csv')
pd.DataFrame(prob_test_3_c).to_csv('/content/Data/liar/Caso3/union/prob_test_3_c.csv')
pd.DataFrame(prob_val_3_c).to_csv('/content/Data/liar/Caso3/union/prob_val_3_c.csv')

# %%
# %%capture 
#--Data
# !pip install datasets
from datasets import load_dataset

# %%
# %%capture 
#--Data
# !pip install datasets
from datasets import load_dataset

#dataset
dataset = load_dataset('liar')
#data
train=pd.DataFrame(dataset['train'])
test=pd.DataFrame(dataset['test'])
val=pd.DataFrame(dataset['validation'])

train_labels_1=pd.DataFrame(train['label'])
val_labels_1=pd.DataFrame(val['label'])
test_labels_1=pd.DataFrame(test['label'])

Original_labels={5:1, 4:1, 3:1, 1:0,2:0,0:0}
train_labels_2=pd.DataFrame(train['label'].map(Original_labels))
val_labels_2=pd.DataFrame(val['label'].map(Original_labels))
test_labels_2=pd.DataFrame(test['label'].map(Original_labels))

Original_labels={5:0, 4:0, 3:1, 1:0,2:1,0:0}
train_labels_3=pd.DataFrame(train['label'].map(Original_labels))
val_labels_3=pd.DataFrame(val['label'].map(Original_labels))
test_labels_3=pd.DataFrame(test['label'].map(Original_labels))

# %% [markdown]
# ## Diversity Analysis

# %%
# %%capture
# !pip install deslib
# !pip install umap
# !pip install umap-learn
import pandas as pd
import numpy as np
from sklearn.manifold import MDS, TSNE
from deslib.util.diversity import double_fault
import matplotlib.lines as mlines
# !pip install 'umap-learn==0.3.10'
from umap.umap_ import UMAP
from matplotlib import pyplot as plt

def compute_pairwise_diversity_matrix(targets, prediction_matrix, diversity_func):
    """Computes the pairwise diversity matrix.

     Parameters
     ----------
     targets : array of shape (n_samples):
        Class labels of each sample in X.

     prediction_matrix : array of shape (n_samples, n_classifiers):
        Predicted class labels for each classifier in the pool

     diversity_func : Function
        Function used to estimate the pairwise diversity

     Returns
     -------
     diversity : array of shape = [n_classifiers]
        The average pairwise diversity matrix calculated for the pool of
        classifiers

     """
    n_classifiers = prediction_matrix.shape[1]
    diversity = np.zeros((n_classifiers, n_classifiers))
    for clf_index in range(n_classifiers):
        for clf_index2 in range(clf_index + 1, n_classifiers):
            this_diversity = diversity_func(targets,
                                            prediction_matrix[:, clf_index],
                                            prediction_matrix[:, clf_index2])

            diversity[clf_index, clf_index2] = this_diversity
            diversity[clf_index2, clf_index] = this_diversity

    return diversity

def compute_matrix_embedding(dataset_name, n_classifiers, n_features, method='mds', n_neighbors=5, min_dist=0.7):
    D = compute_pairwise_diversity_matrix(label.to_numpy(), methods.to_numpy(), double_fault)
    D = 1/D
    D[D==np.inf] = 0
    if method == 'mds':
        method = MDS(dissimilarity='precomputed', random_state=123456987, n_init=20, max_iter=100000)
    elif method == 'tsne':
        method = TSNE(perplexity=25, init='pca', random_state=42, early_exaggeration=50, 
                      learning_rate=200, n_iter=2500, angle=0.5)
    else:        
        method = UMAP(n_neighbors=2, metric='euclidean', random_state=123456987, min_dist=0.7, n_components=2,)
    D_tilde = method.fit_transform(D)
    D_tilde = D_tilde.reshape(n_classifiers, n_features, 2)
    return D_tilde

# %% [markdown]
# ### Caso 1

# %% [markdown]
# ####a

# %% [markdown]
# ![umap_LIAR_dataset_1_a.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ####b

# %% [markdown]
# ![umap_LIAR_dataset_1_b.jpg](data:image/jpeg;base64,...)

# %%
#SVM-GLOVE,MLP-FAST, EXTRA-GLOVE, SVM-W2V,SVM-TFIDF,EXTRA-TFIDF, NB-TFIDF, NB-FAST, CNN-GLOVE, KNN-W2V

# %% [markdown]
# ####c

# %% [markdown]
# ![umap_LIAR_dataset_1_c.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Caso 2

# %% [markdown]
# ####a

# %%
def load_predictions_2_a(dataset_name):
    path = '/content/Data/liar/Caso2/pred_val_2_a.csv'
    table_pred = pd.read_csv(path)
    print(dataset_name)
    if dataset_name == 'liar':
        label = table_pred["label"]
        methods = table_pred.drop('label', axis=1)
    methods = methods.drop('Unnamed: 0', axis=1)
    return label, methods

def plot_diversity_1_a(D_changed, method_tmp, dataset_name, title):
    s = 100
    colors = {}
    colors[0] = '#DAA520'
    colors[1] = '#FF0000'
    colors[2] = '#0000FF'
    colors[3] = '#228B22'
    colors[4] = '#000000'
    markers = {}
    markers[0] = 'X'
    markers[1] = 'd'
    markers[2] = '*'
    markers[3] = "^"
    markers[4] = 'o'
    n_classifiers, n_features, _ = D_changed.shape
    plt.figure(figsize=(15,10))
    method=0
    for idx in range(n_classifiers):
        for idx2 in range(n_features):
            x, y = D_changed[idx,idx2, 0], D_changed[idx,idx2, 1]
            plt.scatter(x, y, color=colors[idx2], s=s, lw=0, marker=markers[idx2])
            plt.annotate(method_tmp[method], xy=(x, y), textcoords='offset points', xytext=(5, 15), ha='right', va='top')  
            method += 1
    
    m1 = mlines.Line2D([], [], color=colors[0], marker=markers[0], linestyle='None', markersize=10, label='CV')
    m2 = mlines.Line2D([], [], color=colors[1], marker=markers[1], linestyle='None', markersize=10, label='TFIDF')
    m3 = mlines.Line2D([], [], color=colors[2], marker=markers[2], linestyle='None', markersize=10, label='Glove')
    m4 = mlines.Line2D([], [], color=colors[3], marker=markers[3], linestyle='None', markersize=10, label='Word2Vec')
    m5 = mlines.Line2D([], [], color=colors[4], marker=markers[4], linestyle='None', markersize=10, label='FastText')
    plt.title('CPS ' + dataset_name.upper()+' dataset')
    plt.legend(handles=[m1, m2, m3, m4, m5])
    plt.tight_layout()
    plt.savefig(title + "_" + dataset_name.upper()+'_dataset_2_a.pdf', dpi=450)

n_classifiers = 8
method = 'umap'
n_features = 5
for dataset_name in ['liar']:
    
    label, methods = load_predictions_2_a(dataset_name)
    methods_name = [name.split('-', 1)[0] for name in methods.columns]
    D_tilde = compute_matrix_embedding(dataset_name, n_classifiers, n_features, method)
    plot_diversity_1_a(D_tilde, methods_name, dataset_name, method)
# Out:
# liar
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: RuntimeWarning: divide by zero encountered in true_divide
# /usr/local/lib/python3.7/dist-packages/umap/spectral.py:229: UserWarning: Embedding a total of 10 separate connected components using meta-embedding (experimental)
#   n_components

# %% [markdown]
# ####b

# %%
def load_predictions_2_a(dataset_name):
    path = '/content/Data/liar/Caso2/pred_val_2_b.csv'
    table_pred = pd.read_csv(path)
    print(dataset_name)
    if dataset_name == 'liar':
        label = table_pred["label"]
        methods = table_pred.drop('label', axis=1)
    methods = methods.drop('Unnamed: 0', axis=1)
    return label, methods

def plot_diversity_1_a(D_changed, method_tmp, dataset_name, title):
    s = 100
    colors = {}
    colors[0] = '#DAA520'
    colors[1] = '#FF0000'
    colors[2] = '#0000FF'
    colors[3] = '#228B22'
    colors[4] = '#000000'
    markers = {}
    markers[0] = 'X'
    markers[1] = 'd'
    markers[2] = '*'
    markers[3] = "^"
    markers[4] = 'o'
    n_classifiers, n_features, _ = D_changed.shape
    plt.figure(figsize=(15,10))
    method=0
    for idx in range(n_classifiers):
        for idx2 in range(n_features):
            x, y = D_changed[idx,idx2, 0], D_changed[idx,idx2, 1]
            plt.scatter(x, y, color=colors[idx2], s=s, lw=0, marker=markers[idx2])
            plt.annotate(method_tmp[method], xy=(x, y), textcoords='offset points', xytext=(5, 15), ha='right', va='top')  
            method += 1
    
    m1 = mlines.Line2D([], [], color=colors[0], marker=markers[0], linestyle='None', markersize=10, label='CV')
    m2 = mlines.Line2D([], [], color=colors[1], marker=markers[1], linestyle='None', markersize=10, label='TFIDF')
    m3 = mlines.Line2D([], [], color=colors[2], marker=markers[2], linestyle='None', markersize=10, label='Glove')
    m4 = mlines.Line2D([], [], color=colors[3], marker=markers[3], linestyle='None', markersize=10, label='Word2Vec')
    m5 = mlines.Line2D([], [], color=colors[4], marker=markers[4], linestyle='None', markersize=10, label='FastText')
    plt.title('CPS ' + dataset_name.upper()+' dataset')
    plt.legend(handles=[m1, m2, m3, m4, m5])
    plt.tight_layout()
    plt.savefig(title + "_" + dataset_name.upper()+'_dataset_2_b.pdf', dpi=450)

n_classifiers = 8
method = 'umap'
n_features = 5
for dataset_name in ['liar']:
    
    label, methods = load_predictions_2_a(dataset_name)
    methods_name = [name.split('-', 1)[0] for name in methods.columns]
    D_tilde = compute_matrix_embedding(dataset_name, n_classifiers, n_features, method)
    plot_diversity_1_a(D_tilde, methods_name, dataset_name, method)
# Out:
# liar
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: RuntimeWarning: divide by zero encountered in true_divide
# /usr/local/lib/python3.7/dist-packages/umap/spectral.py:229: UserWarning: Embedding a total of 7 separate connected components using meta-embedding (experimental)
#   n_components

# %% [markdown]
# ####c

# %%
# !mkdir Data 
# !mkdir Data/liar 
# !mkdir Data/liar/Caso2

# %%
def load_predictions_2_a(dataset_name):
    path = '/content/Data/liar/Caso2/pred_val_2_c.csv'
    table_pred = pd.read_csv(path)
    print(dataset_name)
    if dataset_name == 'liar':
        label = table_pred["label"]
        methods = table_pred.drop('label', axis=1)
    methods = methods.drop('Unnamed: 0', axis=1)
    return label, methods

def plot_diversity_1_a(D_changed, method_tmp, dataset_name, title):
    s = 100
    colors = {}
    colors[0] = '#DAA520'
    colors[1] = '#FF0000'
    colors[2] = '#0000FF'
    colors[3] = '#228B22'
    colors[4] = '#000000'
    markers = {}
    markers[0] = 'X'
    markers[1] = 'd'
    markers[2] = '*'
    markers[3] = "^"
    markers[4] = 'o'
    n_classifiers, n_features, _ = D_changed.shape
    plt.figure(figsize=(15,10))
    method=0
    for idx in range(n_classifiers):
        for idx2 in range(n_features):
            x, y = D_changed[idx,idx2, 0], D_changed[idx,idx2, 1]
            plt.scatter(x, y, color=colors[idx2], s=s, lw=0, marker=markers[idx2])
            plt.annotate(method_tmp[method], xy=(x, y), textcoords='offset points', xytext=(5, 15), ha='right', va='top')  
            method += 1
    
    m1 = mlines.Line2D([], [], color=colors[0], marker=markers[0], linestyle='None', markersize=10, label='CV')
    m2 = mlines.Line2D([], [], color=colors[1], marker=markers[1], linestyle='None', markersize=10, label='TFIDF')
    m3 = mlines.Line2D([], [], color=colors[2], marker=markers[2], linestyle='None', markersize=10, label='Glove')
    m4 = mlines.Line2D([], [], color=colors[3], marker=markers[3], linestyle='None', markersize=10, label='Word2Vec')
    m5 = mlines.Line2D([], [], color=colors[4], marker=markers[4], linestyle='None', markersize=10, label='FastText')
    plt.title('CPS ' + dataset_name.upper()+' dataset')
    plt.legend(handles=[m1, m2, m3, m4, m5])
    plt.tight_layout()
    plt.savefig(title + "_" + dataset_name.upper()+'_dataset_2_c.pdf', dpi=450)

n_classifiers = 8
method = 'umap'
n_features = 5
#for dataset_name in ['liar']:
    
#    label, methods = load_predictions_2_a(dataset_name)
#    methods_name = [name.split('-', 1)[0] for name in methods.columns]
#    D_tilde = compute_matrix_embedding(dataset_name, n_classifiers, n_features, method)
#    plot_diversity_1_a(D_tilde, methods_name, dataset_name, method)

# %% [markdown]
# ![umap_LIAR_dataset_2_c_pdf_to_jpg.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Caso 3

# %% [markdown]
# ####a

# %%
def load_predictions_3_a(dataset_name):
    path = '/content/Data/liar/Caso3/union/pred_val_3_a.csv'
    table_pred = pd.read_csv(path)
    print(dataset_name)
    if dataset_name == 'liar':
        label = table_pred["label"]
        methods = table_pred.drop('label', axis=1)
    methods = methods.drop('Unnamed: 0', axis=1)
    methods = methods.drop('Unnamed: 0.1', axis=1)
    return label, methods

def plot_diversity_3_a(D_changed, method_tmp, dataset_name, title):
    s = 100
    colors = {}
    colors[0] = '#DAA520'
    colors[1] = '#FF0000'
    colors[2] = '#0000FF'
    colors[3] = '#228B22'
    colors[4] = '#000000'
    markers = {}
    markers[0] = 'X'
    markers[1] = 'd'
    markers[2] = '*'
    markers[3] = "^"
    markers[4] = 'o'
    n_classifiers, n_features, _ = D_changed.shape
    plt.figure(figsize=(15,10))
    method=0
    for idx in range(n_classifiers):
        for idx2 in range(n_features):
            x, y = D_changed[idx,idx2, 0], D_changed[idx,idx2, 1]
            plt.scatter(x, y, color=colors[idx2], s=s, lw=0, marker=markers[idx2])
            plt.annotate(method_tmp[method], xy=(x, y), textcoords='offset points', xytext=(5, 15), ha='right', va='top')  
            method += 1
    
    m1 = mlines.Line2D([], [], color=colors[0], marker=markers[0], linestyle='None', markersize=10, label='CV')
    m2 = mlines.Line2D([], [], color=colors[1], marker=markers[1], linestyle='None', markersize=10, label='TFIDF')
    m3 = mlines.Line2D([], [], color=colors[2], marker=markers[2], linestyle='None', markersize=10, label='Glove')
    m4 = mlines.Line2D([], [], color=colors[3], marker=markers[3], linestyle='None', markersize=10, label='Word2Vec')
    m5 = mlines.Line2D([], [], color=colors[4], marker=markers[4], linestyle='None', markersize=10, label='FastText')
    plt.title('CPS ' + dataset_name.upper()+' dataset')
    plt.legend(handles=[m1, m2, m3, m4, m5])
    plt.tight_layout()
    plt.savefig(title + "_" + dataset_name.upper()+'_dataset_3_a.pdf', dpi=450)

n_classifiers = 8
method = 'umap'
n_features = 5
for dataset_name in ['liar']:
    
    label, methods = load_predictions_3_a(dataset_name)
    methods_name = [name.split('-', 1)[0] for name in methods.columns]
    D_tilde = compute_matrix_embedding(dataset_name, n_classifiers, n_features, method)
    plot_diversity_3_a(D_tilde, methods_name, dataset_name, method)
# Out:
# liar
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: RuntimeWarning: divide by zero encountered in true_divide
# /usr/local/lib/python3.7/dist-packages/umap/spectral.py:229: UserWarning: Embedding a total of 11 separate connected components using meta-embedding (experimental)
#   n_components

# %%
# qualquer um : CNN-TFIDF, MLP-CV; KNN-TFIDF, MLP-W2V, LR-GLOVE, SVM-FAST, KNN-GLOVE, MLP-TFIDF, NB-FAST, NB-CV, RF-CV
# diversity variando: LR-GLOVE, SVM-FAST, NB-W2V, CNN-CV, MLP-TFIDF,RF-CV, EXTRA-GLOVE, NB-TFIDF,LR-W2V, KNN-FAST, MLP-CV

# %% [markdown]
# ####b

# %%
def load_predictions_3_b(dataset_name):
    path = '/content/Data/liar/Caso3/union/pred_val_3_b.csv'
    table_pred = pd.read_csv(path)
    print(dataset_name)
    if dataset_name == 'liar':
        label = table_pred["label"]
        methods = table_pred.drop('label', axis=1)
    methods = methods.drop('Unnamed: 0', axis=1)
    methods = methods.drop('Unnamed: 0.1', axis=1)
    return label, methods

def plot_diversity_3_b(D_changed, method_tmp, dataset_name, title):
    s = 100
    colors = {}
    colors[0] = '#DAA520'
    colors[1] = '#FF0000'
    colors[2] = '#0000FF'
    colors[3] = '#228B22'
    colors[4] = '#000000'
    markers = {}
    markers[0] = 'X'
    markers[1] = 'd'
    markers[2] = '*'
    markers[3] = "^"
    markers[4] = 'o'
    n_classifiers, n_features, _ = D_changed.shape
    plt.figure(figsize=(15,10))
    method=0
    for idx in range(n_classifiers):
        for idx2 in range(n_features):
            x, y = D_changed[idx,idx2, 0], D_changed[idx,idx2, 1]
            plt.scatter(x, y, color=colors[idx2], s=s, lw=0, marker=markers[idx2])
            plt.annotate(method_tmp[method], xy=(x, y), textcoords='offset points', xytext=(5, 15), ha='right', va='top')  
            method += 1
    
    m1 = mlines.Line2D([], [], color=colors[0], marker=markers[0], linestyle='None', markersize=10, label='CV')
    m2 = mlines.Line2D([], [], color=colors[1], marker=markers[1], linestyle='None', markersize=10, label='TFIDF')
    m3 = mlines.Line2D([], [], color=colors[2], marker=markers[2], linestyle='None', markersize=10, label='Glove')
    m4 = mlines.Line2D([], [], color=colors[3], marker=markers[3], linestyle='None', markersize=10, label='Word2Vec')
    m5 = mlines.Line2D([], [], color=colors[4], marker=markers[4], linestyle='None', markersize=10, label='FastText')
    plt.title('CPS ' + dataset_name.upper()+' dataset')
    plt.legend(handles=[m1, m2, m3, m4, m5])
    plt.tight_layout()
    plt.savefig(title + "_" + dataset_name.upper()+'_dataset_3_b.pdf', dpi=450)

n_classifiers = 8
method = 'umap'
n_features = 5
for dataset_name in ['liar']:
    
    label, methods = load_predictions_3_b(dataset_name)
    methods_name = [name.split('-', 1)[0] for name in methods.columns]
    D_tilde = compute_matrix_embedding(dataset_name, n_classifiers, n_features, method)
    plot_diversity_3_b(D_tilde, methods_name, dataset_name, method)
# Out:
# liar
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: RuntimeWarning: divide by zero encountered in true_divide
# /usr/local/lib/python3.7/dist-packages/umap/spectral.py:229: UserWarning: Embedding a total of 8 separate connected components using meta-embedding (experimental)
#   n_components

# %%
#aleatorio: CNN-GLOVE,CNN-W2V, CNN-TFIDF, KNN-W2V, EXTRA-CV, LR-TFIDF, MLP-TFIDF
#variando tecnicas: KNN-FAST, EXTRA-TFIDF, CNN-CV, NB-W2V, RF-GLOVE, LR-TFIDF, NB-GLOVE
#melhores: SVM-W2V,LR-TFIDF,EXTRA-TFIDF,CNN-GLOVE, NB-FAST, KNN-FAST, CNN-FAST

# %% [markdown]
# ####c

# %%
def load_predictions_3_c(dataset_name):
    path = '/content/Data/liar/Caso3/union/pred_val_3_c.csv'
    table_pred = pd.read_csv(path)
    print(dataset_name)
    if dataset_name == 'liar':
        label = table_pred["label"]
        methods = table_pred.drop('label', axis=1)
    methods = methods.drop('Unnamed: 0', axis=1)
    methods = methods.drop('Unnamed: 0.1', axis=1)
    return label, methods

def plot_diversity_3_c(D_changed, method_tmp, dataset_name, title):
    s = 100
    colors = {}
    colors[0] = '#DAA520'
    colors[1] = '#FF0000'
    colors[2] = '#0000FF'
    colors[3] = '#228B22'
    colors[4] = '#000000'
    markers = {}
    markers[0] = 'X'
    markers[1] = 'd'
    markers[2] = '*'
    markers[3] = "^"
    markers[4] = 'o'
    n_classifiers, n_features, _ = D_changed.shape
    plt.figure(figsize=(15,10))
    method=0
    for idx in range(n_classifiers):
        for idx2 in range(n_features):
            x, y = D_changed[idx,idx2, 0], D_changed[idx,idx2, 1]
            plt.scatter(x, y, color=colors[idx2], s=s, lw=0, marker=markers[idx2])
            plt.annotate(method_tmp[method], xy=(x, y), textcoords='offset points', xytext=(5, 15), ha='right', va='top')  
            method += 1
    
    m1 = mlines.Line2D([], [], color=colors[0], marker=markers[0], linestyle='None', markersize=10, label='CV')
    m2 = mlines.Line2D([], [], color=colors[1], marker=markers[1], linestyle='None', markersize=10, label='TFIDF')
    m3 = mlines.Line2D([], [], color=colors[2], marker=markers[2], linestyle='None', markersize=10, label='Glove')
    m4 = mlines.Line2D([], [], color=colors[3], marker=markers[3], linestyle='None', markersize=10, label='Word2Vec')
    m5 = mlines.Line2D([], [], color=colors[4], marker=markers[4], linestyle='None', markersize=10, label='FastText')
    plt.title('CPS ' + dataset_name.upper()+' dataset')
    plt.legend(handles=[m1, m2, m3, m4, m5])
    plt.tight_layout()
    plt.savefig(title + "_" + dataset_name.upper()+'_dataset_3_c.pdf', dpi=450)

n_classifiers = 8
method = 'umap'
n_features = 5
for dataset_name in ['liar']:
    
    label, methods = load_predictions_3_a(dataset_name)
    methods_name = [name.split('-', 1)[0] for name in methods.columns]
    D_tilde = compute_matrix_embedding(dataset_name, n_classifiers, n_features, method)
    plot_diversity_3_c(D_tilde, methods_name, dataset_name, method)
# Out:
# liar
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: RuntimeWarning: divide by zero encountered in true_divide
# /usr/local/lib/python3.7/dist-packages/umap/spectral.py:229: UserWarning: Embedding a total of 11 separate connected components using meta-embedding (experimental)
#   n_components

# %%
#aleatorio:  MLP-W2V, CNN-CV, RF-CV, NB-CV, CNN-GLOVE, EXTRA-GLOVE, NB-W2V, NB-GLOVE, LR-FAST, SVM-CV, SVM-TFIDF

# %% [markdown]
# ## Stacking

# %%
# %%capture 
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.metrics import f1_score, accuracy_score
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, plot_confusion_matrix
import matplotlib.pyplot as plt

# %%
def filter_df_train_test(train_df, test_df, name, filter_first=True):
    train = train_df.filter(regex=name, axis=1)
    test = test_df.filter(regex=name, axis=1)
    return train.to_numpy(), test.to_numpy(), train.columns
def filter_collinearity(X_train, X_test):
    X_train = X_train[:, ::2]
    X_test = X_test[:, ::2]
    return X_train, X_test
stacking = LogisticRegression()
def generate_confusion_matrix(stacking, X_test, labels_test, name):
    disp = plot_confusion_matrix(stacking, X_test, 
                             labels_test, cmap=plt.cm.Blues, display_labels=['True', 'Fake'])
    disp.ax_.set_title(name)
    plt.tight_layout()
    plt.savefig('confusion_matrix_' + name+'.pdf', dpi=300)
def create_coefficient_plot(coefs, names, group, savename):
    log_odds = np.exp(coefs.T)
    log_odds = pd.DataFrame(log_odds,names,['Coef']).sort_values(by='Coef', ascending=False)
    log_odds.round(3)
    log_odds.plot.bar()
    plt.ylabel('LR Coefficients')
    plt.xlabel(group)
    plt.tight_layout()
    plt.savefig(savename+'.pdf', dpi=300)
def organize_names_df(names):
    names_coeffs = names[::2]
    names_coeffs = [name.replace("-0", "") for name in names_coeffs]
    #names_coeffs = [name.replace("-CV", "-TF") for name in names_coeffs]
    return names_coeffs

# %% [markdown]
# ### Caso 1 - Pre process 1

# %% [markdown]
# #### Any Diversity

# %% [markdown]
# ##### a

# %%
train_labels=train_labels_1
val_labels=val_labels_1
test_labels=test_labels_1
val_df = pd.read_csv("/content/Data/liar/Caso1/prob_val_1_a.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso1/prob_test_1_a.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]

#group A------------------------------------------------------------------------
algorithms_list = ['SVM', 'LR','RF','NB','MLP', 'EXTRA','KNN','CNN']
stacking = LogisticRegression(class_weight='balanced',multi_class='multinomial')
results_A = np.zeros(len(algorithms_list))
for idx_alg, algorithm in enumerate(algorithms_list):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, algorithm)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking.fit(X_val, labels_val)
  y_pred = stacking.predict(X_test)
  score = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
  results_A[idx_alg] = score
print("results A - Caso 1 a: ", results_A)
print("results A - Caso 1 a: ", round(results_A.mean(),3))

#group B -----------------------------------------------------------------------
fe_list = ['CV', 'TFIDF', 'W2V', 'GLOVE', 'FAST']
results_B = np.zeros(len(fe_list))
for idx_alg, fe in enumerate(fe_list):
    X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, fe)
    X_val, X_test = filter_collinearity(X_val, X_test)
    stacking.fit(X_val, labels_val)
    y_pred = stacking.predict(X_test)
    results_B[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#     generate_confusion_matrix(stacking, X_test, labels_test, name)
print("resultsB - Caso 1 a: ", results_B)
print("resultsB - Caso 1 a: ", round(results_B.mean(),3))

#group C -----------------------------------------------------------------------
results_C = 0
stacking_C = LogisticRegression()
X_val, X_test = filter_collinearity(probas_val.to_numpy(), probas_test.to_numpy())
stacking_C.fit(X_val, labels_val)
y_pred = stacking_C.predict(X_test)
results_C = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp = plot_confusion_matrix(stacking_C, X_test, labels_test, cmap=plt.cm.Blues, 
#                             display_labels=['False','Half-true','Mostly-true','True','Barely-true','Pants-fire'])
                             #['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
print("resultsC - Caso 1 a: ", results_C)
#disp.ax_.set_title("Confusion Matrix - Group C")
#plt.rcParams["figure.figsize"] = (10,8)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GROUP_C_Caso_1_a.pdf', dpi=300)

#group D------------------------------------------------------------------------
models_D = ['RF-FAST','SVM-FAST','CNN-W2V','NB-GLOVE','MLP-TFIDF','MLP-W2V','EXTRA-FAST','EXTRA-TFIDF','SVM-TFIDF','NB-TFIDF']
names = 'RF-FAST|SVM-FAST|CNN-W2V|NB-GLOVE|MLP-TFIDF|MLP-W2V|EXTRA-FAST|EXTRA-TFIDF|SVM-TFIDF|NB-TFIDF'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))

##### Coefficients Group D 
#models_C=['SVM-CV', 'SVM-TFIDF', 'SVM-W2V', 'SVM-GLOVE', 'SVM-FAST','LR-CV','LR-TFIDF','LR-W2V','LR-GLOVE','LR-FAST',
#          'RF-CV','RF-TFIDF','RF-W2V','RF-GLOVE','RF-FAST','NB-CV','NB-TFIDF','NB-W2V','NB-GLOVE','NB-FAST',
#          'MLP-CV','MLP-TFIDF','MLP-W2V','MLP-GLOVE','MLP-FAST','EXTRA-CV', 'EXTRA-TFIDF','EXTRA-W2V', 'EXTRA-GLOVE', 'EXTRA-FAST',
#          'CNN-CV','CNN-TFIDF','CNN-W2V','CNN-GLOVE','CNN-FAST', 'KNN-CV', 'KNN-TFIDF','KNN-W2V', 'KNN-GLOVE', 'KNN-FAST',]
#all_stacking_names = ['Logistic Regression']
#algorithms_list_A = [alg + ' (Group A)' for alg in algorithms_list]
#group_A_df = pd.DataFrame(results_A.mean(), columns=all_stacking_names, index=algorithms_list_A)

#fe_list_B = [fe + ' (Group B)' for fe in fe_list]
#group_B_df = pd.DataFrame(results_B.mean(), columns=all_stacking_names, index=fe_list_B)
#group_C_df = pd.DataFrame(results_C.mean().reshape(1, 1), columns=all_stacking_names, index=['Group C'])
#group_D_df = pd.DataFrame(results_D.mean().reshape(1, 1), columns=all_stacking_names, index=['Group D'])
#from pprint import pprint
#pprint(pd.concat([group_A_df, group_B_df, group_C_df, group_D_df]).round(4).to_latex(caption='dataset '+ dataset_name.upper()))
# Out:
# results A - Caso 1 a:  [0.187 0.205 0.216 0.185 0.195 0.194 0.179 0.22 ]
# results A - Caso 1 a:  0.198
# resultsB - Caso 1 a:  [0.196 0.213 0.201 0.186 0.203]
# resultsB - Caso 1 a:  0.2
# resultsC - Caso 1 a:  0.224
# results D 1 a:  [0.241 0.241 0.241 0.241 0.241 0.241 0.241 0.241 0.241 0.241]
# results mean D 1 a:  0.241

# %% [markdown]
# ##### b

# %%
train_labels=train_labels_2
val_labels=val_labels_2
test_labels=test_labels_2
val_df = pd.read_csv("/content/Data/liar/Caso1/prob_val_1_b.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso1/prob_test_1_b.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]

#group A------------------------------------------------------------------------
algorithms_list = ['SVM', 'LR','RF','NB','MLP', 'EXTRA','KNN','CNN']
stacking = LogisticRegression(class_weight='balanced',multi_class='multinomial')
results_A = np.zeros(len(algorithms_list))
for idx_alg, algorithm in enumerate(algorithms_list):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, algorithm)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking.fit(X_val, labels_val)
  y_pred = stacking.predict(X_test)
  score = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
  results_A[idx_alg] = score
print("results A - Caso 1 a: ", results_A)
print("results A - Caso 1 a: ", round(results_A.mean(),3))

#group B -----------------------------------------------------------------------
fe_list = ['CV', 'TFIDF', 'W2V', 'GLOVE', 'FAST']
results_B = np.zeros(len(fe_list))
for idx_alg, fe in enumerate(fe_list):
    X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, fe)
    X_val, X_test = filter_collinearity(X_val, X_test)
    stacking.fit(X_val, labels_val)
    y_pred = stacking.predict(X_test)
    results_B[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#     generate_confusion_matrix(stacking, X_test, labels_test, name)
print("resultsB - Caso 1 a: ", results_B)
print("resultsB - Caso 1 a: ", round(results_B.mean(),3))

#group C -----------------------------------------------------------------------
results_C = 0
stacking_C = LogisticRegression()
X_val, X_test = filter_collinearity(probas_val.to_numpy(), probas_test.to_numpy())
stacking_C.fit(X_val, labels_val)
y_pred = stacking_C.predict(X_test)
results_C = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp = plot_confusion_matrix(stacking_C, X_test, labels_test, cmap=plt.cm.Blues, 
#                             display_labels=['False','Half-true','Mostly-true','True','Barely-true','Pants-fire'])
                             #['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
print("resultsC - Caso 1 a: ", results_C)
#disp.ax_.set_title("Confusion Matrix - Group C")
#plt.rcParams["figure.figsize"] = (10,8)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GROUP_C_Caso_1_a.pdf', dpi=300)

#group D------------------------------------------------------------------------
models_D = ['SVM-GLOVE', 'MLP-FAST', 'SVM-FAST', 'EXTRA-GLOVE', 'EXTRA-CV', 'SVM-TFIDF', 'NB-FAST', 'RF-CV', 'KNN-TFIDF', 'KNN-GLOVE']
names = 'SVM-GLOVE|MLP-FAST|SVM-FAST|EXTRA-GLOVE|EXTRA-CV|SVM-TFIDF|NB-FAST|RF-CV|KNN-TFIDF|KNN-GLOVE'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results A - Caso 1 a:  [0.543 0.53  0.546 0.501 0.523 0.525 0.506 0.536]
# results A - Caso 1 a:  0.526
# resultsB - Caso 1 a:  [0.526 0.535 0.546 0.538 0.524]
# resultsB - Caso 1 a:  0.534
# resultsC - Caso 1 a:  0.58
# results D 1 a:  [0.602 0.602 0.602 0.602 0.602 0.602 0.602 0.602 0.602 0.602]
# results mean D 1 a:  0.602

# %% [markdown]
# ##### c

# %%
train_labels=train_labels_3
val_labels=val_labels_3
test_labels=test_labels_3
val_df = pd.read_csv("/content/Data/liar/Caso1/prob_val_1_c.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso1/prob_test_1_c.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]

#group A------------------------------------------------------------------------
algorithms_list = ['SVM', 'LR','RF','NB','MLP', 'EXTRA','KNN','CNN']
stacking = LogisticRegression(class_weight='balanced',multi_class='multinomial')
results_A = np.zeros(len(algorithms_list))
for idx_alg, algorithm in enumerate(algorithms_list):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, algorithm)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking.fit(X_val, labels_val)
  y_pred = stacking.predict(X_test)
  score = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
  results_A[idx_alg] = score
print("results A - Caso 1 a: ", results_A)
print("results A - Caso 1 a: ", round(results_A.mean(),3))

#group B -----------------------------------------------------------------------
fe_list = ['CV', 'TFIDF', 'W2V', 'GLOVE', 'FAST']
results_B = np.zeros(len(fe_list))
for idx_alg, fe in enumerate(fe_list):
    X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, fe)
    X_val, X_test = filter_collinearity(X_val, X_test)
    stacking.fit(X_val, labels_val)
    y_pred = stacking.predict(X_test)
    results_B[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#     generate_confusion_matrix(stacking, X_test, labels_test, name)
print("resultsB - Caso 1 a: ", results_B)
print("resultsB - Caso 1 a: ", round(results_B.mean(),3))

#group C -----------------------------------------------------------------------
results_C = 0
stacking_C = LogisticRegression()
X_val, X_test = filter_collinearity(probas_val.to_numpy(), probas_test.to_numpy())
stacking_C.fit(X_val, labels_val)
y_pred = stacking_C.predict(X_test)
results_C = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp = plot_confusion_matrix(stacking_C, X_test, labels_test, cmap=plt.cm.Blues, 
#                             display_labels=['False','Half-true','Mostly-true','True','Barely-true','Pants-fire'])
                             #['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
print("resultsC - Caso 1 a: ", results_C)
#disp.ax_.set_title("Confusion Matrix - Group C")
#plt.rcParams["figure.figsize"] = (10,8)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GROUP_C_Caso_1_a.pdf', dpi=300)

#group D------------------------------------------------------------------------
models_D =['CNN-CV', 'EXTRA-FAST', 'LR-TFIDF', 'SVM-FAST', 'KNN-FAST', 'NB-W2V', 'EXTRA-W2V', 'EXTRA-CV', 'NB-CV', 'SVM-CV']
names = 'CNN-CV|EXTRA-FAST|LR-TFIDF|SVM-FAST|KNN-FAST|NB-W2V|EXTRA-W2V|EXTRA-CV|NB-CV|SVM-CV'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results A - Caso 1 a:  [0.624 0.609 0.595 0.605 0.612 0.597 0.579 0.613]
# results A - Caso 1 a:  0.604
# resultsB - Caso 1 a:  [0.589 0.608 0.619 0.599 0.614]
# resultsB - Caso 1 a:  0.606
# resultsC - Caso 1 a:  0.638
# results D 1 a:  [0.649 0.649 0.649 0.649 0.649 0.649 0.649 0.649 0.649 0.649]
# results mean D 1 a:  0.649

# %% [markdown]
# #### Varying Techniques

# %% [markdown]
# ##### a

# %%
train_labels=train_labels_1
val_labels=val_labels_1
test_labels=test_labels_1
val_df = pd.read_csv("/content/Data/liar/Caso1/prob_val_1_a.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso1/prob_test_1_a.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['EXTRA-GLOVE', 'LR-FAST', 'CNN-W2V', 'MLP-GLOVE', 'SVM-CV', 'MLP-FAST', 'RF-CV', 'KNN-TFIDF','LR-CV', 'NB-TFIDF']
names = 'EXTRA-GLOVE|LR-FAST|CNN-W2V|MLP-GLOVE|SVM-CV|MLP-FAST|RF-CV|KNN-TFIDF|LR-CV|NB-TFIDF'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results D 1 a:  [0.242 0.242 0.242 0.242 0.242 0.242 0.242 0.242 0.242 0.242]
# results mean D 1 a:  0.242

# %% [markdown]
# #####b

# %%
texte="CNN-W2V, MLP-FAST,RF-GLOVE, SVM-W2V, EXTRA-TFIDF, NB-FAST, LR-CV, RF-CV, KNN-TFIDF, MLP-W2V"
texte.replace(",","|")
# Out:
# 'CNN-W2V| MLP-FAST|RF-GLOVE| SVM-W2V| EXTRA-TFIDF| NB-FAST| LR-CV| RF-CV| KNN-TFIDF| MLP-W2V'

# %%
texte2="CNN-W2V, MLP-FAST,RF-GLOVE, SVM-W2V, EXTRA-TFIDF, NB-FAST, LR-CV, RF-CV, KNN-TFIDF, MLP-W2V"
texte2.replace(" "," '' ")
# Out:
# "CNN-W2V, '' MLP-FAST,RF-GLOVE, '' SVM-W2V, '' EXTRA-TFIDF, '' NB-FAST, '' LR-CV, '' RF-CV, '' KNN-TFIDF, '' MLP-W2V"

# %%
train_labels=train_labels_2
val_labels=val_labels_2
test_labels=test_labels_2
val_df = pd.read_csv("/content/Data/liar/Caso1/prob_val_1_b.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso1/prob_test_1_b.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['CNN-W2V','MLP-FAST','RF-GLOVE','SVM-W2V','EXTRA-TFIDF',' NB-FAST','LR-CV','RF-CV','KNN-TFIDF','MLP-W2V']
names = 'CNN-W2V| MLP-FAST|RF-GLOVE| SVM-W2V| EXTRA-TFIDF| NB-FAST| LR-CV| RF-CV| KNN-TFIDF| MLP-W2V'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean()),3)
# Out:
# results D 1 a:  [0.599 0.599 0.599 0.599 0.599 0.599 0.599 0.599 0.599 0.599]
# results mean D 1 a:  1 3

# %% [markdown]
# ##### c

# %%
texte="MLP-W2V, RF-W2V, LR-TFIDF, SVM-FAST, KNN-TFIDF, CNN-TFIDF, EXTRA-CV, EXTRA-GLOVE, NB-CV, SVM-CV "
texte.replace(",","|")
# Out:
# 'MLP-W2V| RF-W2V| LR-TFIDF| SVM-FAST| KNN-TFIDF| CNN-TFIDF| EXTRA-CV| EXTRA-GLOVE| NB-CV| SVM-CV '

# %%
texte2="MLP-W2V, RF-W2V, LR-TFIDF, SVM-FAST, KNN-TFIDF, CNN-TFIDF, EXTRA-CV, EXTRA-GLOVE, NB-CV, SVM-CV "
texte2.replace(" "," '' ")
# Out:
# "MLP-W2V, '' RF-W2V, '' LR-TFIDF, '' SVM-FAST, '' KNN-TFIDF, '' CNN-TFIDF, '' EXTRA-CV, '' EXTRA-GLOVE, '' NB-CV, '' SVM-CV '' "

# %%
train_labels=train_labels_3
val_labels=val_labels_3
test_labels=test_labels_3
val_df = pd.read_csv("/content/Data/liar/Caso1/prob_val_1_c.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso1/prob_test_1_c.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['MLP-W2V','RF-W2V','LR-TFIDF','SVM-FAST','KNN-TFIDF','CNN-TFIDF','EXTRA-CV','EXTRA-GLOVE','NB-CV','SVM-CV']
names = 'MLP-W2V| RF-W2V| LR-TFIDF| SVM-FAST| KNN-TFIDF| CNN-TFIDF| EXTRA-CV| EXTRA-GLOVE| NB-CV| SVM-CV' 
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean()),3)
# Out:
# results D 1 a:  [0.626 0.626 0.626 0.626 0.626 0.626 0.626 0.626 0.626 0.626]
# results mean D 1 a:  1 3

# %% [markdown]
# #### Best

# %% [markdown]
# ##### a

# %%
texte="SVM-W2V,RF-TFIDF,LR-FAST,CNN-FAST, EXTRA-GLOVE, LR-TFIDF, NB-GLOVE, KNN-TFIDF, NB-TFIDF, MLP-CV"
texte.replace(",","|")
# Out:
# 'SVM-W2V|RF-TFIDF|LR-FAST|CNN-FAST| EXTRA-GLOVE| LR-TFIDF| NB-GLOVE| KNN-TFIDF| NB-TFIDF| MLP-CV'

# %%
texte2="SVM-W2V,RF-TFIDF,LR-FAST,CNN-FAST, EXTRA-GLOVE, LR-TFIDF, NB-GLOVE, KNN-TFIDF, NB-TFIDF, MLP-CV"
texte2.replace(" "," '").replace(",","' ").replace(" ",",")
# Out:
# "SVM-W2V',RF-TFIDF',LR-FAST',CNN-FAST',,'EXTRA-GLOVE',,'LR-TFIDF',,'NB-GLOVE',,'KNN-TFIDF',,'NB-TFIDF',,'MLP-CV"

# %%
train_labels=train_labels_3
val_labels=val_labels_3
test_labels=test_labels_3
val_df = pd.read_csv("/content/Data/liar/Caso1/prob_val_1_c.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso1/prob_test_1_c.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['SVM-W2V','RF-TFIDF','LR-FAST','CNN-FAST','EXTRA-GLOVE','LR-TFIDF','NB-GLOVE','KNN-TFIDF','NB-TFIDF','MLP-CV']
names = 'SVM-W2V|RF-TFIDF|LR-FAST|CNN-FAST| EXTRA-GLOVE| LR-TFIDF| NB-GLOVE| KNN-TFIDF| NB-TFIDF| MLP-CV' 
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results D 1 a:  [0.67 0.67 0.67 0.67 0.67 0.67 0.67 0.67 0.67 0.67]
# results mean D 1 a:  0.67

# %% [markdown]
# ##### b

# %%
texte="SVM-GLOVE,MLP-FAST, EXTRA-GLOVE, SVM-W2V,SVM-TFIDF,EXTRA-TFIDF, NB-TFIDF, NB-FAST, CNN-GLOVE, KNN-W2V "
texte.replace(",","|")
# Out:
# 'SVM-GLOVE|MLP-FAST| EXTRA-GLOVE| SVM-W2V|SVM-TFIDF|EXTRA-TFIDF| NB-TFIDF| NB-FAST| CNN-GLOVE| KNN-W2V '

# %%
texte2="SVM-GLOVE,MLP-FAST, EXTRA-GLOVE, SVM-W2V,SVM-TFIDF,EXTRA-TFIDF, NB-TFIDF, NB-FAST, CNN-GLOVE, KNN-W2V "
texte2.replace(" "," '' ")
# Out:
# "SVM-GLOVE,MLP-FAST, '' EXTRA-GLOVE, '' SVM-W2V,SVM-TFIDF,EXTRA-TFIDF, '' NB-TFIDF, '' NB-FAST, '' CNN-GLOVE, '' KNN-W2V '' "

# %%
train_labels=train_labels_2
val_labels=val_labels_2
test_labels=test_labels_2
val_df = pd.read_csv("/content/Data/liar/Caso1/prob_val_1_b.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso1/prob_test_1_b.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['SVM-GLOVE','MLP-FAST','EXTRA-GLOVE','SVM-W2V','SVM-TFIDF','EXTRA-TFIDF','NB-TFIDF', 'NB-FAST','CNN-GLOVE','KNN-W2V']
names = 'SVM-GLOVE|MLP-FAST| EXTRA-GLOVE| SVM-W2V|SVM-TFIDF|EXTRA-TFIDF| NB-TFIDF| NB-FAST| CNN-GLOVE| KNN-W2V ' 
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = accuracy_score(labels_test, y_pred)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ",results_D.mean())
# Out:
# results D 1 a:  [0.59547935 0.59547935 0.59547935 0.59547935 0.59547935 0.59547935
#  0.59547935 0.59547935 0.59547935 0.59547935]
# results mean D 1 a:  0.5954793452844893

# %% [markdown]
# ##### c

# %%
texte="SVM-W2V,RF-TFIDF,LR-FAST,CNN-FAST, EXTRA-GLOVE, LR-TFIDF, NB-GLOVE, KNN-TFIDF, NB-TFIDF, MLP-CV "
texte.replace(",","|")
# Out:
# 'SVM-W2V|RF-TFIDF|LR-FAST|CNN-FAST| EXTRA-GLOVE| LR-TFIDF| NB-GLOVE| KNN-TFIDF| NB-TFIDF| MLP-CV '

# %%
texte2="SVM-W2V,RF-TFIDF,LR-FAST,CNN-FAST, EXTRA-GLOVE, LR-TFIDF, NB-GLOVE, KNN-TFIDF, NB-TFIDF, MLP-CV "
texte2.replace(" "," '' ")
# Out:
# "SVM-W2V,RF-TFIDF,LR-FAST,CNN-FAST, '' EXTRA-GLOVE, '' LR-TFIDF, '' NB-GLOVE, '' KNN-TFIDF, '' NB-TFIDF, '' MLP-CV '' "

# %%
train_labels=train_labels_3
val_labels=val_labels_3
test_labels=test_labels_3
val_df = pd.read_csv("/content/Data/liar/Caso1/prob_val_1_c.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso1/prob_test_1_c.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['SVM-W2V','RF-TFIDF','LR-FAST','CNN-FAST','EXTRA-GLOVE', 'LR-TFIDF', 'NB-GLOVE', 'KNN-TFIDF', 'NB-TFIDF', 'MLP-CV']
names = 'SVM-W2V|RF-TFIDF|LR-FAST|CNN-FAST| EXTRA-GLOVE| LR-TFIDF| NB-GLOVE| KNN-TFIDF| NB-TFIDF| MLP-CV' 
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = accuracy_score(labels_test, y_pred)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ",results_D.mean())
# Out:
# results D 1 a:  [0.67030398 0.67030398 0.67030398 0.67030398 0.67030398 0.67030398
#  0.67030398 0.67030398 0.67030398 0.67030398]
# results mean D 1 a:  0.6703039750584567

# %% [markdown]
# ### Caso 2 - Pre process 2

# %% [markdown]
# #### Any Diversity

# %% [markdown]
# ##### a

# %%
texte=" CNN-TFIDF, NB-W2V,NB-GLOVE, EXTRA-GLOVE,LR-FAST, MLP-FAST, MLP-TFIDF, RF-TFIDF, MLP-W2V, NB-CV"
texte.replace(",","|")
# Out:
# ' CNN-TFIDF| NB-W2V|NB-GLOVE| EXTRA-GLOVE|LR-FAST| MLP-FAST| MLP-TFIDF| RF-TFIDF| MLP-W2V| NB-CV'

# %%
texte2=" CNN-TFIDF, NB-W2V,NB-GLOVE, EXTRA-GLOVE,LR-FAST, MLP-FAST, MLP-TFIDF, RF-TFIDF, MLP-W2V, NB-CV"
texte2.replace(" "," '").replace(",","' ").replace(" ",",")
# Out:
# ",'CNN-TFIDF',,'NB-W2V',NB-GLOVE',,'EXTRA-GLOVE',LR-FAST',,'MLP-FAST',,'MLP-TFIDF',,'RF-TFIDF',,'MLP-W2V',,'NB-CV"

# %%
train_labels=train_labels_1
val_labels=val_labels_1
test_labels=test_labels_1
val_df = pd.read_csv("/content/Data/liar/Caso2/prob_val_2_a.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso2/prob_test_2_a.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]

#group A------------------------------------------------------------------------
algorithms_list = ['SVM', 'LR','RF','NB','MLP', 'EXTRA','KNN','CNN']
stacking = LogisticRegression(class_weight='balanced',multi_class='multinomial')
results_A = np.zeros(len(algorithms_list))
for idx_alg, algorithm in enumerate(algorithms_list):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, algorithm)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking.fit(X_val, labels_val)
  y_pred = stacking.predict(X_test)
  score = accuracy_score(labels_test, y_pred)#,average='macro')
  results_A[idx_alg] = round(score,3)
print("results A - Caso 1 a: ", results_A)
print("results A - Caso 1 a: ", round(results_A.mean(),3))

#group B -----------------------------------------------------------------------
fe_list = ['CV', 'TFIDF', 'W2V', 'GLOVE', 'FAST']
results_B = np.zeros(len(fe_list))
for idx_alg, fe in enumerate(fe_list):
    X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, fe)
    X_val, X_test = filter_collinearity(X_val, X_test)
    stacking.fit(X_val, labels_val)
    y_pred = stacking.predict(X_test)
    results_B[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#     generate_confusion_matrix(stacking, X_test, labels_test, name)
print("resultsB - Caso 1 a: ", results_B)
print("resultsB - Caso 1 a: ", round(results_B.mean(),3))

#group C -----------------------------------------------------------------------
results_C = 0
stacking_C = LogisticRegression()
X_val, X_test = filter_collinearity(probas_val.to_numpy(), probas_test.to_numpy())
stacking_C.fit(X_val, labels_val)
y_pred = stacking_C.predict(X_test)
results_C = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp = plot_confusion_matrix(stacking_C, X_test, labels_test, cmap=plt.cm.Blues, 
#                             display_labels=['False','Half-true','Mostly-true','True','Barely-true','Pants-fire'])
                             #['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
print("resultsC - Caso 1 a: ", results_C)
#disp.ax_.set_title("Confusion Matrix - Group C")
#plt.rcParams["figure.figsize"] = (10,8)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GROUP_C_Caso_1_a.pdf', dpi=300)

#group D------------------------------------------------------------------------
models_D = [' CNN-TFIDF','NB-W2V','NB-GLOVE','EXTRA-GLOVE','LR-FAST', 'MLP-FAST', 'MLP-TFIDF', 'RF-TFIDF', 'MLP-W2V', 'NB-CV']
names = ' CNN-TFIDF| NB-W2V|NB-GLOVE| EXTRA-GLOVE|LR-FAST| MLP-FAST| MLP-TFIDF| RF-TFIDF| MLP-W2V| NB-CV'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results A - Caso 1 a:  [0.205 0.205 0.196 0.198 0.21  0.226 0.203 0.212]
# results A - Caso 1 a:  0.207
# resultsB - Caso 1 a:  [0.208 0.213 0.21  0.189 0.214]
# resultsB - Caso 1 a:  0.207
# resultsC - Caso 1 a:  0.242
# results D 1 a:  [0.235 0.235 0.235 0.235 0.235 0.235 0.235 0.235 0.235 0.235]
# results mean D 1 a:  0.235

# %% [markdown]
# ##### b

# %%
texte="SVM-GLOVE, CNN-FAST, MLP-TFIDF, EXTRA-TFIDF, KNN-CV, NB-W2V, KNN-FAST"
texte.replace(",","|")
# Out:
# 'SVM-GLOVE| CNN-FAST| MLP-TFIDF| EXTRA-TFIDF| KNN-CV| NB-W2V| KNN-FAST'

# %%
texte2="SVM-GLOVE, CNN-FAST, MLP-TFIDF, EXTRA-TFIDF, KNN-CV, NB-W2V, KNN-FAST"
texte2.replace(" "," '").replace(",","' ").replace(" ",",")
# Out:
# "SVM-GLOVE',,'CNN-FAST',,'MLP-TFIDF',,'EXTRA-TFIDF',,'KNN-CV',,'NB-W2V',,'KNN-FAST"

# %%
train_labels=train_labels_2
val_labels=val_labels_2
test_labels=test_labels_2
val_df = pd.read_csv("/content/Data/liar/Caso2/prob_val_2_b.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso2/prob_test_2_b.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]

#group A------------------------------------------------------------------------
algorithms_list = ['SVM', 'LR','RF','NB','MLP', 'EXTRA','KNN','CNN']
stacking = LogisticRegression(class_weight='balanced',multi_class='multinomial')
results_A = np.zeros(len(algorithms_list))
for idx_alg, algorithm in enumerate(algorithms_list):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, algorithm)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking.fit(X_val, labels_val)
  y_pred = stacking.predict(X_test)
  score = accuracy_score(labels_test, y_pred)#,average='macro')
  results_A[idx_alg] = round(score,3)
print("results A - Caso 1 a: ", results_A)
print("results A - Caso 1 a: ", round(results_A.mean(),3))

#group B -----------------------------------------------------------------------
fe_list = ['CV', 'TFIDF', 'W2V', 'GLOVE', 'FAST']
results_B = np.zeros(len(fe_list))
for idx_alg, fe in enumerate(fe_list):
    X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, fe)
    X_val, X_test = filter_collinearity(X_val, X_test)
    stacking.fit(X_val, labels_val)
    y_pred = stacking.predict(X_test)
    results_B[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#     generate_confusion_matrix(stacking, X_test, labels_test, name)
print("resultsB - Caso 1 a: ", results_B)
print("resultsB - Caso 1 a: ", round(results_B.mean(),3))

#group C -----------------------------------------------------------------------
results_C = 0
stacking_C = LogisticRegression()
X_val, X_test = filter_collinearity(probas_val.to_numpy(), probas_test.to_numpy())
stacking_C.fit(X_val, labels_val)
y_pred = stacking_C.predict(X_test)
results_C = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp = plot_confusion_matrix(stacking_C, X_test, labels_test, cmap=plt.cm.Blues, 
#                             display_labels=['False','Half-true','Mostly-true','True','Barely-true','Pants-fire'])
                             #['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
print("resultsC - Caso 1 a: ", results_C)
#disp.ax_.set_title("Confusion Matrix - Group C")
#plt.rcParams["figure.figsize"] = (10,8)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GROUP_C_Caso_1_a.pdf', dpi=300)

#group D------------------------------------------------------------------------
models_D = ['SVM-GLOVE', 'CNN-FAST','MLP-TFIDF','EXTRA-TFIDF','KNN-CV','NB-W2V','KNN-FAST']
names = 'SVM-GLOVE| CNN-FAST| MLP-TFIDF| EXTRA-TFIDF| KNN-CV| NB-W2V| KNN-FAST'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results A - Caso 1 a:  [0.542 0.525 0.522 0.527 0.554 0.55  0.515 0.543]
# results A - Caso 1 a:  0.535
# resultsB - Caso 1 a:  [0.538 0.521 0.553 0.535 0.535]
# resultsB - Caso 1 a:  0.536
# resultsC - Caso 1 a:  0.588
# results D 1 a:  [0.597 0.597 0.597 0.597 0.597 0.597 0.597]
# results mean D 1 a:  0.597

# %% [markdown]
# ##### c

# %%
texte=" NB-FAST, MLP-FAST, LR-W2V, LR-CV, CNN-CV, NB-TFIDF, MLP-CV, KNN-TFIDF"
texte.replace(",","|")
# Out:
# ' NB-FAST| MLP-FAST| LR-W2V| LR-CV| CNN-CV| NB-TFIDF| MLP-CV| KNN-TFIDF'

# %%
texte2=" NB-FAST, MLP-FAST, LR-W2V, LR-CV, CNN-CV, NB-TFIDF, MLP-CV, KNN-TFIDF"
texte2.replace(" "," '").replace(",","' ").replace(" ",",")
# Out:
# ",'NB-FAST',,'MLP-FAST',,'LR-W2V',,'LR-CV',,'CNN-CV',,'NB-TFIDF',,'MLP-CV',,'KNN-TFIDF"

# %%
train_labels=train_labels_3
val_labels=val_labels_3
test_labels=test_labels_3
val_df = pd.read_csv("/content/Data/liar/Caso2/prob_val_2_c.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso2/prob_test_2_c.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]

#group A------------------------------------------------------------------------
algorithms_list = ['SVM', 'LR','RF','NB','MLP', 'EXTRA','KNN','CNN']
stacking = LogisticRegression(class_weight='balanced',multi_class='multinomial')
results_A = np.zeros(len(algorithms_list))
for idx_alg, algorithm in enumerate(algorithms_list):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, algorithm)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking.fit(X_val, labels_val)
  y_pred = stacking.predict(X_test)
  score = accuracy_score(labels_test, y_pred)#,average='macro')
  results_A[idx_alg] = round(score,3)
print("results A - Caso 1 a: ", results_A)
print("results A - Caso 1 a: ", round(results_A.mean(),3))

#group B -----------------------------------------------------------------------
fe_list = ['CV', 'TFIDF', 'W2V', 'GLOVE', 'FAST']
results_B = np.zeros(len(fe_list))
for idx_alg, fe in enumerate(fe_list):
    X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, fe)
    X_val, X_test = filter_collinearity(X_val, X_test)
    stacking.fit(X_val, labels_val)
    y_pred = stacking.predict(X_test)
    results_B[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#     generate_confusion_matrix(stacking, X_test, labels_test, name)
print("resultsB - Caso 1 a: ", results_B)
print("resultsB - Caso 1 a: ", round(results_B.mean(),3))

#group C -----------------------------------------------------------------------
results_C = 0
stacking_C = LogisticRegression()
X_val, X_test = filter_collinearity(probas_val.to_numpy(), probas_test.to_numpy())
stacking_C.fit(X_val, labels_val)
y_pred = stacking_C.predict(X_test)
results_C = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp = plot_confusion_matrix(stacking_C, X_test, labels_test, cmap=plt.cm.Blues, 
#                             display_labels=['False','Half-true','Mostly-true','True','Barely-true','Pants-fire'])
                             #['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
print("resultsC - Caso 1 a: ", results_C)
#disp.ax_.set_title("Confusion Matrix - Group C")
#plt.rcParams["figure.figsize"] = (10,8)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GROUP_C_Caso_1_a.pdf', dpi=300)

#group D------------------------------------------------------------------------
models_D = ['NB-FAST','MLP-FAST','LR-W2V','LR-CV','CNN-CV','NB-TFIDF','MLP-CV','KNN-TFIDF']
names = 'NB-FAST| MLP-FAST| LR-W2V| LR-CV| CNN-CV| NB-TFIDF| MLP-CV| KNN-TFIDF'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results A - Caso 1 a:  [0.611 0.599 0.578 0.603 0.607 0.586 0.578 0.592]
# results A - Caso 1 a:  0.594
# resultsB - Caso 1 a:  [0.588 0.589 0.624 0.602 0.624]
# resultsB - Caso 1 a:  0.605
# resultsC - Caso 1 a:  0.662
# results D 1 a:  [0.641 0.641 0.641 0.641 0.641 0.641 0.641 0.641]
# results mean D 1 a:  0.641

# %% [markdown]
# #### Varying tecniques

# %% [markdown]
# ##### a

# %%
texte="CNN-TFIDF, NB-FAST, LR-GLOVE, EXTRA-W2V, NB-CV, KNN-CLOVE, SVM-FAST, MLP-TFIDF, RF-TFIDF, MLP-W2V"
texte.replace(",","|")
# Out:
# 'CNN-TFIDF| NB-FAST| LR-GLOVE| EXTRA-W2V| NB-CV| KNN-CLOVE| SVM-FAST| MLP-TFIDF| RF-TFIDF| MLP-W2V'

# %%
texte2="CNN-TFIDF, NB-FAST, LR-GLOVE, EXTRA-W2V, NB-CV, KNN-CLOVE, SVM-FAST, MLP-TFIDF, RF-TFIDF, MLP-W2V"
texte2.replace(" "," '").replace(",","'").replace(" ",",")
# Out:
# "CNN-TFIDF','NB-FAST','LR-GLOVE','EXTRA-W2V','NB-CV','KNN-CLOVE','SVM-FAST','MLP-TFIDF','RF-TFIDF','MLP-W2V"

# %%
train_labels=train_labels_1
val_labels=val_labels_1
test_labels=test_labels_1
val_df = pd.read_csv("/content/Data/liar/Caso2/prob_val_2_a.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso2/prob_test_2_a.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['CNN-TFIDF','NB-FAST','LR-GLOVE','EXTRA-W2V','NB-CV','KNN-CLOVE','SVM-FAST','MLP-TFIDF','RF-TFIDF','MLP-W2V']
names = 'CNN-TFIDF|NB-FAST|LR-GLOVE|EXTRA-W2V|NB-CV|KNN-CLOVE|SVM-FAST|MLP-TFIDF|RF-TFIDF|MLP-W2V'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results D 1 a:  [0.238 0.238 0.238 0.238 0.238 0.238 0.238 0.238 0.238 0.238]
# results mean D 1 a:  0.238

# %% [markdown]
# ##### b

# %%
texte="SVM-GLOVE, CNN-FAST, MLP-TFIDF, EXTRA-CV, KNN-W2V,RF-GLOVE, NB-W2V"
texte.replace(",","|").replace(" ","")
# Out:
# 'SVM-GLOVE|CNN-FAST|MLP-TFIDF|EXTRA-CV|KNN-W2V|RF-GLOVE|NB-W2V'

# %%
texte2="SVM-GLOVE, CNN-FAST, MLP-TFIDF, EXTRA-CV, KNN-W2V,RF-GLOVE, NB-W2V"
texte2.replace(" "," '").replace(",","'").replace(" ",",")
# Out:
# "SVM-GLOVE','CNN-FAST','MLP-TFIDF','EXTRA-CV','KNN-W2V'RF-GLOVE','NB-W2V"

# %%
train_labels=train_labels_2
val_labels=val_labels_2
test_labels=test_labels_2
val_df = pd.read_csv("/content/Data/liar/Caso2/prob_val_2_b.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso2/prob_test_2_b.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['SVM-GLOVE','CNN-FAST','MLP-TFIDF','EXTRA-CV','KNN-W2V','RF-GLOVE','NB-W2V']
names = 'SVM-GLOVE|CNN-FAST|MLP-TFIDF|EXTRA-CV|KNN-W2V|RF-GLOVE|NB-W2V'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results D 1 a:  [0.599 0.599 0.599 0.599 0.599 0.599 0.599]
# results mean D 1 a:  0.599

# %% [markdown]
# #####c

# %%
texte="EXTRA-GLOVE, SVM-TFIDF, CNN-CV, NB-W2V, MLP-FAST, SVM-CV, NB-TFIDF, ,KNN-TFIDF"
texte.replace(",","|").replace(" ","")
# Out:
# 'EXTRA-GLOVE|SVM-TFIDF|CNN-CV|NB-W2V|MLP-FAST|SVM-CV|NB-TFIDF||KNN-TFIDF'

# %%
texte2="EXTRA-GLOVE, SVM-TFIDF, CNN-CV, NB-W2V, MLP-FAST, SVM-CV, NB-TFIDF, ,KNN-TFIDF"
texte2.replace(" "," '").replace(",","'").replace(" ",",")
# Out:
# "EXTRA-GLOVE','SVM-TFIDF','CNN-CV','NB-W2V','MLP-FAST','SVM-CV','NB-TFIDF',''KNN-TFIDF"

# %%
train_labels=train_labels_3
val_labels=val_labels_3
test_labels=test_labels_3
val_df = pd.read_csv("/content/Data/liar/Caso2/prob_val_2_c.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso2/prob_test_2_c.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['EXTRA-GLOVE','SVM-TFIDF','CNN-CV','NB-W2V','MLP-FAST','SVM-CV','NB-TFIDF','KNN-TFIDF']
names = 'EXTRA-GLOVE|SVM-TFIDF|CNN-CV|NB-W2V|MLP-FAST|SVM-CV|NB-TFIDF||KNN-TFIDF'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ",round(results_D.mean(),3))
# Out:
# results D 1 a:  [0.662 0.662 0.662 0.662 0.662 0.662 0.662 0.662]
# results mean D 1 a:  0.662

# %% [markdown]
# #### Best

# %% [markdown]
# ##### a

# %%
texte="SVM-W2V,EXTRA-TFIDF,LR-FAST,NB-CV,MLP-FAST,LR-GLOVE,MLP-W2V,CNN-FAST,CNN-TFIDF"
texte.replace(",","|").replace(" ","")
# Out:
# 'SVM-W2V|EXTRA-TFIDF|LR-FAST|NB-CV|MLP-FAST|LR-GLOVE|MLP-W2V|CNN-FAST|CNN-TFIDF'

# %%
texte2="SVM-W2V,EXTRA-TFIDF,LR-FAST,NB-CV,MLP-FAST,LR-GLOVE,MLP-W2V,CNN-FAST,CNN-TFIDF"
texte2.replace(" "," '").replace(",","'").replace(" ",",")
# Out:
# "SVM-W2V'EXTRA-TFIDF'LR-FAST'NB-CV'MLP-FAST'LR-GLOVE'MLP-W2V'CNN-FAST'CNN-TFIDF"

# %%
train_labels=train_labels_1
val_labels=val_labels_1
test_labels=test_labels_1
val_df = pd.read_csv("/content/Data/liar/Caso2/prob_val_2_a.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso2/prob_test_2_a.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['SVM-W2V','EXTRA-TFIDF','LR-FAST','NB-CV','MLP-FAST','LR-GLOVE','MLP-W2V','CNN-FAST','CNN-TFIDF']
names = 'SVM-W2V|EXTRA-TFIDF|LR-FAST|NB-CV|MLP-FAST|LR-GLOVE|MLP-W2V|CNN-FAST|CNN-TFIDF'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results D 1 a:  [0.245 0.245 0.245 0.245 0.245 0.245 0.245 0.245 0.245]
# results mean D 1 a:  0.245

# %% [markdown]
# #####b

# %%
texte=" SVM-W2V, SVM-GLOVE, EXTRA-TFIDF, SVM-TFIDF, NB-FAST, NB-TFIDF, KNN-W2V"
texte.replace(",","|").replace(" ","")
# Out:
# 'SVM-W2V|SVM-GLOVE|EXTRA-TFIDF|SVM-TFIDF|NB-FAST|NB-TFIDF|KNN-W2V'

# %%
texte2=" SVM-W2V, SVM-GLOVE, EXTRA-TFIDF, SVM-TFIDF, NB-FAST, NB-TFIDF, KNN-W2V"
texte2.replace(" "," '").replace(",","'").replace(" ",",")
# Out:
# ",'SVM-W2V','SVM-GLOVE','EXTRA-TFIDF','SVM-TFIDF','NB-FAST','NB-TFIDF','KNN-W2V"

# %%
train_labels=train_labels_2
val_labels=val_labels_2
test_labels=test_labels_2
val_df = pd.read_csv("/content/Data/liar/Caso2/prob_val_2_b.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso2/prob_test_2_b.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['SVM-W2V','SVM-GLOVE','EXTRA-TFIDF','SVM-TFIDF','NB-FAST','NB-TFIDF','KNN-W2V']
names = 'SVM-W2V|SVM-GLOVE|EXTRA-TFIDF|SVM-TFIDF|NB-FAST|NB-TFIDF|KNN-W2V'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results D 1 a:  [0.599 0.599 0.599 0.599 0.599 0.599 0.599]
# results mean D 1 a:  0.599

# %% [markdown]
# #####c

# %%
texte="SVM-W2V, LR-TFIDF, RF-CV, CNN-GLOVE, MLP-W2V, CNN-TFIDF, CNN-W2V, NB-CV"
texte.replace(",","|").replace(" ","")
# Out:
# 'SVM-W2V|LR-TFIDF|RF-CV|CNN-GLOVE|MLP-W2V|CNN-TFIDF|CNN-W2V|NB-CV'

# %%
texte2="SVM-W2V, LR-TFIDF, RF-CV, CNN-GLOVE, MLP-W2V, CNN-TFIDF, CNN-W2V, NB-CV"
texte2.replace(" "," '").replace(",","'").replace(" ",",")
# Out:
# "SVM-W2V','LR-TFIDF','RF-CV','CNN-GLOVE','MLP-W2V','CNN-TFIDF','CNN-W2V','NB-CV"

# %%
train_labels=train_labels_3
val_labels=val_labels_3
test_labels=test_labels_3
val_df = pd.read_csv("/content/Data/liar/Caso2/prob_val_2_c.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso2/prob_test_2_c.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['SVM-W2V','LR-TFIDF','RF-CV','CNN-GLOVE','MLP-W2V','CNN-TFIDF','CNN-W2V','NB-CV']
names = 'SVM-W2V|LR-TFIDF|RF-CV|CNN-GLOVE|MLP-W2V|CNN-TFIDF|CNN-W2V|NB-CV'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results D 1 a:  [0.667 0.667 0.667 0.667 0.667 0.667 0.667 0.667]
# results mean D 1 a:  0.667

# %% [markdown]
# ### Caso 3 - Pre process 3

# %% [markdown]
# #### Any Diversity

# %% [markdown]
# ##### a

# %%
texte="CNN-TFIDF, MLP-CV; KNN-TFIDF, MLP-W2V, LR-GLOVE, SVM-FAST, KNN-GLOVE, MLP-TFIDF, NB-FAST, NB-CV, RF-CV"
texte.replace(",","|").replace(" ","")
# Out:
# 'CNN-TFIDF|MLP-CV;KNN-TFIDF|MLP-W2V|LR-GLOVE|SVM-FAST|KNN-GLOVE|MLP-TFIDF|NB-FAST|NB-CV|RF-CV'

# %%
texte2="CNN-TFIDF, MLP-CV; KNN-TFIDF, MLP-W2V, LR-GLOVE, SVM-FAST, KNN-GLOVE, MLP-TFIDF, NB-FAST, NB-CV, RF-CV"
texte2.replace(" "," '").replace(",","'").replace(" ",",")
# Out:
# "CNN-TFIDF','MLP-CV;,'KNN-TFIDF','MLP-W2V','LR-GLOVE','SVM-FAST','KNN-GLOVE','MLP-TFIDF','NB-FAST','NB-CV','RF-CV"

# %%
train_labels=train_labels_1
val_labels=val_labels_1
test_labels=test_labels_1
val_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_val_3_a.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_test_3_a.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","Unnamed: 0.1","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","Unnamed: 0.1","label"]), test_labels["label"]

# %%
#group A------------------------------------------------------------------------
algorithms_list = ['SVM', 'LR','RF','NB','MLP', 'EXTRA','KNN','CNN']
stacking = LogisticRegression(class_weight='balanced',multi_class='multinomial')
results_A = np.zeros(len(algorithms_list))
for idx_alg, algorithm in enumerate(algorithms_list):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, algorithm)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking.fit(X_val, labels_val)
  y_pred = stacking.predict(X_test)
  score = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
  results_A[idx_alg] = score
print("results A - Caso 1 a: ", results_A)
print("results A - Caso 1 a: ", round(results_A.mean(),3))

#group B -----------------------------------------------------------------------
fe_list = ['CV', 'TFIDF', 'W2V', 'GLOVE', 'FAST']
results_B = np.zeros(len(fe_list))
for idx_alg, fe in enumerate(fe_list):
    X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, fe)
    X_val, X_test = filter_collinearity(X_val, X_test)
    stacking.fit(X_val, labels_val)
    y_pred = stacking.predict(X_test)
    results_B[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#     generate_confusion_matrix(stacking, X_test, labels_test, name)
print("resultsB - Caso 1 a: ", results_B)
print("resultsB - Caso 1 a: ", round(results_B.mean(),3))

#group C -----------------------------------------------------------------------
results_C = 0
stacking_C = LogisticRegression()
X_val, X_test = filter_collinearity(probas_val.to_numpy(), probas_test.to_numpy())
stacking_C.fit(X_val, labels_val)
y_pred = stacking_C.predict(X_test)
results_C = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp = plot_confusion_matrix(stacking_C, X_test, labels_test, cmap=plt.cm.Blues, 
#                             display_labels=['False','Half-true','Mostly-true','True','Barely-true','Pants-fire'])
                             #['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
print("resultsC - Caso 1 a: ", results_C)
#disp.ax_.set_title("Confusion Matrix - Group C")
#plt.rcParams["figure.figsize"] = (10,8)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GROUP_C_Caso_1_a.pdf', dpi=300)

#group D------------------------------------------------------------------------
models_D = ['CNN-TFIDF','MLP-CV','KNN-TFIDF','MLP-W2V','LR-GLOVE','SVM-FAST','KNN-GLOVE','MLP-TFIDF','NB-FAST','NB-CV','RF-CV']
names = 'CNN-TFIDF|MLP-CV|KNN-TFIDF|MLP-W2V|LR-GLOVE|SVM-FAST|KNN-GLOVE|MLP-TFIDF|NB-FAST|NB-CV|RF-CV'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results A - Caso 1 a:  [0.205 0.197 0.198 0.191 0.205 0.227 0.181 0.213]
# results A - Caso 1 a:  0.202
# resultsB - Caso 1 a:  [0.186 0.213 0.208 0.186 0.21 ]
# resultsB - Caso 1 a:  0.201
# resultsC - Caso 1 a:  0.222
# results D 1 a:  [0.241 0.241 0.241 0.241 0.241 0.241 0.241 0.241 0.241 0.241 0.241]
# results mean D 1 a:  0.241

# %% [markdown]
# ##### b

# %%
texte="CNN-GLOVE,CNN-W2V, CNN-TFIDF, KNN-W2V, EXTRA-CV, LR-TFIDF, MLP-TFIDF"
texte.replace(",","|").replace(" ","")
# Out:
# 'CNN-GLOVE|CNN-W2V|CNN-TFIDF|KNN-W2V|EXTRA-CV|LR-TFIDF|MLP-TFIDF'

# %%
texte2="CNN-GLOVE,CNN-W2V, CNN-TFIDF, KNN-W2V, EXTRA-CV, LR-TFIDF, MLP-TFIDF"
texte2.replace(" "," '").replace(",","'").replace(" ",",")
# Out:
# "CNN-GLOVE'CNN-W2V','CNN-TFIDF','KNN-W2V','EXTRA-CV','LR-TFIDF','MLP-TFIDF"

# %%
train_labels=train_labels_2
val_labels=val_labels_2
test_labels=test_labels_2
val_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_val_3_b.csv").dropna(axis=1)
test_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_test_3_b.csv").dropna(axis=1)

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]

# %%
probas_val
# Out:
#       Unnamed: 0.1  SVM-CV-0  SVM-CV-1  SVM-TFIDF-0  SVM-TFIDF-1  SVM-W2V-0  \
# 0                0  0.599114  0.400886     0.604501     0.395499   0.639186
# 1                1  0.508662  0.491338     0.444750     0.555250   0.535906
# 2                2  0.614589  0.385411     0.623319     0.376681   0.592335
# 3                3  0.588226  0.411774     0.570243     0.429757   0.540070
# 4                4  0.568638  0.431362     0.567497     0.432503   0.622468
# ...            ...       ...       ...          ...          ...        ...
# 1279          1279  0.603610  0.396390     0.617298     0.382702   0.595561
# 1280          1280  0.605797  0.394203     0.629078     0.370922   0.669721
# 1281          1281  0.586994  0.413006     0.538123     0.461877   0.573327
# 1282          1282  0.584934  0.415066     0.561662     0.438338   0.589426
# 1283          1283  0.603185  0.396815     0.632388     0.367612   0.623136
#
#       SVM-W2V-1  SVM-GLOVE-0  SVM-GLOVE-1  SVM-FAST-0  ...  CNN-CV-0  \
# 0      0.360814     0.614435     0.385565    0.600947  ...  0.484138
# 1      0.464094     0.594090     0.405910    0.543284  ...  0.485816
# 2      0.407665     0.609207     0.390793    0.611547  ...  0.511349
# 3      0.459930     0.576133     0.423867    0.619295  ...  0.524552
# 4      0.377532     0.611024     0.388976    0.618566  ...  0.557591
# ...         ...          ...          ...         ...  ...       ...
# 1279   0.404439     0.593251     0.406749    0.617412  ...  0.534842
# 1280   0.330279     0.616162     0.383838    0.626413  ...  0.546001
# 1281   0.426673     0.555313     0.444687    0.567544  ...  0.522058
# 1282   0.410574     0.586960     0.413040    0.599380  ...  0.613847
# 1283   0.376864     0.566943     0.433057    0.606931  ...  0.518132
#
#       CNN-CV-1  CNN-TF-0  CNN-TF-1  CNN-W2V-0  CNN-W2V-1  CNN-GLOVE-0  \
# 0     0.508460  0.475411  0.522680   0.586211   0.434649     0.569233
# 1     0.506301  0.478224  0.519655   0.132647   0.885598     0.487591
# 2     0.481622  0.481733  0.516045   0.578458   0.434118     0.538452
# 3     0.468588  0.493846  0.503435   0.515974   0.473020     0.515779
# 4     0.435903  0.492964  0.503893   0.545579   0.468398     0.635594
# ...        ...       ...       ...        ...        ...          ...
# 1279  0.458611  0.481830  0.515422   0.572354   0.466401     0.577932
# 1280  0.447517  0.492907  0.504182   0.677120   0.341567     0.552459
# 1281  0.470624  0.480333  0.517486   0.303766   0.697877     0.475438
# 1282  0.383199  0.571847  0.426017   0.303137   0.663135     0.551723
# 1283  0.474810  0.486640  0.511193   0.423573   0.617873     0.530743
#
#       CNN-GLOVE-1  CNN-FAST-0  CNN-FAST-1
# 0        0.526344    0.619258    0.391420
# 1        0.536289    0.416712    0.588869
# 2        0.532079    0.280676    0.718376
# 3        0.520698    0.495863    0.508940
# 4        0.485545    0.562797    0.454498
# ...           ...         ...         ...
# 1279     0.517800    0.602965    0.399954
# 1280     0.498106    0.704898    0.294150
# 1281     0.553074    0.383873    0.611637
# 1282     0.502648    0.419441    0.583421
# 1283     0.522311    0.560057    0.421700
#
# [1284 rows x 81 columns]

# %%
#group A------------------------------------------------------------------------
algorithms_list = ['SVM', 'LR','RF','NB','MLP', 'EXTRA','KNN','CNN']
stacking = LogisticRegression(class_weight='balanced',multi_class='multinomial')
results_A = np.zeros(len(algorithms_list))
for idx_alg, algorithm in enumerate(algorithms_list):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, algorithm)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking.fit(X_val, labels_val)
  y_pred = stacking.predict(X_test)
  score = accuracy_score(labels_test, y_pred)#,average='macro')
  results_A[idx_alg] = round(score,3)
print("results A - Caso 1 a: ", results_A)
print("results A - Caso 1 a: ", round(results_A.mean(),3))

#group B -----------------------------------------------------------------------
fe_list = ['CV', 'TFIDF', 'W2V', 'GLOVE', 'FAST']
results_B = np.zeros(len(fe_list))
for idx_alg, fe in enumerate(fe_list):
    X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, fe)
    X_val, X_test = filter_collinearity(X_val, X_test)
    stacking.fit(X_val, labels_val)
    y_pred = stacking.predict(X_test)
    results_B[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#     generate_confusion_matrix(stacking, X_test, labels_test, name)
print("resultsB - Caso 1 a: ", results_B)
print("resultsB - Caso 1 a: ", round(results_B.mean(),3))

#group C -----------------------------------------------------------------------
results_C = 0
stacking_C = LogisticRegression()
X_val, X_test = filter_collinearity(probas_val.to_numpy(), probas_test.to_numpy())
stacking_C.fit(X_val, labels_val)
y_pred = stacking_C.predict(X_test)
results_C = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp = plot_confusion_matrix(stacking_C, X_test, labels_test, cmap=plt.cm.Blues, 
#                             display_labels=['False','Half-true','Mostly-true','True','Barely-true','Pants-fire'])
                             #['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
print("resultsC - Caso 1 a: ", results_C)
#disp.ax_.set_title("Confusion Matrix - Group C")
#plt.rcParams["figure.figsize"] = (10,8)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GROUP_C_Caso_1_a.pdf', dpi=300)

#group D------------------------------------------------------------------------
models_D = ['CNN-GLOVE','CNN-W2V','CNN-TFIDF','KNN-W2V','EXTRA-CV','LR-TFIDF','MLP-TFIDF']
names = 'CNN-GLOVE|CNN-W2V|CNN-TFIDF|KNN-W2V|EXTRA-CV|LR-TFIDF|MLP-TFIDF'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results A - Caso 1 a:  [0.539 0.526 0.551 0.507 0.52  0.545 0.5   0.544]
# results A - Caso 1 a:  0.529
# resultsB - Caso 1 a:  [0.528 0.535 0.534 0.539 0.542]
# resultsB - Caso 1 a:  0.536
# resultsC - Caso 1 a:  0.58
# results D 1 a:  [0.6 0.6 0.6 0.6 0.6 0.6 0.6]
# results mean D 1 a:  0.6

# %% [markdown]
# ##### c

# %%
texte=" MLP-W2V, CNN-CV, RF-CV, NB-CV, CNN-GLOVE, EXTRA-GLOVE, NB-W2V, NB-GLOVE, LR-FAST, SVM-CV, SVM-TFIDF"
texte.replace(",","|").replace(" ","")
# Out:
# 'MLP-W2V|CNN-CV|RF-CV|NB-CV|CNN-GLOVE|EXTRA-GLOVE|NB-W2V|NB-GLOVE|LR-FAST|SVM-CV|SVM-TFIDF'

# %%
texte2=" MLP-W2V, CNN-CV, RF-CV, NB-CV, CNN-GLOVE, EXTRA-GLOVE, NB-W2V, NB-GLOVE, LR-FAST, SVM-CV, SVM-TFIDF"
texte2.replace(" "," '").replace(",","'").replace(" ",",")
# Out:
# ",'MLP-W2V','CNN-CV','RF-CV','NB-CV','CNN-GLOVE','EXTRA-GLOVE','NB-W2V','NB-GLOVE','LR-FAST','SVM-CV','SVM-TFIDF"

# %%
train_labels=train_labels_3
val_labels=val_labels_3
test_labels=test_labels_3
val_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_val_3_c.csv").dropna(axis=1)
test_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_test_3_c.csv").dropna(axis=1)

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]

#group A------------------------------------------------------------------------
algorithms_list = ['SVM', 'LR','RF','NB','MLP', 'EXTRA','KNN','CNN']
stacking = LogisticRegression(class_weight='balanced',multi_class='multinomial')
results_A = np.zeros(len(algorithms_list))
for idx_alg, algorithm in enumerate(algorithms_list):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, algorithm)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking.fit(X_val, labels_val)
  y_pred = stacking.predict(X_test)
  score = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
  results_A[idx_alg] = score
print("results A - Caso 1 a: ", results_A)
print("results A - Caso 1 a: ", round(results_A.mean(),3))

#group B -----------------------------------------------------------------------
fe_list = ['CV', 'TFIDF', 'W2V', 'GLOVE', 'FAST']
results_B = np.zeros(len(fe_list))
for idx_alg, fe in enumerate(fe_list):
    X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, fe)
    X_val, X_test = filter_collinearity(X_val, X_test)
    stacking.fit(X_val, labels_val)
    y_pred = stacking.predict(X_test)
    results_B[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#     generate_confusion_matrix(stacking, X_test, labels_test, name)
print("resultsB - Caso 1 a: ", results_B)
print("resultsB - Caso 1 a: ", round(results_B.mean(),3))

#group C -----------------------------------------------------------------------
results_C = 0
stacking_C = LogisticRegression()
X_val, X_test = filter_collinearity(probas_val.to_numpy(), probas_test.to_numpy())
stacking_C.fit(X_val, labels_val)
y_pred = stacking_C.predict(X_test)
results_C = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp = plot_confusion_matrix(stacking_C, X_test, labels_test, cmap=plt.cm.Blues, 
#                             display_labels=['False','Half-true','Mostly-true','True','Barely-true','Pants-fire'])
                             #['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
print("resultsC - Caso 1 a: ", results_C)
#disp.ax_.set_title("Confusion Matrix - Group C")
#plt.rcParams["figure.figsize"] = (10,8)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GROUP_C_Caso_1_a.pdf', dpi=300)

#group D------------------------------------------------------------------------
models_D = ['MLP-W2V','CNN-CV','RF-CV','NB-CV','CNN-GLOVE','EXTRA-GLOVE','NB-W2V','NB-GLOVE','LR-FAST','SVM-CV','SVM-TFIDF']

names = 'MLP-W2V|CNN-CV|RF-CV|NB-CV|CNN-GLOVE|EXTRA-GLOVE|NB-W2V|NB-GLOVE|LR-FAST|SVM-CV|SVM-TFIDF'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results A - Caso 1 a:  [0.624 0.625 0.61  0.613 0.613 0.598 0.582 0.592]
# results A - Caso 1 a:  0.607
# resultsB - Caso 1 a:  [0.568 0.608 0.631 0.599 0.624]
# resultsB - Caso 1 a:  0.606
# resultsC - Caso 1 a:  0.673
# results D 1 a:  [0.652 0.652 0.652 0.652 0.652 0.652 0.652 0.652 0.652 0.652 0.652]
# results mean D 1 a:  0.652

# %% [markdown]
# #### Varying Tecniques

# %% [markdown]
# ##### a

# %%
texte="LR-GLOVE, SVM-FAST, NB-W2V, CNN-CV, MLP-TFIDF,RF-CV, EXTRA-GLOVE, NB-TFIDF,LR-W2V, KNN-FAST, MLP-CV"
texte.replace(",","|").replace(" ","")
# Out:
# 'LR-GLOVE|SVM-FAST|NB-W2V|CNN-CV|MLP-TFIDF|RF-CV|EXTRA-GLOVE|NB-TFIDF|LR-W2V|KNN-FAST|MLP-CV'

# %%
texte2="LR-GLOVE, SVM-FAST, NB-W2V, CNN-CV, MLP-TFIDF,RF-CV, EXTRA-GLOVE, NB-TFIDF,LR-W2V, KNN-FAST, MLP-CV"
texte2.replace(" "," '").replace(",","'").replace(" ",",")
# Out:
# "LR-GLOVE','SVM-FAST','NB-W2V','CNN-CV','MLP-TFIDF'RF-CV','EXTRA-GLOVE','NB-TFIDF'LR-W2V','KNN-FAST','MLP-CV"

# %%
train_labels=train_labels_1
val_labels=val_labels_1
test_labels=test_labels_1
val_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_val_3_a.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_test_3_a.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['LR-GLOVE','SVM-FAST','NB-W2V','CNN-CV','MLP-TFIDF','RF-CV','EXTRA-GLOVE','NB-TFIDF','LR-W2V','KNN-FAST','MLP-CV']
names = 'LR-GLOVE|SVM-FAST|NB-W2V|CNN-CV|MLP-TFIDF|RF-CV|EXTRA-GLOVE|NB-TFIDF|LR-W2V|KNN-FAST|MLP-CV'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results D 1 a:  [0.235 0.235 0.235 0.235 0.235 0.235 0.235 0.235 0.235 0.235 0.235]
# results mean D 1 a:  0.235

# %% [markdown]
# ##### b

# %%
texte="KNN-FAST, EXTRA-TFIDF, CNN-CV, NB-W2V, RF-GLOVE, LR-TFIDF, NB-GLOVE"
texte.replace(",","|").replace(" ","")
# Out:
# 'KNN-FAST|EXTRA-TFIDF|CNN-CV|NB-W2V|RF-GLOVE|LR-TFIDF|NB-GLOVE'

# %%
texte2="KNN-FAST, EXTRA-TFIDF, CNN-CV, NB-W2V, RF-GLOVE, LR-TFIDF, NB-GLOVE"
texte2.replace(" "," '").replace(",","'").replace(" ",",")
# Out:
# "KNN-FAST','EXTRA-TFIDF','CNN-CV','NB-W2V','RF-GLOVE','LR-TFIDF','NB-GLOVE"

# %%
train_labels=train_labels_2
val_labels=val_labels_2
test_labels=test_labels_2
val_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_val_3_b.csv").dropna(axis=1)
test_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_test_3_b.csv").dropna(axis=1)

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['KNN-FAST','EXTRA-TFIDF','CNN-CV','NB-W2V','RF-GLOVE','LR-TFIDF','NB-GLOVE']
names = 'KNN-FAST|EXTRA-TFIDF|CNN-CV|NB-W2V|RF-GLOVE|LR-TFIDF|NB-GLOVE'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = round(accuracy_score(labels_test, y_pred),3)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ",round(results_D.mean(),3))
# Out:
# results D 1 a:  [0.596 0.596 0.596 0.596 0.596 0.596 0.596]
# results mean D 1 a:  0.596

# %% [markdown]
# ##### c

# %%
texte="SVM-FAST, NB-CV, NB-W2V, LR-GLOVE, EXTRA-TFIDF, MLP-CV, RF-W2V, MLP-TFIDF, CNN-CV, KNN-FAST, SVM-GLOVE"
texte.replace(",","|").replace(" ","")
# Out:
# 'SVM-FAST|NB-CV|NB-W2V|LR-GLOVE|EXTRA-TFIDF|MLP-CV|RF-W2V|MLP-TFIDF|CNN-CV|KNN-FAST|SVM-GLOVE'

# %%
texte2="SVM-FAST, NB-CV, NB-W2V, LR-GLOVE, EXTRA-TFIDF, MLP-CV, RF-W2V, MLP-TFIDF, CNN-CV, KNN-FAST, SVM-GLOVE"
texte2.replace(" "," '").replace(",","'").replace(" ",",")
# Out:
# "SVM-FAST','NB-CV','NB-W2V','LR-GLOVE','EXTRA-TFIDF','MLP-CV','RF-W2V','MLP-TFIDF','CNN-CV','KNN-FAST','SVM-GLOVE"

# %%
train_labels=train_labels_3
val_labels=val_labels_3
test_labels=test_labels_3
val_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_val_3_c.csv").dropna(axis=1)
test_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_test_3_c.csv").dropna(axis=1)

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['SVM-FAST','NB-CV','NB-W2V','LR-GLOVE','EXTRA-TFIDF','MLP-CV','RF-W2V','MLP-TFIDF','CNN-CV','KNN-FAST','SVM-GLOVE']
names = 'SVM-FAST|NB-CV|NB-W2V|LR-GLOVE|EXTRA-TFIDF|MLP-CV|RF-W2V|MLP-TFIDF|CNN-CV|KNN-FAST|SVM-GLOVE'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = accuracy_score(labels_test, y_pred)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results D 1 a:  [0.65315666 0.65315666 0.65315666 0.65315666 0.65315666 0.65315666
#  0.65315666 0.65315666 0.65315666 0.65315666 0.65315666]
# results mean D 1 a:  0.653

# %% [markdown]
# #### Best

# %% [markdown]
# ##### a

# %%
texte="SVM-W2V,RF-TFIDF, LR-FAST, RF-FAST, NB-CV, MLP-FAST, LR-GLOVE, LR-TFIDF, SVM-CV, CNN-TFIDF, NB-FAST"
texte.replace(",","|").replace(" ","")
# Out:
# 'SVM-W2V|RF-TFIDF|LR-FAST|RF-FAST|NB-CV|MLP-FAST|LR-GLOVE|LR-TFIDF|SVM-CV|CNN-TFIDF|NB-FAST'

# %%
texte2="SVM-W2V,RF-TFIDF, LR-FAST, RF-FAST, NB-CV, MLP-FAST, LR-GLOVE, LR-TFIDF, SVM-CV, CNN-TFIDF, NB-FAST"
texte2.replace(" "," '").replace(",","'").replace(" ",",")
# Out:
# "SVM-W2V'RF-TFIDF','LR-FAST','RF-FAST','NB-CV','MLP-FAST','LR-GLOVE','LR-TFIDF','SVM-CV','CNN-TFIDF','NB-FAST"

# %%
train_labels=train_labels_1
val_labels=val_labels_1
test_labels=test_labels_1
val_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_val_3_a.csv").dropna(axis=1)
test_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_test_3_a.csv").dropna(axis=1)

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['SVM-W2V','RF-TFIDF','LR-FAST','RF-FAST','NB-CV','MLP-FAST','LR-GLOVE','LR-TFIDF','SVM-CV','CNN-TFIDF','NB-FAST']
names = 'SVM-W2V|RF-TFIDF|LR-FAST|RF-FAST|NB-CV|MLP-FAST|LR-GLOVE|LR-TFIDF|SVM-CV|CNN-TFIDF|NB-FAST'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = accuracy_score(labels_test, y_pred)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results D 1 a:  [0.25643024 0.25643024 0.25643024 0.25643024 0.25643024 0.25643024
#  0.25643024 0.25643024 0.25643024 0.25643024 0.25643024]
# results mean D 1 a:  0.256

# %% [markdown]
# ##### b

# %%
texte="SVM-W2V,LR-TFIDF,EXTRA-TFIDF,CNN-GLOVE, NB-FAST, KNN-FAST, CNN-FAST"
texte.replace(",","|").replace(" ","")
# Out:
# 'SVM-W2V|LR-TFIDF|EXTRA-TFIDF|CNN-GLOVE|NB-FAST|KNN-FAST|CNN-FAST'

# %%
texte2="SVM-W2V,LR-TFIDF,EXTRA-TFIDF,CNN-GLOVE, NB-FAST, KNN-FAST, CNN-FAST"
texte2.replace(" "," '").replace(",","'").replace(" ",",")
# Out:
# "SVM-W2V'LR-TFIDF'EXTRA-TFIDF'CNN-GLOVE','NB-FAST','KNN-FAST','CNN-FAST"

# %%
train_labels=train_labels_2
val_labels=val_labels_2
test_labels=test_labels_2
val_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_val_3_b.csv").dropna(axis=1)
test_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_test_3_b.csv").dropna(axis=1)

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['SVM-W2V','LR-TFIDF','EXTRA-TFIDF','CNN-GLOVE','NB-FAST','KNN-FAST','CNN-FAST']
names = 'SVM-W2V|LR-TFIDF|EXTRA-TFIDF|CNN-GLOVE|NB-FAST|KNN-FAST|CNN-FAST'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = accuracy_score(labels_test, y_pred)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results D 1 a:  [0.59703819 0.59703819 0.59703819 0.59703819 0.59703819 0.59703819
#  0.59703819]
# results mean D 1 a:  0.597

# %% [markdown]
# ##### c

# %%
texte="LR-FAST, RF-TFIDF, LR-W2V, SVM-W2V, EXTRA-FAST, NB-GLOVE, LR-TFIDF, CNN-CV, NB-W2V, NB-TFIDF, MLP-TFIDF"
texte.replace(",","|").replace(" ","")
# Out:
# 'LR-FAST|RF-TFIDF|LR-W2V|SVM-W2V|EXTRA-FAST|NB-GLOVE|LR-TFIDF|CNN-CV|NB-W2V|NB-TFIDF|MLP-TFIDF'

# %%
texte2="LR-FAST, RF-TFIDF, LR-W2V, SVM-W2V, EXTRA-FAST, NB-GLOVE, LR-TFIDF, CNN-CV, NB-W2V, NB-TFIDF, MLP-TFIDF"
texte2.replace(" "," '").replace(",","'").replace(" ",",")
# Out:
# "LR-FAST','RF-TFIDF','LR-W2V','SVM-W2V','EXTRA-FAST','NB-GLOVE','LR-TFIDF','CNN-CV','NB-W2V','NB-TFIDF','MLP-TFIDF"

# %%
train_labels=train_labels_3
val_labels=val_labels_3
test_labels=test_labels_3
val_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_val_3_c.csv").dropna(axis=1)
test_df = pd.read_csv("/content/Data/liar/Caso3/union/prob_test_3_c.csv").dropna(axis=1)

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]
#group D------------------------------------------------------------------------
models_D =['LR-FAST','RF-TFIDF','LR-W2V','SVM-W2V','EXTRA-FAST','NB-GLOVE','LR-TFIDF','CNN-CV','NB-W2V','NB-TFIDF','MLP-TFIDF']
names = 'LR-FAST|RF-TFIDF|LR-W2V|SVM-W2V|EXTRA-FAST|NB-GLOVE|LR-TFIDF|CNN-CV|NB-W2V|NB-TFIDF|MLP-TFIDF'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = accuracy_score(labels_test, y_pred)#,average='macro')
#disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
#display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
#disp.ax_.set_title("Confusion Matrix - Group D")
#plt.rcParams["figure.figsize"] = (25,15)
#plt.tight_layout()
#plt.savefig('confusion_matrix_GroupD_Caso_1_a.pdf', dpi=300)
print("results D 1 a: ",results_D)
print("results mean D 1 a: ", round(results_D.mean(),3))
# Out:
# results D 1 a:  [0.66017147 0.66017147 0.66017147 0.66017147 0.66017147 0.66017147
#  0.66017147 0.66017147 0.66017147 0.66017147 0.66017147]
# results mean D 1 a:  0.66

# %% [markdown]
# ## Best Monolitichs

# %%
table=pd.read_csv('/content/Data/liar/Caso1/pred_test_1_a.csv')
label_list=np.array(table['label'])
for column in table.columns:
  pred_list=np.array(table[column])
  print(accuracy_score(label_list,pred_list),column)
# Out:
# 0.0 Unnamed: 0
# 1.0 label
# 0.23148869836321123 SVM-CV
# 0.2244738893219018 SVM-TFIDF
# 0.24785658612626657 SVM-W2V
# 0.23928293063133282 SVM-GLOVE
# 0.24162120031176929 SVM-FAST
# 0.23148869836321123 LR-CV
# 0.24006235385814498 LR-TFIDF
# 0.23694466095089634 LR-GLOVE
# 0.24473889321901793 LR-W2V
# 0.24006235385814498 LR-FAST
# 0.24318004676539362 RF-CV
# 0.25565081839438814 RF-TFIDF
# 0.20810600155884645 RF-GLOVE
# 0.24785658612626657 RF-W2V
# 0.2338269680436477 RF-FAST
# 0.24629773967264224 NB-CV
# 0.24395946999220577 NB-TFIDF
# 0.24162120031176929 NB-GLOVE
# 0.2338269680436477 NB-W2V
# 0.2221356196414653 NB-FAST
# 0.21434138737334374 MLP-CV
# 0.22525331254871395 MLP-TFIDF
# 0.23616523772408418 MLP-GLOVE
# 0.23694466095089634 MLP-W2V
# 0.25175370226032734 MLP-FAST
# 0.23694466095089634 EXTRA-CV
# 0.25019485580670303 EXTRA-TFIDF
# 0.2299298519095869 EXTRA-GLOVE
# 0.22525331254871395 EXTRA-W2V
# 0.23226812159002339 EXTRA-FAST
# 0.2260327357755261 KNN-CV
# 0.2073265783320343 KNN-TFIDF
# 0.18550272798129383 KNN-GLOVE
# 0.2127825409197194 KNN-W2V
# 0.20810600155884645 KNN-FAST
# 0.23928293063133282 CNN-CV
# 0.20966484801247076 CNN-TFIDF
# 0.2182385035074045 CNN-W2V
# 0.23850350740452064 CNN-GLOVE
# 0.2260327357755261 CNN-FAST

# %%
#cluster 1: KNN (w2v,fast,glove), RF (glove, fast), Extra (glove)* -> RF_FAST
#cluster 2: SVM e LR (fast) -> SVM-FAST
#cluster 3: NB e CNN (w2v), NB (fast) -> NB-W2V
#cluster 4: NB, LR, MLP (glove) e SVM (w2v) -> SVM-W2V
#cluster 5: MLP(tfidf), SVM(cv) -> SVM-CV
#cluster 6: MLP,LR(w2v), SVM(glove), MLP(fast) -> LR-W2V
#cluster 7: LR, MLP (cv), LR e SVM(tfidf) -> LR-TFIDF
#cluster 8: NB(cv e tfidf) -> NB-CV
#cluster 9: extra (cv,tfidf) , rf (cv,tfidf) -> RF-TFIDF
#cluster 10: extra (fast,w2v), rf (w2v), cnn (fast,glove,tfidf,cv), knn(cv,tfidf) -> RF-W2V

# %%
models_D = ['RF-FAST','SVM-FAST','NB-W2V','SVM-W2V','SVM-CV','LR-W2V','LR-TFIDF','NB-CV','RF-TFIDF','RF-W2V']
names = 'RF-FAST|SVM-FAST|NB-W2V|SVM-W2V|SVM-CV|LR-W2V|LR-TFIDF|NB-CV|RF-TFIDF|RF-W2V'
results_D = np.zeros(len(models_D))
stacking_D = LogisticRegression()
for idx_alg, fe in enumerate(models_D):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, names)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking_D.fit(X_val, labels_val)
  y_pred = stacking_D.predict(X_test)
  results_D[idx_alg] = f1_score(labels_test, y_pred,average='macro')
disp=plot_confusion_matrix(stacking_D, X_test, labels_test, cmap=plt.cm.Blues,
display_labels=['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
disp.ax_.set_title("Confusion Matrix - Group D")
plt.rcParams["figure.figsize"] = (25,15)
plt.tight_layout()
plt.savefig('confusion_matrix_GroupD_Caso_1_a_best_monolitics.pdf', dpi=300)
print("results D 1 a best monolitics",results_D)
print("results mean D 1 a best monolitics",results_D.mean())
# Out:
# results D 1 a best monolitics [0.18486632 0.18486632 0.18486632 0.18486632 0.18486632 0.18486632
#  0.18486632 0.18486632 0.18486632 0.18486632]
# results mean D 1 a best monolitics 0.18486631846344911

# %% [markdown]
# ##### b - Caso 1

# %%
train_labels=train_labels_2
val_labels=val_labels_2
test_labels=test_labels_2
val_df = pd.read_csv("/content/Data/liar/Caso1/prob_val_1_b.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso1/prob_test_1_b.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]

# %%
algorithms_list = ['SVM', 'LR','RF','NB','MLP', 'EXTRA','KNN','CNN']
stacking = LogisticRegression(class_weight='balanced',multi_class='multinomial')
results_A = np.zeros(len(algorithms_list))
for idx_alg, algorithm in enumerate(algorithms_list):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, algorithm)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking.fit(X_val, labels_val)
  y_pred = stacking.predict(X_test)
  score = f1_score(labels_test, y_pred,average='macro')
  results_A[idx_alg] = score
print("results A - Caso 1 b", results_A)

fe_list = ['CV', 'TFIDF', 'W2V', 'GLOVE', 'FAST']
results_B = np.zeros(len(fe_list))
for idx_alg, fe in enumerate(fe_list):
    X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, fe)
    X_val, X_test = filter_collinearity(X_val, X_test)
    stacking.fit(X_val, labels_val)
    y_pred = stacking.predict(X_test)
    results_B[idx_alg] = f1_score(labels_test, y_pred,average='macro')
#     generate_confusion_matrix(stacking, X_test, labels_test, name)
print("resultsB - Caso 1 b", results_B)

results_C = 0
stacking_C = LogisticRegression()
X_val, X_test = filter_collinearity(probas_val.to_numpy(), probas_test.to_numpy())
stacking_C.fit(X_val, labels_val)
y_pred = stacking_C.predict(X_test)
results_C = f1_score(labels_test, y_pred,average='macro')
disp = plot_confusion_matrix(stacking_C, X_test, 
                             labels_test, cmap=plt.cm.Blues, 
                             display_labels=['False','Half-true','Mostly-true','True','Barely-true','Pants-fire'])
                             #['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
print("resultsC - Caso 1 b", results_C)
disp.ax_.set_title("Confusion Matrix - Group C")
plt.rcParams["figure.figsize"] = (10,8)
plt.tight_layout()
plt.savefig('confusion_matrix_GROUP_C_Caso_1_b.pdf', dpi=300)
# Out:
# results A - Caso 1 b [0.53334451 0.52220087 0.53737064 0.49669251 0.51812147 0.51532736
#  0.49962968 0.53228687]
# resultsB - Caso 1 b [0.51670334 0.52333179 0.53841772 0.52954231 0.5195696 ]
# resultsC - Caso 1 b 0.44416151649381536

# %% [markdown]
# ##### c - Caso 1

# %%
train_labels=train_labels_3
val_labels=val_labels_3
test_labels=test_labels_3
val_df = pd.read_csv("/content/Data/liar/Caso1/prob_val_1_c.csv").dropna()
test_df = pd.read_csv("/content/Data/liar/Caso1/prob_test_1_c.csv").dropna()

probas_val, labels_val = val_df.drop(columns=["Unnamed: 0","label"]), val_labels["label"]
probas_test, labels_test = test_df.drop(columns=["Unnamed: 0","label"]), test_labels["label"]

# %%
algorithms_list = ['SVM', 'LR','RF','NB','MLP', 'EXTRA','KNN','CNN']
stacking = LogisticRegression(class_weight='balanced',multi_class='multinomial')
results_A = np.zeros(len(algorithms_list))
for idx_alg, algorithm in enumerate(algorithms_list):
  X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, algorithm)
  X_val, X_test = filter_collinearity(X_val, X_test)
  stacking.fit(X_val, labels_val)
  y_pred = stacking.predict(X_test)
  score = f1_score(labels_test, y_pred,average='macro')
  results_A[idx_alg] = score
print("results A - Caso 1 c", results_A)

fe_list = ['CV', 'TFIDF', 'W2V', 'GLOVE', 'FAST']
results_B = np.zeros(len(fe_list))
for idx_alg, fe in enumerate(fe_list):
    X_val, X_test, cols = filter_df_train_test(probas_val, probas_test, fe)
    X_val, X_test = filter_collinearity(X_val, X_test)
    stacking.fit(X_val, labels_val)
    y_pred = stacking.predict(X_test)
    results_B[idx_alg] = f1_score(labels_test, y_pred,average='macro')
#     generate_confusion_matrix(stacking, X_test, labels_test, name)
print("resultsB - Caso 1 c", results_B)

results_C = 0
stacking_C = LogisticRegression()
X_val, X_test = filter_collinearity(probas_val.to_numpy(), probas_test.to_numpy())
stacking_C.fit(X_val, labels_val)
y_pred = stacking_C.predict(X_test)
results_C = f1_score(labels_test, y_pred,average='macro')
disp = plot_confusion_matrix(stacking_C, X_test, 
                             labels_test, cmap=plt.cm.Blues, 
                             display_labels=['False','Half-true','Mostly-true','True','Barely-true','Pants-fire'])
                             #['True','Mostly-true','Half-true','False','Barel-true','Pants-fire'])
print("resultsC - Caso 1 b", results_C)
disp.ax_.set_title("Confusion Matrix - Group C")
plt.rcParams["figure.figsize"] = (10,8)
plt.tight_layout()
plt.savefig('confusion_matrix_GROUP_C_Caso_1_c.pdf', dpi=300)
# Out:
# results A - Caso 1 c [0.60207091 0.59562085 0.58276109 0.58871263 0.60126634 0.58436895
#  0.56064987 0.60356255]
# resultsB - Caso 1 c [0.5751103  0.59493255 0.60551449 0.57941468 0.60271556]
# resultsC - Caso 1 b 0.529904427807891

# %% [markdown]
# ## Oracle

# %%
dataset_name = 'liar'
import pandas as pd
import numpy as np
from sklearn.metrics import f1_score, accuracy_score
def get_oracle(labels, pred={}, clfs=[]):
    cont = 0;
    list_yes = np.zeros((len(labels)))
    oracle_preds = np.zeros((len(labels)))
    for i, k in enumerate(labels):
        acertou = False
        for clf in clfs:
            if pred[clf][i] == k:
                acertou = True
                oracle_preds[i] = pred[clf][i]
                break
        if acertou:
            cont += 1
            list_yes[i] = k
        else:
            oracle_preds[i] = pred[clf][0]
            if k == 0:
                list_yes[i] = 1
            else:
                list_yes[i] = 0
    return cont, list_yes, oracle_preds
clfs = ['SVM-CV', 'SVM-TFIDF', 'SVM-W2V', 'SVM-GLOVE', 'SVM-FAST', 'SVM-BERT',
        'KNN-CV', 'KNN-TFIDF','KNN-W2V', 'KNN-GLOVE', 'KNN-FAST', 'KNN-BERT',
        'MLP-CV','MLP-TFIDF','MLP-W2V','MLP-GLOVE','MLP-FAST','MLP-BERT',
        'NB-CV','NB-TFIDF','NB-W2V','NB-GLOVE','NB-FAST','NB-BERT',
        'RF-CV','RF-TFIDF','RF-W2V','RF-GLOVE','RF-FAST','RF-BERT',
        'LR-CV','LR-TFIDF','LR-W2V','LR-GLOVE','LR-FAST','LR-BERT',
        'CNN-CV','CNN-TFIDF','CNN-W2V','CNN-GLOVE','CNN-FAST','CNN-BERT']

# %% [markdown]
# ### 1 a

# %%
def load_predictions_1_a(dataset_name):
    path =  '/content/Data/liar/Caso1' + '/pred_val_1_a' + '.csv'
    table_pred = pd.read_csv(path)
    label = table_pred['label']
    methods = table_pred.drop('label', axis=1)
    methods = methods.drop('Unnamed: 0', axis=1)
    return label, methods
label, methods = load_predictions_1_a(dataset_name)
names = {}
dataset_name='liar'
names['liar'] = ['RF-FAST','SVM-FAST','CNN-W2V','NB-GLOVE','MLP-TFIDF','MLP-W2V','EXTRA-FAST','EXTRA-TFIDF','SVM-TFIDF','NB-TFIDF']
#['MLP-FAST','KNN-GLOVE','KNN-FAST','KNN-CV','MLP-W2V','NB-CV','NB-FAST','RF-CV','LR-CV','KNN-W2V']

oracle, df_yes, oracle_preds = get_oracle(label.to_numpy(), methods, names[dataset_name])
print(oracle)
# Out:
# 976

# %% [markdown]
# #### Oracles Group B

# %%
names = {}
names['fast'] = ['MLP-FAST','KNN-FAST','EXTRA-FAST','RF-FAST','SVM-FAST','LR-FAST','NB-FAST','CNN-FAST']
names['glove'] = ['MLP-GLOVE','KNN-GLOVE','EXTRA-GLOVE','RF-GLOVE','SVM-GLOVE','LR-GLOVE','NB-GLOVE','CNN-GLOVE']
names['cv'] = ['MLP-CV','KNN-CV','EXTRA-CV','RF-CV','SVM-CV','LR-CV','NB-CV','CNN-CV']
names['tfidf'] = ['MLP-TFIDF','KNN-TFIDF','EXTRA-TFIDF','RF-TFIDF','SVM-TFIDF','LR-TFIDF','NB-TFIDF','CNN-TFIDF']
names['w2v'] = ['MLP-W2V','KNN-W2V','EXTRA-W2V','RF-W2V','SVM-W2V','LR-W2V','NB-W2V','NB-W2V']
                
for name in ['fast', 'glove', 'cv', 'tfidf', 'w2v']:
    oracle, df_yes, oracle_preds = get_oracle(label.to_numpy(), methods, names[name])
    print(f"{name}: {oracle}")
    score = accuracy_score(label.to_numpy(), oracle_preds)
    print(f"{name} acc score: {score}")
# Out:
# fast: 921
# fast acc score: 0.735981308411215
# glove: 870
# glove acc score: 0.7095015576323987
# cv: 843
# cv acc score: 0.7227414330218068
# tfidf: 849
# tfidf acc score: 0.6915887850467289
# w2v: 878
# w2v acc score: 0.7398753894080997

# %%
methods
# Out:
#       SVM-CV  SVM-TFIDF  SVM-W2V  SVM-GLOVE  SVM-FAST  LR-CV  LR-TFIDF  \
# 0          2          2        2          1         2      2         1
# 1          3          3        0          0         0      3         3
# 2          0          0        4          1         1      2         0
# 3          3          3        2          2         2      3         3
# 4          4          4        1          1         1      4         2
# ...      ...        ...      ...        ...       ...    ...       ...
# 1279       3          3        2          2         2      3         3
# 1280       1          3        2          1         2      3         3
# 1281       3          3        0          4         0      3         3
# 1282       4          4        0          0         0      4         4
# 1283       0          0        0          1         0      1         0
#
#       LR-GLOVE  LR-W2V  LR-FAST  ...  KNN-CV  KNN-TFIDF  KNN-GLOVE  KNN-W2V  \
# 0            2       2        2  ...       1          1          3        3
# 1            3       0        0  ...       0          3          0        4
# 2            2       0        1  ...       0          1          4        3
# 3            2       2        2  ...       0          2          0        2
# 4            1       1        1  ...       0          2          2        3
# ...        ...     ...      ...  ...     ...        ...        ...      ...
# 1279         2       2        2  ...       0          0          1        3
# 1280         1       2        3  ...       2          0          1        2
# 1281         4       0        0  ...       0          4          1        0
# 1282         0       0        0  ...       1          1          0        0
# 1283         0       0        0  ...       0          2          0        1
#
#       KNN-FAST  CNN-CV  CNN-TFIDF  CNN-W2V  CNN-GLOVE  CNN-FAST
# 0            3       2          0        3          2         0
# 1            4       0          5        0          4         5
# 2            0       0          5        3          2         0
# 3            1       3          3        3          3         3
# 4            0       4          5        0          2         0
# ...        ...     ...        ...      ...        ...       ...
# 1279         1       3          3        2          2         3
# 1280         0       2          2        2          2         0
# 1281         3       1          3        0          4         3
# 1282         0       1          1        3          2         1
# 1283         4       1          2        5          2         0
#
# [1284 rows x 40 columns]

# %%
from sklearn.preprocessing import Normalizer
norm = Normalizer()
from sklearn.datasets import make_classification
X, y = make_classification()
X_norm = norm.fit_transform(X)
X_norm
# Out:
# array([[ 0.57173185,  0.09540988, -0.01639037, ...,  0.20029115,
#          0.13095192,  0.38033514],
#        [-0.18382357, -0.29856745,  0.24402546, ...,  0.12783804,
#         -0.36249682, -0.0170639 ],
#        [ 0.03022311, -0.32810989, -0.29676239, ...,  0.03573387,
#          0.02281204,  0.15263112],
#        ...,
#        [-0.33563318, -0.05881109, -0.16361067, ..., -0.07782859,
#         -0.25766718, -0.0176905 ],
#        [ 0.03844618,  0.28542756, -0.04713105, ..., -0.06704036,
#          0.18328638,  0.16005999],
#        [-0.05778998,  0.22303241, -0.1564934 , ...,  0.03665256,
#          0.17646125, -0.00701236]])

# %% [markdown]
# ### 1 b

# %%
def load_predictions_1_a(dataset_name):
    path =  '/content/Data/liar/Caso1' + '/pred_val_1_b' + '.csv'
    table_pred = pd.read_csv(path)
    label = table_pred['label']
    methods = table_pred.drop('label', axis=1)
    methods = methods.drop('Unnamed: 0', axis=1)
    return label, methods
label, methods = load_predictions_1_a(dataset_name)
names = {}
dataset_name='liar'
names['liar'] = [
                 'SVM-GLOVE', 'MLP-FAST', 'SVM-FAST', 'EXTRA-GLOVE', 'EXTRA-CV', 'SVM-TFIDF', 'NB-FAST', 'RF-CV', 'KNN-TFIDF', 'KNN-GLOVE']
#['MLP-FAST','KNN-GLOVE','KNN-FAST','KNN-CV','MLP-W2V','NB-CV','NB-FAST','RF-CV','LR-CV','KNN-W2V']

oracle, df_yes, oracle_preds = get_oracle(label.to_numpy(), methods, names[dataset_name])
print(oracle)
# Out:
# 1186

# %% [markdown]
# ### 1 c

# %%
def load_predictions_1_a(dataset_name):
    path =  '/content/Data/liar/Caso1' + '/pred_val_1_c' + '.csv'
    table_pred = pd.read_csv(path)
    label = table_pred['label']
    methods = table_pred.drop('label', axis=1)
    methods = methods.drop('Unnamed: 0', axis=1)
    return label, methods
label, methods = load_predictions_1_a(dataset_name)
names = {}
dataset_name='liar'
names['liar'] = ['CNN-CV', 'EXTRA-FAST', 'LR-TFIDF', 'SVM-FAST', 'KNN-FAST', 'NB-W2V', 'EXTRA-W2V', 'EXTRA-CV', 'NB-CV', 'SVM-CV']

oracle, df_yes, oracle_preds = get_oracle(label.to_numpy(), methods, names[dataset_name])

# %%
print(oracle)
# Out:
# 1210

# %% [markdown]
# ### 2 a

# %%
def load_predictions_1_a(dataset_name):
    path =  '/content/Data/liar/Caso2' + '/pred_val_2_a' + '.csv'
    table_pred = pd.read_csv(path)
    label = table_pred['label']
    methods = table_pred.drop('label', axis=1)
    methods = methods.drop('Unnamed: 0', axis=1)
    return label, methods
label, methods = load_predictions_1_a(dataset_name)
names = {}
dataset_name='liar'
names['liar'] = ['CNN-TFIDF','NB-W2V','NB-GLOVE','EXTRA-GLOVE','LR-FAST', 'MLP-FAST', 'MLP-TFIDF', 'RF-TFIDF', 'MLP-W2V', 'NB-CV']

oracle, df_yes, oracle_preds = get_oracle(label.to_numpy(), methods, names[dataset_name])

# %%
print(oracle)
# Out:
# 1005

# %% [markdown]
# ### 2 b

# %%
def load_predictions_1_a(dataset_name):
    path =  '/content/Data/liar/Caso2' + '/pred_val_2_b' + '.csv'
    table_pred = pd.read_csv(path)
    label = table_pred['label']
    methods = table_pred.drop('label', axis=1)
    methods = methods.drop('Unnamed: 0', axis=1)
    return label, methods
label, methods = load_predictions_1_a(dataset_name)
names = {}
dataset_name='liar'
names['liar'] = ['SVM-GLOVE', 'CNN-FAST','MLP-TFIDF','EXTRA-TFIDF','KNN-CV','NB-W2V','KNN-FAST']

oracle, df_yes, oracle_preds = get_oracle(label.to_numpy(), methods, names[dataset_name])

# %%
print(oracle)
# Out:
# 1209

# %% [markdown]
# ### 2 c

# %%
def load_predictions_1_a(dataset_name):
    path =  '/content/Data/liar/Caso2' + '/pred_val_2_c' + '.csv'
    table_pred = pd.read_csv(path)
    label = table_pred['label']
    methods = table_pred.drop('label', axis=1)
    methods = methods.drop('Unnamed: 0', axis=1)
    return label, methods
label, methods = load_predictions_1_a(dataset_name)
names = {}
dataset_name='liar'
names['liar'] = ['NB-FAST','MLP-FAST','LR-W2V','LR-CV','CNN-CV','NB-TFIDF','MLP-CV','KNN-TFIDF']

oracle, df_yes, oracle_preds = get_oracle(label.to_numpy(), methods, names[dataset_name])

# %%
print(oracle)
# Out:
# 1206

# %% [markdown]
# ### 3 a

# %%
def load_predictions_1_a(dataset_name):
    path =  '/content/Data/liar/Caso3/union' + '/pred_val_3_a' + '.csv'
    table_pred = pd.read_csv(path)
    label = table_pred['label']
    methods = table_pred.drop('label', axis=1)
    methods = methods.drop('Unnamed: 0', axis=1)
    return label, methods
label, methods = load_predictions_1_a(dataset_name)
names = {}
dataset_name='liar'
names['liar'] = ['CNN-TFIDF','MLP-CV','KNN-TFIDF','MLP-W2V','LR-GLOVE','SVM-FAST','KNN-GLOVE','MLP-TFIDF','NB-FAST','NB-CV','RF-CV']

oracle, df_yes, oracle_preds = get_oracle(label.to_numpy(), methods, names[dataset_name])

# %%
print(oracle)
# Out:
# 1039

# %% [markdown]
# ### 3 b

# %%
def load_predictions_1_a(dataset_name):
    path =  '/content/Data/liar/Caso3/union' + '/pred_val_3_b' + '.csv'
    table_pred = pd.read_csv(path)
    label = table_pred['label']
    methods = table_pred.drop('label', axis=1)
    methods = methods.drop('Unnamed: 0', axis=1)
    return label, methods
label, methods = load_predictions_1_a(dataset_name)
names = {}
dataset_name='liar'
names['liar'] = ['CNN-GLOVE','CNN-W2V','CNN-TFIDF','KNN-W2V','EXTRA-CV','LR-TFIDF','MLP-TFIDF']

oracle, df_yes, oracle_preds = get_oracle(label.to_numpy(), methods, names[dataset_name])

# %%
print(oracle)
# Out:
# 1205

# %% [markdown]
# ### 3 c

# %%
def load_predictions_1_a(dataset_name):
    path =  '/content/Data/liar/Caso3/union' + '/pred_val_3_c' + '.csv'
    table_pred = pd.read_csv(path)
    label = table_pred['label']
    methods = table_pred.drop('label', axis=1)
    methods = methods.drop('Unnamed: 0', axis=1)
    return label, methods
label, methods = load_predictions_1_a(dataset_name)
names = {}
dataset_name='liar'
names['liar'] = ['LR-FAST','RF-TFIDF','LR-W2V','SVM-W2V','EXTRA-FAST','NB-GLOVE','LR-TFIDF','CNN-CV','NB-W2V','NB-TFIDF','MLP-TFIDF']

oracle, df_yes, oracle_preds = get_oracle(label.to_numpy(), methods, names[dataset_name])

# %%
print(oracle)
# Out:
# 1192
